# %%
# %load_ext autoreload
# %autoreload 2

# %%
channel='ibm_quantum'
token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86'

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(500, 505),
    run_on_ibm=True,
    channel=channel,
    token=token
)
# Out:
# Running experiment with payload_size=1 and gates=500
# ibm_kyiv
# 4
# >>> Job ID: cyv0974q5bwg0083nxqg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2000, '0': 2096}
# Experiment with payload=1, gates=500 completed with status: completed
#
# Running experiment with payload_size=1 and gates=501
# ibm_kyiv
# 4
# >>> Job ID: cyv09f578z600082q1pg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1643, '1': 2453}
# Experiment with payload=1, gates=501 completed with status: completed
#
# Running experiment with payload_size=1 and gates=502
# ibm_kyiv
# 5
# >>> Job ID: cyv09rzq5bwg0083nxtg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# Job timed out after 10 minutes
# Experiment with payload=1, gates=502 completed with status: pending
#
# Running experiment with payload_size=1 and gates=503
# ibm_kyiv
# 5
# >>> Job ID: cyv0emay2gd0008864eg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2034, '0': 2062}
# Experiment with payload=1, gates=503 completed with status: completed
#
# Running experiment with payload_size=1 and gates=504
# ibm_kyiv
# 5
# >>> Job ID: cyv0exb4raf0008ejsv0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1476, '0': 2620}
# Experiment with payload=1, gates=504 completed with status: completed
#
# Running experiment with payload_size=1 and gates=505
# ibm_kyiv
# 5
# >>> Job ID: cyv0f6438jq0008xxx7g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1540, '0': 2556}
# Experiment with payload=1, gates=505 completed with status: completed
#
# Running experiment with payload_size=2 and gates=500
# ibm_kyiv
# 5
# >>> Job ID: cyv0fdnq5bwg0083nygg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1231, '10': 1209, '11': 857, '01': 799}
# Experiment with payload=2, gates=500 completed with status: completed
#
# Running experiment with payload_size=2 and gates=501
# ibm_kyiv
# 5
# >>> Job ID: cyv0fpp38jq0008xxxbg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 1112, '10': 1022, '01': 788, '00': 1174}
# Experiment with payload=2, gates=501 completed with status: completed
#
# Running experiment with payload_size=2 and gates=502
# ibm_kyiv
# 5
# >>> Job ID: cyv0fzq38jq0008xxxcg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 807, '10': 1079, '01': 1162, '11': 1048}
# Experiment with payload=2, gates=502 completed with status: completed
#
# Running experiment with payload_size=2 and gates=503
# ibm_kyiv
# 6
# >>> Job ID: cyv0g81q5bwg0083nyp0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1023, '01': 1046, '11': 1164, '10': 863}
# Experiment with payload=2, gates=503 completed with status: completed
#
# Running experiment with payload_size=2 and gates=504
# ibm_kyiv
# 5
# >>> Job ID: cyv0gga78z600082q2hg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 1192, '01': 775, '10': 964, '00': 1165}
# Experiment with payload=2, gates=504 completed with status: completed
#
# Running experiment with payload_size=2 and gates=505
# ibm_kyiv
# 5
# >>> Job ID: cyv0grv78z600082q2j0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1116, '11': 1147, '10': 1005, '01': 828}
# Experiment with payload=2, gates=505 completed with status: completed
#
# Running experiment with payload_size=3 and gates=500
# ibm_kyiv
# 5
# >>> Job ID: cyv0h2m38jq0008xxxmg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 393, '100': 410, '001': 479, '010': 642, '011': 555, '101': 378, '000': 796, '111': 443}
# Experiment with payload=3, gates=500 completed with status: completed
#
# Running experiment with payload_size=3 and gates=501
# ibm_kyiv
# 6
# >>> Job ID: cyv0hbd78z600082q2qg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'101': 707, '001': 457, '111': 580, '011': 375, '100': 632, '010': 380, '000': 415, '110': 550}
# Experiment with payload=3, gates=501 completed with status: completed
#
# Running experiment with payload_size=3 and gates=502
# ibm_kyiv
# 5
# >>> Job ID: cyv0hm6y2gd00088652g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'001': 419, '110': 599, '000': 439, '011': 406, '010': 442, '101': 582, '100': 630, '111': 579}
# Experiment with payload=3, gates=502 completed with status: completed
#
# Running experiment with payload_size=3 and gates=503
# ibm_kyiv
# 6
# >>> Job ID: cyv0hvq4raf0008ejt90
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'000': 368, '011': 596, '110': 455, '101': 615, '100': 567, '001': 428, '010': 646, '111': 421}
# Experiment with payload=3, gates=503 completed with status: completed
#
# Running experiment with payload_size=3 and gates=504
# ibm_kyiv
# 5
# >>> Job ID: cyv0j484raf0008ejt9g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 558, '001': 477, '100': 503, '011': 475, '010': 525, '111': 490, '101': 593, '000': 475}
# Experiment with payload=3, gates=504 completed with status: completed
#
# Running experiment with payload_size=3 and gates=505
# ibm_kyiv
# 6
# >>> Job ID: cyv0jd9jj6dg008g49t0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'001': 580, '011': 681, '111': 458, '000': 597, '100': 376, '110': 389, '101': 396, '010': 619}
# Experiment with payload=3, gates=505 completed with status: completed
#
# Running experiment with payload_size=4 and gates=500
# ibm_kyiv
# 5
# >>> Job ID: cyv0jpa4raf0008ejtag
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1011': 239, '0111': 242, '0010': 250, '1101': 252, '1110': 268, '1111': 261, '1010': 230, '0110': 254, '0001': 263, '0101': 284, '1100': 256, '0000': 258, '0011': 281, '0100': 265, '1001': 269, '1000': 224}
# Experiment with payload=4, gates=500 completed with status: completed
#
# Running experiment with payload_size=4 and gates=501
# ibm_kyiv
# 5
# >>> Job ID: cyv0jzvjj6dg008g49tg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1110': 231, '1001': 278, '0011': 212, '1111': 247, '1101': 233, '1011': 292, '0101': 253, '1010': 265, '0100': 264, '0001': 249, '0111': 229, '1000': 292, '0000': 266, '0110': 253, '0010': 268, '1100': 264}
# Experiment with payload=4, gates=501 completed with status: completed
#
# Running experiment with payload_size=4 and gates=502
# ibm_kyiv
# 9
# >>> Job ID: cyv0nsq38jq0008xxxv0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1011': 247, '1010': 229, '1001': 234, '0001': 260, '0010': 236, '1110': 222, '0011': 267, '0111': 279, '1111': 202, '1101': 216, '0000': 265, '1000': 290, '0101': 282, '1100': 214, '0100': 328, '0110': 325}
# Experiment with payload=4, gates=502 completed with status: completed
#
# Running experiment with payload_size=4 and gates=503
# ibm_kyiv
# 9
# >>> Job ID: cyv0p2ry2gd0008865f0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0010': 194, '0001': 239, '1011': 288, '1010': 283, '1111': 298, '0011': 249, '1001': 316, '0100': 186, '1110': 323, '0000': 210, '0111': 190, '1000': 337, '1100': 319, '0110': 179, '1101': 277, '0101': 208}
# Experiment with payload=4, gates=503 completed with status: completed
#
# Running experiment with payload_size=4 and gates=504
# ibm_kyiv
# 7
# >>> Job ID: cyv0pbs38jq0008xxxz0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0010': 273, '1011': 254, '0110': 265, '0000': 234, '0101': 273, '1111': 257, '0011': 267, '1000': 236, '0111': 278, '1010': 244, '0100': 221, '1001': 259, '0001': 258, '1110': 287, '1101': 245, '1100': 245}
# Experiment with payload=4, gates=504 completed with status: completed
#
# Running experiment with payload_size=4 and gates=505
# ibm_kyiv
# 7
# >>> Job ID: cyv0pmjy2gd0008865k0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0000': 327, '0110': 363, '0011': 305, '1111': 222, '1001': 210, '0001': 320, '1100': 181, '1101': 185, '0101': 308, '0100': 319, '1011': 194, '0010': 301, '1010': 173, '0111': 331, '1000': 186, '1110': 171}
# Experiment with payload=4, gates=505 completed with status: completed
# [{'status': 'completed',
#   'circuit_metrics': {'depth': 1005,
#    'width': 5,
#    'size': 1011,
#    'count_ops': OrderedDict([('x', 206),
#                 ('y', 186),
#                 ('u', 180),
#                 ('s', 107),
#                 ('t', 107),
#                 ('tdg', 107),
#                 ('sdg', 107),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0974q5bwg0083nxqg',
#    'counts': {'1': 2000, '0': 2096},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 2000, '0': 2096},
#    'success_rate': 0.51171875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 500,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1007,
#    'width': 5,
#    'size': 1013,
#    'count_ops': OrderedDict([('y', 216),
#                 ('u', 214),
#                 ('x', 194),
#                 ('s', 112),
#                 ('sdg', 112),
#                 ('t', 77),
#                 ('tdg', 77),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv09f578z600082q1pg',
#    'counts': {'0': 1643, '1': 2453},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0': 1643, '1': 2453},
#    'success_rate': 0.401123046875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 501,
#    'execution_type': 'ibm'}},
#  {'status': 'pending',
#   'circuit_metrics': {'depth': 1009,
#    'width': 5,
#    'size': 1015,
#    'count_ops': OrderedDict([('y', 214),
#                 ('x', 198),
#                 ('u', 192),
#                 ('s', 101),
#                 ('sdg', 101),
#                 ('t', 99),
#                 ('tdg', 99),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'pending',
#    'job_id': 'cyv09rzq5bwg0083nxtg',
#    'backend': 'ibm_kyiv'},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 502,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1011,
#    'width': 5,
#    'size': 1017,
#    'count_ops': OrderedDict([('x', 226),
#                 ('y', 184),
#                 ('u', 182),
#                 ('t', 104),
#                 ('tdg', 104),
#                 ('s', 103),
#                 ('sdg', 103),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0emay2gd0008864eg',
#    'counts': {'1': 2034, '0': 2062},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 2034, '0': 2062},
#    'success_rate': 0.50341796875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 503,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1013,
#    'width': 5,
#    'size': 1019,
#    'count_ops': OrderedDict([('u', 228),
#                 ('x', 214),
#                 ('y', 172),
#                 ('s', 103),
#                 ('sdg', 103),
#                 ('t', 94),
#                 ('tdg', 94),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0exb4raf0008ejsv0',
#    'counts': {'1': 1476, '0': 2620},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 1476, '0': 2620},
#    'success_rate': 0.6396484375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 504,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1015,
#    'width': 5,
#    'size': 1021,
#    'count_ops': OrderedDict([('x', 218),
#                 ('u', 214),
#                 ('y', 194),
#                 ('s', 107),
#                 ('sdg', 107),
#                 ('t', 85),
#                 ('tdg', 85),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0f6438jq0008xxx7g',
#    'counts': {'1': 1540, '0': 2556},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 1540, '0': 2556},
#    'success_rate': 0.6240234375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 505,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 507,
#    'width': 7,
#    'size': 1016,
#    'count_ops': OrderedDict([('u', 236),
#                 ('x', 182),
#                 ('y', 178),
#                 ('s', 115),
#                 ('sdg', 115),
#                 ('t', 87),
#                 ('tdg', 87),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0fdnq5bwg0083nygg',
#    'counts': {'00': 1231, '10': 1209, '11': 857, '01': 799},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'00': 1231, '10': 1209, '11': 857, '01': 799},
#    'success_rate': 0.300537109375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 500,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 507,
#    'width': 7,
#    'size': 1018,
#    'count_ops': OrderedDict([('y', 250),
#                 ('u', 192),
#                 ('x', 192),
#                 ('s', 102),
#                 ('sdg', 102),
#                 ('t', 82),
#                 ('tdg', 82),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0fpp38jq0008xxxbg',
#    'counts': {'11': 1112, '10': 1022, '01': 788, '00': 1174},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'11': 1112,
#     '10': 1022,
#     '01': 788,
#     '00': 1174},
#    'success_rate': 0.28662109375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 501,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 509,
#    'width': 7,
#    'size': 1020,
#    'count_ops': OrderedDict([('x', 228),
#                 ('u', 214),
#                 ('y', 176),
#                 ('s', 102),
#                 ('sdg', 102),
#                 ('t', 91),
#                 ('tdg', 91),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0fzq38jq0008xxxcg',
#    'counts': {'00': 807, '10': 1079, '01': 1162, '11': 1048},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'00': 807,
#     '10': 1079,
#     '01': 1162,
#     '11': 1048},
#    'success_rate': 0.197021484375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 502,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 509,
#    'width': 7,
#    'size': 1022,
#    'count_ops': OrderedDict([('x', 214),
#                 ('u', 196),
#                 ('y', 184),
#                 ('s', 105),
#                 ('sdg', 105),
#                 ('t', 101),
#                 ('tdg', 101),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0g81q5bwg0083nyp0',
#    'counts': {'00': 1023, '01': 1046, '11': 1164, '10': 863},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'00': 1023,
#     '01': 1046,
#     '11': 1164,
#     '10': 863},
#    'success_rate': 0.249755859375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 503,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 511,
#    'width': 7,
#    'size': 1024,
#    'count_ops': OrderedDict([('x', 230),
#                 ('u', 224),
#                 ('y', 174),
#                 ('s', 98),
#                 ('sdg', 98),
#                 ('t', 92),
#                 ('tdg', 92),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0gga78z600082q2hg',
#    'counts': {'11': 1192, '01': 775, '10': 964, '00': 1165},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'11': 1192, '01': 775, '10': 964, '00': 1165},
#    'success_rate': 0.284423828125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 504,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 511,
#    'width': 7,
#    'size': 1026,
#    'count_ops': OrderedDict([('u', 224),
#                 ('y', 196),
#                 ('x', 188),
#                 ('s', 108),
#                 ('sdg', 108),
#                 ('t', 93),
#                 ('tdg', 93),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0grv78z600082q2j0',
#    'counts': {'00': 1116, '11': 1147, '10': 1005, '01': 828},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'00': 1116,
#     '11': 1147,
#     '10': 1005,
#     '01': 828},
#    'success_rate': 0.2724609375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 505,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 341,
#    'width': 9,
#    'size': 1021,
#    'count_ops': OrderedDict([('x', 214),
#                 ('y', 210),
#                 ('u', 184),
#                 ('t', 103),
#                 ('tdg', 103),
#                 ('s', 93),
#                 ('sdg', 93),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0h2m38jq0008xxxmg',
#    'counts': {'110': 393,
#     '100': 410,
#     '001': 479,
#     '010': 642,
#     '011': 555,
#     '101': 378,
#     '000': 796,
#     '111': 443},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'110': 393,
#     '100': 410,
#     '001': 479,
#     '010': 642,
#     '011': 555,
#     '101': 378,
#     '000': 796,
#     '111': 443},
#    'success_rate': 0.1943359375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 500,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 343,
#    'width': 9,
#    'size': 1023,
#    'count_ops': OrderedDict([('u', 206),
#                 ('x', 176),
#                 ('y', 170),
#                 ('s', 117),
#                 ('sdg', 117),
#                 ('t', 108),
#                 ('tdg', 108),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0hbd78z600082q2qg',
#    'counts': {'101': 707,
#     '001': 457,
#     '111': 580,
#     '011': 375,
#     '100': 632,
#     '010': 380,
#     '000': 415,
#     '110': 550},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'101': 707,
#     '001': 457,
#     '111': 580,
#     '011': 375,
#     '100': 632,
#     '010': 380,
#     '000': 415,
#     '110': 550},
#    'success_rate': 0.101318359375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 501,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 343,
#    'width': 9,
#    'size': 1025,
#    'count_ops': OrderedDict([('u', 194),
#                 ('x', 192),
#                 ('y', 180),
#                 ('s', 129),
#                 ('sdg', 129),
#                 ('t', 90),
#                 ('tdg', 90),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0hm6y2gd00088652g',
#    'counts': {'001': 419,
#     '110': 599,
#     '000': 439,
#     '011': 406,
#     '010': 442,
#     '101': 582,
#     '100': 630,
#     '111': 579},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'001': 419,
#     '110': 599,
#     '000': 439,
#     '011': 406,
#     '010': 442,
#     '101': 582,
#     '100': 630,
#     '111': 579},
#    'success_rate': 0.107177734375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 502,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 343,
#    'width': 9,
#    'size': 1027,
#    'count_ops': OrderedDict([('x', 210),
#                 ('u', 192),
#                 ('y', 146),
#                 ('s', 123),
#                 ('sdg', 123),
#                 ('t', 106),
#                 ('tdg', 106),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0hvq4raf0008ejt90',
#    'counts': {'000': 368,
#     '011': 596,
#     '110': 455,
#     '101': 615,
#     '100': 567,
#     '001': 428,
#     '010': 646,
#     '111': 421},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'000': 368,
#     '011': 596,
#     '110': 455,
#     '101': 615,
#     '100': 567,
#     '001': 428,
#     '010': 646,
#     '111': 421},
#    'success_rate': 0.08984375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 503,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 345,
#    'width': 9,
#    'size': 1029,
#    'count_ops': OrderedDict([('x', 242),
#                 ('u', 190),
#                 ('y', 172),
#                 ('t', 113),
#                 ('tdg', 113),
#                 ('s', 89),
#                 ('sdg', 89),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0j484raf0008ejt9g',
#    'counts': {'110': 558,
#     '001': 477,
#     '100': 503,
#     '011': 475,
#     '010': 525,
#     '111': 490,
#     '101': 593,
#     '000': 475},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'110': 558,
#     '001': 477,
#     '100': 503,
#     '011': 475,
#     '010': 525,
#     '111': 490,
#     '101': 593,
#     '000': 475},
#    'success_rate': 0.115966796875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 504,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 345,
#    'width': 9,
#    'size': 1031,
#    'count_ops': OrderedDict([('y', 212),
#                 ('u', 208),
#                 ('x', 192),
#                 ('t', 100),
#                 ('tdg', 100),
#                 ('s', 99),
#                 ('sdg', 99),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0jd9jj6dg008g49t0',
#    'counts': {'001': 580,
#     '011': 681,
#     '111': 458,
#     '000': 597,
#     '100': 376,
#     '110': 389,
#     '101': 396,
#     '010': 619},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'001': 580,
#     '011': 681,
#     '111': 458,
#     '000': 597,
#     '100': 376,
#     '110': 389,
#     '101': 396,
#     '010': 619},
#    'success_rate': 0.145751953125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 505,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 261,
#    'width': 11,
#    'size': 1026,
#    'count_ops': OrderedDict([('x', 220),
#                 ('y', 214),
#                 ('u', 182),
#                 ('t', 99),
#                 ('tdg', 99),
#                 ('s', 93),
#                 ('sdg', 93),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0jpa4raf0008ejtag',
#    'counts': {'1011': 239,
#     '0111': 242,
#     '0010': 250,
#     '1101': 252,
#     '1110': 268,
#     '1111': 261,
#     '1010': 230,
#     '0110': 254,
#     '0001': 263,
#     '0101': 284,
#     '1100': 256,
#     '0000': 258,
#     '0011': 281,
#     '0100': 265,
#     '1001': 269,
#     '1000': 224},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1011': 239,
#     '0111': 242,
#     '0010': 250,
#     '1101': 252,
#     '1110': 268,
#     '1111': 261,
#     '1010': 230,
#     '0110': 254,
#     '0001': 263,
#     '0101': 284,
#     '1100': 256,
#     '0000': 258,
#     '0011': 281,
#     '0100': 265,
#     '1001': 269,
#     '1000': 224},
#    'success_rate': 0.06298828125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 500,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 261,
#    'width': 11,
#    'size': 1028,
#    'count_ops': OrderedDict([('u', 220),
#                 ('y', 214),
#                 ('x', 188),
#                 ('t', 100),
#                 ('tdg', 100),
#                 ('s', 90),
#                 ('sdg', 90),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0jzvjj6dg008g49tg',
#    'counts': {'1110': 231,
#     '1001': 278,
#     '0011': 212,
#     '1111': 247,
#     '1101': 233,
#     '1011': 292,
#     '0101': 253,
#     '1010': 265,
#     '0100': 264,
#     '0001': 249,
#     '0111': 229,
#     '1000': 292,
#     '0000': 266,
#     '0110': 253,
#     '0010': 268,
#     '1100': 264},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1110': 231,
#     '1001': 278,
#     '0011': 212,
#     '1111': 247,
#     '1101': 233,
#     '1011': 292,
#     '0101': 253,
#     '1010': 265,
#     '0100': 264,
#     '0001': 249,
#     '0111': 229,
#     '1000': 292,
#     '0000': 266,
#     '0110': 253,
#     '0010': 268,
#     '1100': 264},
#    'success_rate': 0.06494140625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 501,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 261,
#    'width': 11,
#    'size': 1030,
#    'count_ops': OrderedDict([('x', 220),
#                 ('u', 208),
#                 ('y', 188),
#                 ('t', 99),
#                 ('tdg', 99),
#                 ('s', 95),
#                 ('sdg', 95),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0nsq38jq0008xxxv0',
#    'counts': {'1011': 247,
#     '1010': 229,
#     '1001': 234,
#     '0001': 260,
#     '0010': 236,
#     '1110': 222,
#     '0011': 267,
#     '0111': 279,
#     '1111': 202,
#     '1101': 216,
#     '0000': 265,
#     '1000': 290,
#     '0101': 282,
#     '1100': 214,
#     '0100': 328,
#     '0110': 325},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1011': 247,
#     '1010': 229,
#     '1001': 234,
#     '0001': 260,
#     '0010': 236,
#     '1110': 222,
#     '0011': 267,
#     '0111': 279,
#     '1111': 202,
#     '1101': 216,
#     '0000': 265,
#     '1000': 290,
#     '0101': 282,
#     '1100': 214,
#     '0100': 328,
#     '0110': 325},
#    'success_rate': 0.064697265625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 502,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 261,
#    'width': 11,
#    'size': 1032,
#    'count_ops': OrderedDict([('y', 218),
#                 ('x', 210),
#                 ('u', 192),
#                 ('s', 99),
#                 ('sdg', 99),
#                 ('t', 94),
#                 ('tdg', 94),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0p2ry2gd0008865f0',
#    'counts': {'0010': 194,
#     '0001': 239,
#     '1011': 288,
#     '1010': 283,
#     '1111': 298,
#     '0011': 249,
#     '1001': 316,
#     '0100': 186,
#     '1110': 323,
#     '0000': 210,
#     '0111': 190,
#     '1000': 337,
#     '1100': 319,
#     '0110': 179,
#     '1101': 277,
#     '0101': 208},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0010': 194,
#     '0001': 239,
#     '1011': 288,
#     '1010': 283,
#     '1111': 298,
#     '0011': 249,
#     '1001': 316,
#     '0100': 186,
#     '1110': 323,
#     '0000': 210,
#     '0111': 190,
#     '1000': 337,
#     '1100': 319,
#     '0110': 179,
#     '1101': 277,
#     '0101': 208},
#    'success_rate': 0.05126953125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 503,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 263,
#    'width': 11,
#    'size': 1034,
#    'count_ops': OrderedDict([('y', 236),
#                 ('x', 188),
#                 ('u', 182),
#                 ('t', 112),
#                 ('tdg', 112),
#                 ('s', 89),
#                 ('sdg', 89),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0pbs38jq0008xxxz0',
#    'counts': {'0010': 273,
#     '1011': 254,
#     '0110': 265,
#     '0000': 234,
#     '0101': 273,
#     '1111': 257,
#     '0011': 267,
#     '1000': 236,
#     '0111': 278,
#     '1010': 244,
#     '0100': 221,
#     '1001': 259,
#     '0001': 258,
#     '1110': 287,
#     '1101': 245,
#     '1100': 245},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0010': 273,
#     '1011': 254,
#     '0110': 265,
#     '0000': 234,
#     '0101': 273,
#     '1111': 257,
#     '0011': 267,
#     '1000': 236,
#     '0111': 278,
#     '1010': 244,
#     '0100': 221,
#     '1001': 259,
#     '0001': 258,
#     '1110': 287,
#     '1101': 245,
#     '1100': 245},
#    'success_rate': 0.05712890625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 504,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 263,
#    'width': 11,
#    'size': 1036,
#    'count_ops': OrderedDict([('x', 224),
#                 ('y', 210),
#                 ('u', 182),
#                 ('s', 122),
#                 ('sdg', 122),
#                 ('t', 75),
#                 ('tdg', 75),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0pmjy2gd0008865k0',
#    'counts': {'0000': 327,
#     '0110': 363,
#     '0011': 305,
#     '1111': 222,
#     '1001': 210,
#     '0001': 320,
#     '1100': 181,
#     '1101': 185,
#     '0101': 308,
#     '0100': 319,
#     '1011': 194,
#     '0010': 301,
#     '1010': 173,
#     '0111': 331,
#     '1000': 186,
#     '1110': 171},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0000': 327,
#     '0110': 363,
#     '0011': 305,
#     '1111': 222,
#     '1001': 210,
#     '0001': 320,
#     '1100': 181,
#     '1101': 185,
#     '0101': 308,
#     '0100': 319,
#     '1011': 194,
#     '0010': 301,
#     '1010': 173,
#     '0111': 331,
#     '1000': 186,
#     '1110': 171},
#    'success_rate': 0.079833984375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 505,
#    'execution_type': 'ibm'}}]

# %%
experiments.plot_success_rates()
