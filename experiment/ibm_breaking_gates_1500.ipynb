# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(1500, 1505),
    run_on_ibm=True,
    channel=channel,
    token=token
)
# Out:
# Running experiment with payload_size=1 and gates=1500
# ibm_kyiv
# 5
# >>> Job ID: cyv10t338jq0008xxz20
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2115, '1': 1981}
# Experiment with payload=1, gates=1500 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1501
# ibm_kyiv
# 5
# >>> Job ID: cyv113c78z600082q4eg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1987, '0': 2109}
# Experiment with payload=1, gates=1501 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1502
# ibm_kyiv
# 7
# >>> Job ID: cyv11cx4raf0008ejvr0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2061, '0': 2035}
# Experiment with payload=1, gates=1502 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1503
# ibm_kyiv
# 5
# >>> Job ID: cyv11p6q5bwg0083p0mg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1922, '0': 2174}
# Experiment with payload=1, gates=1503 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1504
# ibm_kyiv
# 5
# >>> Job ID: cyv11zq4raf0008ejvsg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2085, '0': 2011}
# Experiment with payload=1, gates=1504 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1505
# ibm_kyiv
# 5
# >>> Job ID: cyv128hy2gd0008866mg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2123, '1': 1973}
# Experiment with payload=1, gates=1505 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1500
# ibm_kyiv
# 5
# >>> Job ID: cyv12hjq5bwg0083p0ng
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1011, '01': 866, '11': 1002, '10': 1217}
# Experiment with payload=2, gates=1500 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1501
# ibm_kyiv
# 5
# >>> Job ID: cyv12tk78z600082q4j0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1021, '01': 965, '11': 1093, '10': 1017}
# Experiment with payload=2, gates=1501 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1502
# ibm_kyiv
# 5
# >>> Job ID: cyv133cjj6dg008g4b60
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 881, '10': 859, '00': 1604, '01': 752}
# Experiment with payload=2, gates=1502 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1503
# ibm_kyiv
# 5
# >>> Job ID: cyv13c54raf0008ejvvg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 994, '00': 1038, '10': 1024, '11': 1040}
# Experiment with payload=2, gates=1503 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1504
# ibm_kyiv
# 6
# >>> Job ID: cyv13mp4raf0008ejvwg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 1068, '10': 1131, '11': 925, '00': 972}
# Experiment with payload=2, gates=1504 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1505
# ibm_kyiv
# 5
# >>> Job ID: cyv13xz4raf0008ejvx0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 1034, '00': 896, '10': 1315, '01': 851}
# Experiment with payload=2, gates=1505 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1500
# ibm_kyiv
# 5
# >>> Job ID: cyv147838jq0008xxz5g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'000': 483, '111': 509, '001': 571, '011': 551, '101': 511, '110': 470, '100': 505, '010': 496}
# Experiment with payload=3, gates=1500 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1501
# ibm_kyiv
# 6
# >>> Job ID: cyv14gj38jq0008xxz60
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'001': 673, '010': 536, '000': 553, '111': 433, '011': 590, '101': 426, '100': 438, '110': 447}
# Experiment with payload=3, gates=1501 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1502
# ibm_kyiv
# 6
# >>> Job ID: cyv14sk38jq0008xxz7g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 376, '100': 385, '101': 413, '000': 480, '001': 635, '010': 557, '011': 775, '111': 475}
# Experiment with payload=3, gates=1502 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1503
# ibm_kyiv
# 5
# >>> Job ID: cyv153cjj6dg008g4b90
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'111': 490, '100': 482, '010': 532, '011': 509, '001': 514, '000': 481, '101': 506, '110': 582}
# Experiment with payload=3, gates=1503 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1504
# ibm_kyiv
# 5
# >>> Job ID: cyv15cdjj6dg008g4bb0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 607, '101': 624, '011': 441, '000': 379, '001': 405, '100': 615, '111': 602, '010': 423}
# Experiment with payload=3, gates=1504 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1505
# ibm_kyiv
# 5
# >>> Job ID: cyv15ne78z600082q4n0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'100': 480, '110': 511, '101': 579, '010': 526, '000': 489, '111': 537, '011': 508, '001': 466}
# Experiment with payload=3, gates=1505 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1500
# ibm_kyiv
# 5
# >>> Job ID: cyv15yqy2gd0008866s0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1000': 261, '0000': 249, '0111': 255, '0100': 245, '1011': 273, '0110': 239, '0011': 247, '0001': 249, '0010': 255, '1101': 275, '1001': 248, '1010': 249, '1111': 282, '1110': 271, '0101': 252, '1100': 246}
# Experiment with payload=4, gates=1500 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1501
# ibm_kyiv
# 5
# >>> Job ID: cyv167gq5bwg0083p0wg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1110': 277, '0101': 262, '0011': 233, '1001': 261, '1111': 263, '1000': 260, '1011': 245, '0111': 242, '0100': 266, '1101': 274, '1010': 240, '0000': 222, '0001': 273, '0110': 286, '1100': 246, '0010': 246}
# Experiment with payload=4, gates=1501 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1502
# ibm_kyiv
# 5
# >>> Job ID: cyv16s3q5bwg0083p0y0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1000': 340, '1111': 165, '1010': 324, '0000': 312, '1110': 175, '1001': 344, '1011': 355, '0100': 193, '0001': 353, '1101': 165, '0010': 322, '0011': 353, '1100': 186, '0111': 182, '0110': 160, '0101': 167}
# Experiment with payload=4, gates=1502 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1503
# ibm_kyiv
# 7
# >>> Job ID: cyv172w78z600082q4s0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1100': 230, '1000': 261, '0000': 263, '0101': 276, '1011': 239, '1101': 248, '1010': 269, '0001': 238, '0110': 252, '0011': 254, '0100': 278, '0111': 262, '1001': 243, '1111': 279, '1110': 242, '0010': 262}
# Experiment with payload=4, gates=1503 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1504
# ibm_kyiv
# 7
# >>> Job ID: cyv1838jj6dg008g4bhg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0110': 312, '0010': 284, '1001': 208, '0000': 332, '0101': 345, '1100': 202, '0001': 321, '1011': 231, '1000': 174, '0111': 309, '1101': 212, '0011': 301, '1010': 199, '1111': 192, '0100': 306, '1110': 168}
# Experiment with payload=4, gates=1504 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1505
# ibm_kyiv
# 7
# >>> Job ID: cyv18j2y2gd000886700
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0111': 264, '1110': 242, '0100': 257, '1100': 208, '0000': 264, '1111': 244, '1010': 258, '0010': 271, '0110': 248, '1000': 247, '1001': 298, '1011': 273, '1101': 232, '0011': 306, '0101': 252, '0001': 232}
# Experiment with payload=4, gates=1505 completed with status: completed
# [{'status': 'completed',
#   'circuit_metrics': {'depth': 3005,
#    'width': 5,
#    'size': 3011,
#    'count_ops': OrderedDict([('y', 648),
#                 ('x', 600),
#                 ('u', 582),
#                 ('s', 295),
#                 ('sdg', 295),
#                 ('t', 290),
#                 ('tdg', 290),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv10t338jq0008xxz20',
#    'counts': {'0': 2115, '1': 1981},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0': 2115, '1': 1981},
#    'success_rate': 0.516357421875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1500,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 3007,
#    'width': 5,
#    'size': 3013,
#    'count_ops': OrderedDict([('u', 670),
#                 ('y', 592),
#                 ('x', 578),
#                 ('s', 296),
#                 ('sdg', 296),
#                 ('t', 285),
#                 ('tdg', 285),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv113c78z600082q4eg',
#    'counts': {'1': 1987, '0': 2109},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 1987, '0': 2109},
#    'success_rate': 0.514892578125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1501,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 3009,
#    'width': 5,
#    'size': 3015,
#    'count_ops': OrderedDict([('y', 642),
#                 ('u', 618),
#                 ('x', 540),
#                 ('t', 310),
#                 ('tdg', 310),
#                 ('s', 292),
#                 ('sdg', 292),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv11cx4raf0008ejvr0',
#    'counts': {'1': 2061, '0': 2035},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 2061, '0': 2035},
#    'success_rate': 0.496826171875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1502,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 3011,
#    'width': 5,
#    'size': 3017,
#    'count_ops': OrderedDict([('x', 656),
#                 ('u', 610),
#                 ('y', 576),
#                 ('s', 301),
#                 ('sdg', 301),
#                 ('t', 281),
#                 ('tdg', 281),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv11p6q5bwg0083p0mg',
#    'counts': {'1': 1922, '0': 2174},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 1922, '0': 2174},
#    'success_rate': 0.53076171875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1503,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 3013,
#    'width': 5,
#    'size': 3019,
#    'count_ops': OrderedDict([('x', 610),
#                 ('y', 606),
#                 ('u', 552),
#                 ('s', 314),
#                 ('sdg', 314),
#                 ('t', 306),
#                 ('tdg', 306),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv11zq4raf0008ejvsg',
#    'counts': {'1': 2085, '0': 2011},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 2085, '0': 2011},
#    'success_rate': 0.490966796875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1504,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 3015,
#    'width': 5,
#    'size': 3021,
#    'count_ops': OrderedDict([('u', 618),
#                 ('y', 616),
#                 ('x', 566),
#                 ('t', 320),
#                 ('tdg', 320),
#                 ('s', 285),
#                 ('sdg', 285),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv128hy2gd0008866mg',
#    'counts': {'0': 2123, '1': 1973},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0': 2123, '1': 1973},
#    'success_rate': 0.518310546875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1505,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1507,
#    'width': 7,
#    'size': 3016,
#    'count_ops': OrderedDict([('y', 650),
#                 ('u', 608),
#                 ('x', 590),
#                 ('t', 303),
#                 ('tdg', 303),
#                 ('s', 273),
#                 ('sdg', 273),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv12hjq5bwg0083p0ng',
#    'counts': {'00': 1011, '01': 866, '11': 1002, '10': 1217},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'00': 1011,
#     '01': 866,
#     '11': 1002,
#     '10': 1217},
#    'success_rate': 0.246826171875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1500,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1507,
#    'width': 7,
#    'size': 3018,
#    'count_ops': OrderedDict([('y', 630),
#                 ('x', 596),
#                 ('u', 548),
#                 ('t', 313),
#                 ('tdg', 313),
#                 ('s', 301),
#                 ('sdg', 301),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv12tk78z600082q4j0',
#    'counts': {'00': 1021, '01': 965, '11': 1093, '10': 1017},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'00': 1021,
#     '01': 965,
#     '11': 1093,
#     '10': 1017},
#    'success_rate': 0.249267578125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1501,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1509,
#    'width': 7,
#    'size': 3020,
#    'count_ops': OrderedDict([('x', 616),
#                 ('u', 616),
#                 ('y', 534),
#                 ('s', 318),
#                 ('sdg', 318),
#                 ('t', 301),
#                 ('tdg', 301),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv133cjj6dg008g4b60',
#    'counts': {'11': 881, '10': 859, '00': 1604, '01': 752},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'11': 881, '10': 859, '00': 1604, '01': 752},
#    'success_rate': 0.3916015625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1502,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1509,
#    'width': 7,
#    'size': 3022,
#    'count_ops': OrderedDict([('y', 638),
#                 ('x', 622),
#                 ('u', 574),
#                 ('t', 302),
#                 ('tdg', 302),
#                 ('s', 284),
#                 ('sdg', 284),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv13c54raf0008ejvvg',
#    'counts': {'01': 994, '00': 1038, '10': 1024, '11': 1040},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'01': 994,
#     '00': 1038,
#     '10': 1024,
#     '11': 1040},
#    'success_rate': 0.25341796875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1503,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1511,
#    'width': 7,
#    'size': 3024,
#    'count_ops': OrderedDict([('u', 632),
#                 ('x', 614),
#                 ('y', 586),
#                 ('t', 302),
#                 ('tdg', 302),
#                 ('s', 286),
#                 ('sdg', 286),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv13mp4raf0008ejvwg',
#    'counts': {'01': 1068, '10': 1131, '11': 925, '00': 972},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'01': 1068, '10': 1131, '11': 925, '00': 972},
#    'success_rate': 0.2373046875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1504,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1511,
#    'width': 7,
#    'size': 3026,
#    'count_ops': OrderedDict([('y', 624),
#                 ('u', 592),
#                 ('x', 580),
#                 ('s', 310),
#                 ('sdg', 310),
#                 ('t', 297),
#                 ('tdg', 297),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv13xz4raf0008ejvx0',
#    'counts': {'11': 1034, '00': 896, '10': 1315, '01': 851},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'11': 1034, '00': 896, '10': 1315, '01': 851},
#    'success_rate': 0.21875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1505,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1009,
#    'width': 9,
#    'size': 3021,
#    'count_ops': OrderedDict([('y', 610),
#                 ('u', 610),
#                 ('x', 550),
#                 ('s', 316),
#                 ('sdg', 316),
#                 ('t', 299),
#                 ('tdg', 299),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv147838jq0008xxz5g',
#    'counts': {'000': 483,
#     '111': 509,
#     '001': 571,
#     '011': 551,
#     '101': 511,
#     '110': 470,
#     '100': 505,
#     '010': 496},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'000': 483,
#     '111': 509,
#     '001': 571,
#     '011': 551,
#     '101': 511,
#     '110': 470,
#     '100': 505,
#     '010': 496},
#    'success_rate': 0.117919921875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1500,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1009,
#    'width': 9,
#    'size': 3023,
#    'count_ops': OrderedDict([('x', 610),
#                 ('y', 590),
#                 ('u', 566),
#                 ('s', 330),
#                 ('sdg', 330),
#                 ('t', 288),
#                 ('tdg', 288),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv14gj38jq0008xxz60',
#    'counts': {'001': 673,
#     '010': 536,
#     '000': 553,
#     '111': 433,
#     '011': 590,
#     '101': 426,
#     '100': 438,
#     '110': 447},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'001': 673,
#     '010': 536,
#     '000': 553,
#     '111': 433,
#     '011': 590,
#     '101': 426,
#     '100': 438,
#     '110': 447},
#    'success_rate': 0.135009765625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1501,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1009,
#    'width': 9,
#    'size': 3025,
#    'count_ops': OrderedDict([('u', 602),
#                 ('y', 588),
#                 ('x', 584),
#                 ('t', 310),
#                 ('tdg', 310),
#                 ('s', 305),
#                 ('sdg', 305),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv14sk38jq0008xxz7g',
#    'counts': {'110': 376,
#     '100': 385,
#     '101': 413,
#     '000': 480,
#     '001': 635,
#     '010': 557,
#     '011': 775,
#     '111': 475},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'110': 376,
#     '100': 385,
#     '101': 413,
#     '000': 480,
#     '001': 635,
#     '010': 557,
#     '011': 775,
#     '111': 475},
#    'success_rate': 0.1171875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1502,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1011,
#    'width': 9,
#    'size': 3027,
#    'count_ops': OrderedDict([('y', 612),
#                 ('x', 572),
#                 ('u', 548),
#                 ('t', 321),
#                 ('tdg', 321),
#                 ('s', 316),
#                 ('sdg', 316),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv153cjj6dg008g4b90',
#    'counts': {'111': 490,
#     '100': 482,
#     '010': 532,
#     '011': 509,
#     '001': 514,
#     '000': 481,
#     '101': 506,
#     '110': 582},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'111': 490,
#     '100': 482,
#     '010': 532,
#     '011': 509,
#     '001': 514,
#     '000': 481,
#     '101': 506,
#     '110': 582},
#    'success_rate': 0.117431640625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1503,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1011,
#    'width': 9,
#    'size': 3029,
#    'count_ops': OrderedDict([('x', 624),
#                 ('u', 608),
#                 ('y', 568),
#                 ('t', 319),
#                 ('tdg', 319),
#                 ('s', 285),
#                 ('sdg', 285),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv15cdjj6dg008g4bb0',
#    'counts': {'110': 607,
#     '101': 624,
#     '011': 441,
#     '000': 379,
#     '001': 405,
#     '100': 615,
#     '111': 602,
#     '010': 423},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'110': 607,
#     '101': 624,
#     '011': 441,
#     '000': 379,
#     '001': 405,
#     '100': 615,
#     '111': 602,
#     '010': 423},
#    'success_rate': 0.092529296875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1504,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1011,
#    'width': 9,
#    'size': 3031,
#    'count_ops': OrderedDict([('x', 620),
#                 ('y', 606),
#                 ('u', 574),
#                 ('s', 313),
#                 ('sdg', 313),
#                 ('t', 292),
#                 ('tdg', 292),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv15ne78z600082q4n0',
#    'counts': {'100': 480,
#     '110': 511,
#     '101': 579,
#     '010': 526,
#     '000': 489,
#     '111': 537,
#     '011': 508,
#     '001': 466},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'100': 480,
#     '110': 511,
#     '101': 579,
#     '010': 526,
#     '000': 489,
#     '111': 537,
#     '011': 508,
#     '001': 466},
#    'success_rate': 0.119384765625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1505,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 761,
#    'width': 11,
#    'size': 3026,
#    'count_ops': OrderedDict([('x', 606),
#                 ('u', 604),
#                 ('y', 584),
#                 ('t', 331),
#                 ('tdg', 331),
#                 ('s', 272),
#                 ('sdg', 272),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv15yqy2gd0008866s0',
#    'counts': {'1000': 261,
#     '0000': 249,
#     '0111': 255,
#     '0100': 245,
#     '1011': 273,
#     '0110': 239,
#     '0011': 247,
#     '0001': 249,
#     '0010': 255,
#     '1101': 275,
#     '1001': 248,
#     '1010': 249,
#     '1111': 282,
#     '1110': 271,
#     '0101': 252,
#     '1100': 246},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1000': 261,
#     '0000': 249,
#     '0111': 255,
#     '0100': 245,
#     '1011': 273,
#     '0110': 239,
#     '0011': 247,
#     '0001': 249,
#     '0010': 255,
#     '1101': 275,
#     '1001': 248,
#     '1010': 249,
#     '1111': 282,
#     '1110': 271,
#     '0101': 252,
#     '1100': 246},
#    'success_rate': 0.060791015625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1500,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 761,
#    'width': 11,
#    'size': 3028,
#    'count_ops': OrderedDict([('x', 630),
#                 ('u', 628),
#                 ('y', 568),
#                 ('t', 296),
#                 ('tdg', 296),
#                 ('s', 292),
#                 ('sdg', 292),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv167gq5bwg0083p0wg',
#    'counts': {'1110': 277,
#     '0101': 262,
#     '0011': 233,
#     '1001': 261,
#     '1111': 263,
#     '1000': 260,
#     '1011': 245,
#     '0111': 242,
#     '0100': 266,
#     '1101': 274,
#     '1010': 240,
#     '0000': 222,
#     '0001': 273,
#     '0110': 286,
#     '1100': 246,
#     '0010': 246},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1110': 277,
#     '0101': 262,
#     '0011': 233,
#     '1001': 261,
#     '1111': 263,
#     '1000': 260,
#     '1011': 245,
#     '0111': 242,
#     '0100': 266,
#     '1101': 274,
#     '1010': 240,
#     '0000': 222,
#     '0001': 273,
#     '0110': 286,
#     '1100': 246,
#     '0010': 246},
#    'success_rate': 0.05419921875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1501,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 761,
#    'width': 11,
#    'size': 3030,
#    'count_ops': OrderedDict([('u', 588),
#                 ('x', 582),
#                 ('y', 578),
#                 ('s', 330),
#                 ('sdg', 330),
#                 ('t', 298),
#                 ('tdg', 298),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv16s3q5bwg0083p0y0',
#    'counts': {'1000': 340,
#     '1111': 165,
#     '1010': 324,
#     '0000': 312,
#     '1110': 175,
#     '1001': 344,
#     '1011': 355,
#     '0100': 193,
#     '0001': 353,
#     '1101': 165,
#     '0010': 322,
#     '0011': 353,
#     '1100': 186,
#     '0111': 182,
#     '0110': 160,
#     '0101': 167},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1000': 340,
#     '1111': 165,
#     '1010': 324,
#     '0000': 312,
#     '1110': 175,
#     '1001': 344,
#     '1011': 355,
#     '0100': 193,
#     '0001': 353,
#     '1101': 165,
#     '0010': 322,
#     '0011': 353,
#     '1100': 186,
#     '0111': 182,
#     '0110': 160,
#     '0101': 167},
#    'success_rate': 0.076171875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1502,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 761,
#    'width': 11,
#    'size': 3032,
#    'count_ops': OrderedDict([('y', 656),
#                 ('x', 614),
#                 ('u', 590),
#                 ('t', 289),
#                 ('tdg', 289),
#                 ('s', 284),
#                 ('sdg', 284),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv172w78z600082q4s0',
#    'counts': {'1100': 230,
#     '1000': 261,
#     '0000': 263,
#     '0101': 276,
#     '1011': 239,
#     '1101': 248,
#     '1010': 269,
#     '0001': 238,
#     '0110': 252,
#     '0011': 254,
#     '0100': 278,
#     '0111': 262,
#     '1001': 243,
#     '1111': 279,
#     '1110': 242,
#     '0010': 262},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1100': 230,
#     '1000': 261,
#     '0000': 263,
#     '0101': 276,
#     '1011': 239,
#     '1101': 248,
#     '1010': 269,
#     '0001': 238,
#     '0110': 252,
#     '0011': 254,
#     '0100': 278,
#     '0111': 262,
#     '1001': 243,
#     '1111': 279,
#     '1110': 242,
#     '0010': 262},
#    'success_rate': 0.064208984375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1503,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 763,
#    'width': 11,
#    'size': 3034,
#    'count_ops': OrderedDict([('x', 606),
#                 ('y', 590),
#                 ('u', 568),
#                 ('t', 316),
#                 ('tdg', 316),
#                 ('s', 306),
#                 ('sdg', 306),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv1838jj6dg008g4bhg',
#    'counts': {'0110': 312,
#     '0010': 284,
#     '1001': 208,
#     '0000': 332,
#     '0101': 345,
#     '1100': 202,
#     '0001': 321,
#     '1011': 231,
#     '1000': 174,
#     '0111': 309,
#     '1101': 212,
#     '0011': 301,
#     '1010': 199,
#     '1111': 192,
#     '0100': 306,
#     '1110': 168},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0110': 312,
#     '0010': 284,
#     '1001': 208,
#     '0000': 332,
#     '0101': 345,
#     '1100': 202,
#     '0001': 321,
#     '1011': 231,
#     '1000': 174,
#     '0111': 309,
#     '1101': 212,
#     '0011': 301,
#     '1010': 199,
#     '1111': 192,
#     '0100': 306,
#     '1110': 168},
#    'success_rate': 0.0810546875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1504,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 763,
#    'width': 11,
#    'size': 3036,
#    'count_ops': OrderedDict([('u', 628),
#                 ('y', 622),
#                 ('x', 562),
#                 ('s', 304),
#                 ('sdg', 304),
#                 ('t', 295),
#                 ('tdg', 295),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv18j2y2gd000886700',
#    'counts': {'0111': 264,
#     '1110': 242,
#     '0100': 257,
#     '1100': 208,
#     '0000': 264,
#     '1111': 244,
#     '1010': 258,
#     '0010': 271,
#     '0110': 248,
#     '1000': 247,
#     '1001': 298,
#     '1011': 273,
#     '1101': 232,
#     '0011': 306,
#     '0101': 252,
#     '0001': 232},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0111': 264,
#     '1110': 242,
#     '0100': 257,
#     '1100': 208,
#     '0000': 264,
#     '1111': 244,
#     '1010': 258,
#     '0010': 271,
#     '0110': 248,
#     '1000': 247,
#     '1001': 298,
#     '1011': 273,
#     '1101': 232,
#     '0011': 306,
#     '0101': 252,
#     '0001': 232},
#    'success_rate': 0.064453125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1505,
#    'execution_type': 'ibm'}}]

# %%
experiments.plot_success_rates()
