# %%
# %load_ext autoreload
# %autoreload 2

# %%
QBRAID_API_KEY='60bnwpwdgqy'

import os

# Set an environment variable
os.environ['QBRAID_API_KEY'] = QBRAID_API_KEY

# Verify it was set
print(os.environ.get('QBRAID_API_KEY'))

from teleportation_validator_qbraid import Experiments
experiments = Experiments()
# Out:
# 60bnwpwdgqy

# %%
experiments = Experiments()
results = experiments.run_target_depth_experiment(min_experiments_per_depth=10, use_qbraid=True)
# Out:
# Running experiments for target depth: 13 (10 combinations)
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-osa6d3bu62rkj0r2mkms
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ds3q7h57bcluu0x69a2s
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 7, '1': 3}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-vpabk9e6ovyawrako0ol
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-xgddmiuig0oa8q05vk4x
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 10}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-f7gurrt1xg5hd13gjdq9
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 9, '1': 1}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-lztbuscz4rwd9zss8ts0
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 10}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-gqtgz90zi77eb2wvgoh0
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ajh4f7zio6jqqrkewgsz
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 7, '1': 3}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-jm7rvfa3e6zws0nwi0jk
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 9, '1': 1}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=1
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 13
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-vhv43r12tnflutw3ixan
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
# Results exported to experiment_results_target_depth_20250903_221822.csv
#
# Running experiments for target depth: 15 (10 combinations)
#   Running experiment with payload_size=1, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-zaxa2veysj04fhn7afpc
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-qup306cemls97pccs1ne
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '10': 2, '11': 4}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-40k2z24adj34966vz6m8
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-x213wfaqqd519o9y247s
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 2, '01': 3, '11': 5}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-mrp8n5nhnngeb55hw4uk
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-bxhxzh8cqlm5qh5rd4cv
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '01': 2, '11': 4}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-exk0kdu3jtoskpnlouax
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 9, '1': 1}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-e70jl1gvpm8hc5arfba8
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '01': 3, '11': 3}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-a54vfrn30odigvpp1dxg
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 9, '1': 1}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=2
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 15
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-8792jjifyj8phd940e76
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '01': 1, '10': 2, '11': 3}
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
# Results exported to experiment_results_target_depth_20250903_221822.csv
#
# Running experiments for target depth: 17 (10 combinations)
#   Running experiment with payload_size=1, gates=3
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-gr3mnhefwx10wq5ejcx1
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=4
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-27mr61xa91uc9c7o0f5a
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 3, '01': 3, '11': 4}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=3, gates=3
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ek64d03qci9zunt6rar6
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 2, '010': 2, '011': 2, '100': 1, '101': 3}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=3
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-4u3pw5ts0z01qlokoe2k
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 9, '1': 1}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=4
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-hsu1vjy21fv0puqmz57l
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '10': 2, '11': 4}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=3, gates=3
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-x0l1qww68mp7m4de2cy8
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 1, '001': 1, '011': 2, '101': 1, '111': 5}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=3
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-s6ruvbn4gn4map05k73f
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=4
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-7qzbg08bl52y5iv4pzy1
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '10': 4, '11': 2}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=3, gates=3
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-qflm54ad59wxcy2u7eh2
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 3, '100': 2, '101': 3, '111': 2}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=3
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 17
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-iqmn90zao8bzty4l5zfi
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 7, '1': 3}
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
# Results exported to experiment_results_target_depth_20250903_221822.csv
#
# Running experiments for target depth: 19 (10 combinations)
#   Running experiment with payload_size=1, gates=4
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 19
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-w2uvmqqrq2d9mv9tiwd1
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 7, '1': 3}
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=6
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 19
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-uzin5on9mwdc3fqats6o
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 2, '01': 1, '10': 2, '11': 5}
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=3, gates=6
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 19
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-nf00jx7tqsnwn1aupd6p
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 5, '011': 2, '100': 1, '111': 2}
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=4, gates=4
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 19
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-xcfkxdjguiak95fp88je
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0000': 3, '0001': 1, '0100': 1, '0101': 1, '1000': 1, '1110': 1, '1111': 2}
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=4
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 19
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-thy9zo78703rhvw708cb
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 8, '1': 2}
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=6
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 19
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ke4442vg209tvqun0paw
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00':
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'01010': 1, '01011': 1, '01101': 1, '10001': 1, '10011': 1, '11000': 2, '11001': 1, '11100': 1, '11110': 1}
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=18
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 47
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ex4dqw13te66spj9158n
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 10}
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=34
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 47
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-evxwn2yj0boc69gokifs
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 5, '01': 1, '10': 3, '11': 1}
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=3, gates=48
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 47
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-fqcurgltnu0umajvy8hr
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 1, '001': 2, '010': 1, '101': 3, '111': 3}
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=4, gates=60
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 47
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-adw0wvrm1ekima766fpo
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0000': 1, '0001': 2, '0100': 1, '0110': 1, '0111': 1, '1001': 1, '1010': 1, '1011': 1, '1111': 1}
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=5, gates=70
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 47
# Original circuit width: 13
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-n6n0w5uwg3u2cna28nb0
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00000': 1, '00100': 1, '01010': 1, '10011': 1, '10110': 1, '11000': 2, '11010': 1, '11110': 1, '11111': 1}
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
# Results exported to experiment_results_target_depth_20250903_221822.csv
#
# Running experiments for target depth: 49 (10 combinations)
#   Running experiment with payload_size=1, gates=19
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-znoh523a3q0jshznu775
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 7, '1': 3}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=36
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-xgx28nra031us6sotesx
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 1, '01': 1, '10': 2, '11': 6}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=3, gates=51
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-yrakyoitj580vrheg8j3
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 3, '010': 1, '011': 1, '110': 2, '111': 3}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=4, gates=64
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-4oqk2ejxuuz61xa44ca5
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0100': 3, '0101': 1, '1001': 1, '1100': 3, '1101': 1, '1110': 1}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=5, gates=75
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 13
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-qmcazpuvg5eeskvs5to2
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00100': 1, '00101': 1, '00110': 1, '00111': 1, '01100': 1, '01111': 1, '10000': 1, '10111': 1, '11000': 1, '11100': 1}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=1, gates=19
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-w7y4ck2r1nmyr7a8e68d
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 10}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=2, gates=36
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-4j1ph4jkfp79bsz0qpzk
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '01': 2, '10': 3, '11': 1}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=3, gates=51
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-jl2o3y5p7bfpzp2mp47e
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 2, '001': 1, '010': 1, '100': 1, '101': 1, '111': 4}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=4, gates=64
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-vfnwx9z4ffi05xxdstbf
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.RUNNING
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0000': 3, '0001': 1, '0100': 2, '0101': 1, '0111': 1, '1100': 1, '1101': 1}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
#   Running experiment with payload_size=5, gates=75
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 49
# Original circuit width: 13
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-f5c4m7s5o3cdcqcbo7u8
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00001': 1, '00011': 1, '00100': 1, '10100': 1, '10101': 1, '10111': 1, '11000': 1, '11001': 1, '11011': 1, '11100': 1}
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250903_221822.csv
