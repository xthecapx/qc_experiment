# %%
# %load_ext autoreload
# %autoreload 2

# %%
QBRAID_API_KEY='60bnwpwdgqy'

import os

# Set an environment variable
os.environ['QBRAID_API_KEY'] = QBRAID_API_KEY

# Verify it was set
print(os.environ.get('QBRAID_API_KEY'))

from teleportation_validator_qbraid import Experiments
experiments = Experiments()
# Out:
# 60bnwpwdgqy

# %%
experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(5000, 5005),
    use_qbraid=True
)
# Out:
# Running experiment with payload_size=1 and gates=5000
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 10011
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-cxvbh3fgyd5vyghl57h5
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 7, '1': 3}
# Experiment with payload=1, gates=5000 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=1 and gates=5001
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 10013
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-gmrgwe1h1pbcl139s793
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 6, '1': 4}
# Experiment with payload=1, gates=5001 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=1 and gates=5002
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 10015
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-qglvuayd0ypztkbj3ob0
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 9, '1': 1}
# Experiment with payload=1, gates=5002 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=1 and gates=5003
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 10017
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-nep0inmtv9j75key7l06
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 7, '1': 3}
# Experiment with payload=1, gates=5003 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=1 and gates=5004
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 10019
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-4qsjqhqxe908g3zlfbf6
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 7, '1': 3}
# Experiment with payload=1, gates=5004 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=1 and gates=5005
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 10021
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-8wwaigvz7sh2eytjtpek
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0': 5, '1': 5}
# Experiment with payload=1, gates=5005 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=2 and gates=5000
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 5013
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ypt5yocg2pu47e78ldmj
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 3, '01': 3, '10': 2, '11': 2}
# Experiment with payload=2, gates=5000 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=2 and gates=5001
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 5013
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-43hb5pygn6fq2hytuxal
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '01': 2, '11': 4}
# Experiment with payload=2, gates=5001 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=2 and gates=5002
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 5015
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-9a0h1byvntacy40w5dlb
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 1, '01': 4, '10': 3, '11': 2}
# Experiment with payload=2, gates=5002 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=2 and gates=5003
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 5015
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-7qbzazcw78r1qvicm3e9
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '01': 2, '10': 2, '11': 2}
# Experiment with payload=2, gates=5003 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=2 and gates=5004
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 5017
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ipnecdsiw401nftcaulm
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 4, '10': 1, '11': 5}
# Experiment with payload=2, gates=5004 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=2 and gates=5005
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 5017
# Original circuit width: 7
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-kna0jm35fjtpiba071t8
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.RUNNING
# Job status: JobStatus.RUNNING
# Job status: JobStatus.RUNNING
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'00': 1, '10': 4, '11': 5}
# Experiment with payload=2, gates=5005 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=3 and gates=5000
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 3347
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-4ebw0rcdq6jtdssdbmup
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job timed out after 5 minutes
# Experiment with payload=3, gates=5000 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=3 and gates=5001
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 3349
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-jgiwugyb3xvgg6x7kv3o
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.RUNNING
# Job status: JobStatus.RUNNING
# Job status: JobStatus.RUNNING
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 2, '010': 4, '101': 1, '111': 3}
# Experiment with payload=3, gates=5001 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=3 and gates=5002
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 3349
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-zy4yclbthf8zqf54g2k4
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 5, '001': 1, '010': 1, '100': 1, '110': 1, '111': 1}
# Experiment with payload=3, gates=5002 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=3 and gates=5003
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 3349
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-mdi2u987xml21144nzc7
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 4, '010': 2, '100': 1, '111': 3}
# Experiment with payload=3, gates=5003 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=3 and gates=5004
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 3351
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ze5dnvx1t5bwgj511wck
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 2, '001': 1, '100': 1, '110': 1, '111': 5}
# Experiment with payload=3, gates=5004 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=3 and gates=5005
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 3351
# Original circuit width: 9
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-u9rhdf60bs5vo1gqcyii
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'000': 4, '001': 1, '100': 3, '111': 2}
# Experiment with payload=3, gates=5005 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=4 and gates=5000
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 2517
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-ls5qjjwnbckslum272kw
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0000': 1, '0001': 3, '0010': 2, '1000': 1, '1001': 2, '1100': 1}
# Experiment with payload=4, gates=5000 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=4 and gates=5001
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 2517
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-f2zpd89ydk3o05ywuwhu
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job timed out after 5 minutes
# Experiment with payload=4, gates=5001 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=4 and gates=5002
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 2517
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-2yx2rqo1gcr01djxlyhf
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0000': 1, '0001': 1, '0010': 3, '1001': 1, '1100': 1, '1101': 1, '1110': 2}
# Experiment with payload=4, gates=5002 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=4 and gates=5003
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 2517
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-fv4cv4l9zgjb01pkx4c8
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job timed out after 5 minutes
# Experiment with payload=4, gates=5003 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=4 and gates=5004
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 2519
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-3xo705p07tohzgykn1jz
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.COMPLETED
# Job completed! Results: {'0000': 2, '0001': 1, '0010': 1, '0100': 2, '0110': 2, '1010': 1, '1100': 1}
# Experiment with payload=4, gates=5004 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#
# Running experiment with payload_size=4 and gates=5005
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 2519
# Original circuit width: 11
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-uyce94jp1jkvrrdv978d
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job status: JobStatus.QUEUED
# Job timed out after 5 minutes
# Experiment with payload=4, gates=5005 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250902_171809.csv
#        status  circuit_depth  circuit_width  circuit_size  \
# 0   completed          10011              5         10011
# 1   completed          10013              5         10013
# 2   completed          10015              5         10015
# 3   completed          10017              5         10017
# 4   completed          10019              5         10019
# 5   completed          10021              5         10021
# 6   completed           5013              7         10016
# 7   completed           5013              7         10018
# 8   completed           5015              7         10020
# 9   completed           5015              7         10022
# 10  completed           5017              7         10024
# 11  completed           5017              7         10026
# 12  completed           3347              9         10021
# 13  completed           3349              9         10023
# 14  completed           3349              9         10025
# 15  completed           3349              9         10027
# 16  completed           3351              9         10029
# 17  completed           3351              9         10031
# 18  completed           2517             11         10026
# 19  completed           2517             11         10028
# 20  completed           2517             11         10030
# 21  completed           2517             11         10032
# 22  completed           2519             11         10034
# 23  completed           2519             11         10036
#
#                                     circuit_count_ops  num_qubits  num_clbits  \
# 0   {"z": 1756, "y": 1744, "s": 1645, "sdg": 1645,...           4           1
# 1   {"z": 1696, "sdg": 1668, "s": 1668, "x": 1662,...           4           1
# 2   {"x": 1694, "sdg": 1693, "s": 1693, "y": 1670,...           4           1
# 3   {"x": 1804, "y": 1680, "z": 1664, "s": 1643, "...           4           1
# 4   {"s": 1740, "sdg": 1740, "h": 1698, "x": 1686,...           4           1
# 5   {"z": 1730, "x": 1670, "s": 1667, "sdg": 1667,...           4           1
# 6   {"y": 1688, "h": 1678, "sdg": 1673, "s": 1673,...           5           2
# 7   {"y": 1726, "h": 1698, "sdg": 1673, "s": 1673,...           5           2
# 8   {"y": 1700, "x": 1678, "s": 1678, "sdg": 1678,...           5           2
# 9   {"z": 1728, "h": 1704, "y": 1670, "x": 1658, "...           5           2
# 10  {"x": 1692, "s": 1688, "sdg": 1688, "y": 1652,...           5           2
# 11  {"x": 1740, "h": 1700, "z": 1650, "s": 1649, "...           5           2
# 12  {"y": 1750, "z": 1716, "x": 1644, "h": 1638, "...           6           3
# 13  {"h": 1754, "y": 1694, "s": 1678, "sdg": 1678,...           6           3
# 14  {"x": 1738, "h": 1698, "s": 1682, "sdg": 1682,...           6           3
# 15  {"x": 1778, "y": 1682, "sdg": 1661, "s": 1661,...           6           3
# 16  {"h": 1752, "s": 1726, "sdg": 1726, "y": 1664,...           6           3
# 17  {"h": 1810, "x": 1718, "z": 1678, "s": 1604, "...           6           3
# 18  {"h": 1774, "z": 1722, "s": 1667, "sdg": 1667,...           7           4
# 19  {"x": 1784, "z": 1726, "y": 1674, "sdg": 1646,...           7           4
# 20  {"z": 1724, "s": 1692, "sdg": 1692, "x": 1676,...           7           4
# 21  {"x": 1728, "y": 1694, "s": 1676, "sdg": 1676,...           7           4
# 22  {"z": 1720, "y": 1704, "x": 1686, "h": 1642, "...           7           4
# 23  {"h": 1752, "y": 1712, "z": 1668, "sdg": 1634,...           7           4
#
#     num_ancillas  num_parameters  has_calibrations  has_layout  payload_size  \
# 0              0               0             False       False             1
# 1              0               0             False       False             1
# 2              0               0             False       False             1
# 3              0               0             False       False             1
# 4              0               0             False       False             1
# 5              0               0             False       False             1
# 6              0               0             False       False             2
# 7              0               0             False       False             2
# 8              0               0             False       False             2
# 9              0               0             False       False             2
# 10             0               0             False       False             2
# 11             0               0             False       False             2
# 12             0               0             False       False             3
# 13             0               0             False       False             3
# 14             0               0             False       False             3
# 15             0               0             False       False             3
# 16             0               0             False       False             3
# 17             0               0             False       False             3
# 18             0               0             False       False             4
# 19             0               0             False       False             4
# 20             0               0             False       False             4
# 21             0               0             False       False             4
# 22             0               0             False       False             4
# 23             0               0             False       False             4
#
#     num_gates execution_type        experiment_type  \
# 0        5000         qbraid  dynamic_payload_gates
# 1        5001         qbraid  dynamic_payload_gates
# 2        5002         qbraid  dynamic_payload_gates
# 3        5003         qbraid  dynamic_payload_gates
# 4        5004         qbraid  dynamic_payload_gates
# 5        5005         qbraid  dynamic_payload_gates
# 6        5000         qbraid  dynamic_payload_gates
# 7        5001         qbraid  dynamic_payload_gates
# 8        5002         qbraid  dynamic_payload_gates
# 9        5003         qbraid  dynamic_payload_gates
# 10       5004         qbraid  dynamic_payload_gates
# 11       5005         qbraid  dynamic_payload_gates
# 12       5000     simulation  dynamic_payload_gates
# 13       5001         qbraid  dynamic_payload_gates
# 14       5002         qbraid  dynamic_payload_gates
# 15       5003         qbraid  dynamic_payload_gates
# 16       5004         qbraid  dynamic_payload_gates
# 17       5005         qbraid  dynamic_payload_gates
# 18       5000         qbraid  dynamic_payload_gates
# 19       5001     simulation  dynamic_payload_gates
# 20       5002         qbraid  dynamic_payload_gates
# 21       5003     simulation  dynamic_payload_gates
# 22       5004         qbraid  dynamic_payload_gates
# 23       5005     simulation  dynamic_payload_gates
#
#                                                counts  success_rate  \
# 0                                    {"0": 7, "1": 3}           0.7
# 1                                    {"0": 6, "1": 4}           0.6
# 2                                    {"0": 9, "1": 1}           0.9
# 3                                    {"0": 7, "1": 3}           0.7
# 4                                    {"0": 7, "1": 3}           0.7
# 5                                    {"0": 5, "1": 5}           0.5
# 6                {"00": 3, "01": 3, "10": 2, "11": 2}           0.3
# 7                         {"00": 4, "01": 2, "11": 4}           0.4
# 8                {"00": 1, "01": 4, "10": 3, "11": 2}           0.1
# 9                {"00": 4, "01": 2, "10": 2, "11": 2}           0.4
# 10                        {"00": 4, "10": 1, "11": 5}           0.4
# 11                        {"00": 1, "10": 4, "11": 5}           0.1
# 12                                      {"000": 1024}           1.0
# 13           {"000": 2, "010": 4, "101": 1, "111": 3}           0.2
# 14  {"000": 5, "001": 1, "010": 1, "100": 1, "110"...           0.5
# 15           {"000": 4, "010": 2, "100": 1, "111": 3}           0.4
# 16  {"000": 2, "001": 1, "100": 1, "110": 1, "111"...           0.2
# 17           {"000": 4, "001": 1, "100": 3, "111": 2}           0.4
# 18  {"0000": 1, "0001": 3, "0010": 2, "1000": 1, "...           0.1
# 19                                     {"0000": 1024}           1.0
# 20  {"0000": 1, "0001": 1, "0010": 3, "1001": 1, "...           0.1
# 21                                     {"0000": 1024}           1.0
# 22  {"0000": 2, "0001": 1, "0010": 1, "0100": 2, "...           0.2
# 23                                     {"0000": 1024}           1.0
#
#                                                job_id
# 0   rigetti_ankaa_3-cmarquezb-qjob-cxvbh3fgyd5vygh...
# 1   rigetti_ankaa_3-cmarquezb-qjob-gmrgwe1h1pbcl13...
# 2   rigetti_ankaa_3-cmarquezb-qjob-qglvuayd0ypztkb...
# 3   rigetti_ankaa_3-cmarquezb-qjob-nep0inmtv9j75ke...
# 4   rigetti_ankaa_3-cmarquezb-qjob-4qsjqhqxe908g3z...
# 5   rigetti_ankaa_3-cmarquezb-qjob-8wwaigvz7sh2eyt...
# 6   rigetti_ankaa_3-cmarquezb-qjob-ypt5yocg2pu47e7...
# 7   rigetti_ankaa_3-cmarquezb-qjob-43hb5pygn6fq2hy...
# 8   rigetti_ankaa_3-cmarquezb-qjob-9a0h1byvntacy40...
# 9   rigetti_ankaa_3-cmarquezb-qjob-7qbzazcw78r1qvi...
# 10  rigetti_ankaa_3-cmarquezb-qjob-ipnecdsiw401nft...
# 11  rigetti_ankaa_3-cmarquezb-qjob-kna0jm35fjtpiba...
# 12                                                NaN
# 13  rigetti_ankaa_3-cmarquezb-qjob-jgiwugyb3xvgg6x...
# 14  rigetti_ankaa_3-cmarquezb-qjob-zy4yclbthf8zqf5...
# 15  rigetti_ankaa_3-cmarquezb-qjob-mdi2u987xml2114...
# 16  rigetti_ankaa_3-cmarquezb-qjob-ze5dnvx1t5bwgj5...
# 17  rigetti_ankaa_3-cmarquezb-qjob-u9rhdf60bs5vo1g...
# 18  rigetti_ankaa_3-cmarquezb-qjob-ls5qjjwnbckslum...
# 19                                                NaN
# 20  rigetti_ankaa_3-cmarquezb-qjob-2yx2rqo1gcr01dj...
# 21                                                NaN
# 22  rigetti_ankaa_3-cmarquezb-qjob-3xo705p07tohzgy...
# 23                                                NaN
