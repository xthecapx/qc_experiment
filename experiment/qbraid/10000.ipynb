# %%
# %load_ext autoreload
# %autoreload 2

# %%
QBRAID_API_KEY='60bnwpwdgqy'

import os

# Set an environment variable
os.environ['QBRAID_API_KEY'] = QBRAID_API_KEY

# Verify it was set
print(os.environ.get('QBRAID_API_KEY'))

from teleportation_validator_qbraid import Experiments
experiments = Experiments()
# Out:
# 60bnwpwdgqy

# %%
experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(10000, 10005),
    use_qbraid=True
)
# Out:
# Running experiment with payload_size=1 and gates=10000
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 20011
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-dkdc3u0cn1jdscbqqigj
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job timed out after 5 minutes
# Job timeout - storing job_id for later retrieval: rigetti_ankaa_3-cmarquezb-qjob-dkdc3u0cn1jdscbqqigj
# Experiment with payload=1, gates=10000 completed with status: timeout
# Results exported to experiment_results_dynamic_1-4_10000-10005_20250903_150122.csv
#
# Running experiment with payload_size=1 and gates=10001
# QbraidDevice('rigetti_ankaa_3')
# Original circuit depth: 20013
# Original circuit width: 5
# Device capabilities: QbraidDevice('rigetti_ankaa_3')
# Transpiled circuit type: <class 'braket.circuits.circuit.Circuit'>
# Device status: DeviceStatus.ONLINE
# Job submitted with ID: rigetti_ankaa_3-cmarquezb-qjob-kecunoczkn5go7xt7pzd
# Waiting for job to complete...
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# Job status: JobStatus.INITIALIZING
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 experiments.run_dynamic_payload_gates(
#       2     payload_range=(1, 4),
#       3     gates_range=(10000, 10005),
#       4     use_qbraid=True
#       5 )
#
# File ~/work/qbraid/teleportation_validator_qbraid.py:718, in Experiments.run_dynamic_payload_gates(self, payload_range, gates_range, use_qbraid, show_circuit)
#     716 if use_qbraid:
#     717     try:
# --> 718         qbraid_result = validator.run_qbraid()
#     719         if qbraid_result["status"] == "completed":
#     720             execution_type = "qbraid"
#
# File ~/work/qbraid/teleportation_validator_qbraid.py:398, in TeleportationValidator.run_qbraid(self)
#     395     else:
#     396         print(f"Unknown status: {status} ({status_str})")
# --> 398     time.sleep(5)  # Wait 5 seconds before checking again
#     400 # Timeout case - still return job_info with job_id
#     401 print("Job timed out after 5 minutes")
#
# KeyboardInterrupt:
