# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# $7.73 usd

# %%
import qiskit; 
print('Qiskit version:', qiskit.__version__)
# Out:
# Qiskit version: 1.4.4

# %%
import os
os.environ['AWS_ACCESS_KEY_ID'] = 'xxxxx'
os.environ['AWS_SECRET_ACCESS_KEY'] = 'xxxxxx'

# %%
from teleportation_validator_qbraid import Experiments
experiments = Experiments()
experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(10000, 10005),
    use_aws=True,
    aws_device_id="Ankaa-3"
)
# Out:
# Running experiment with payload_size=1 and gates=10000
# Setting AWS region to: us-west-1
# Setting up AWS Braket provider...
# Getting device: Ankaa-3
# Device obtained: BraketBackend[Ankaa-3]
# Original circuit depth: 20005
# Original circuit width: 5
# Device capabilities: BraketBackend[Ankaa-3]
# 🚀 Submitting circuit to AWS Braket device: Ankaa-3
# 📊 Shots: 10
# ❌ Error running on AWS Braket: An error occurred (ValidationException) when calling the CreateQuantumTask operation: Validation failed for one or more programs. See 'programSetValidationFailures' for details. First failure:
# {'programIndex': 0, 'errors': ['The total number of gates in the circuit is higher than 20,000. It is currently 20,010.']}
# Rerun the task and catch the exception for more details
# ...

# %%
from teleportation_validator_qbraid import TeleportationValidator

validator = TeleportationValidator(payload_size=1, gates=1, use_barriers=False)

# Retrieve the job using the ARN (job ID) you got when submitting
job_id = "arn:aws:braket:us-west-1:265556963705:quantum-task/92f120d0-9270-4234-9ee0-71b39987cfb7"
result = validator.retrieve_aws_job(job_id)
# Out:
# Retrieving AWS job: arn:aws:braket:us-west-1:265556963705:quantum-task/92f120d0-9270-4234-9ee0-71b39987cfb7
# Job status: JobStatus.DONE

# %%
result
# Out:
# {'status': 'jobstatus.done',
#  'job_id': 'arn:aws:braket:us-west-1:265556963705:quantum-task/92f120d0-9270-4234-9ee0-71b39987cfb7'}

# %%
from qiskit_braket_provider import BraketProvider
provider = BraketProvider()
rigetti = provider.get_backend("Ankaa-3")

# %%
job = rigetti.retrieve_job(job_id)

# %%
entries = job._tasks[0].result()

# %%
entries[0].entries[0].counts
# Out:
# Counter({'0': 7, '1': 3})

# %%
c_program = entries[0].additional_metadata.rigettiMetadata.compiledProgram
program = original_program = entries[0].entries[0].program

# %%
program
# Out:
# 'OPENQASM 3.0;\nbit[1] b;\nqubit[4] q;\nh q[0];\ncnot q[0], q[1];\ny q[0];\nh q[2];\ncnot q[2], q[3];\ncnot q[1], q[2];\nh q[1];\ncnot q[2], q[3];\ncz q[1], q[3];\ny q[0];\ncnot q[0], q[3];\nh q[0];\nb[0] = measure q[0];'

# %%
entries[0]
# Out:
# CompositeEntry(entries=[MeasuredEntry(measurements=array([[1],
#        [0],
#        [0],
#        [0],
#        [0],
#        [0],
#        [1],
#        [1],
#        [0],
# ...
