# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append('./results')

from plot_experiment_results import plot_experiment_results

# %% [markdown]
# # Graph

# %% [markdown]
# ## Payload 1:5, Gates 200:205

# %%
from results_1_5_200_205 import results_1_5_200_205

plot_experiment_results(results_1_5_200_205)

# %% [markdown]
# ## Payload 1:4, Gates 500:505

# %%
from results_1_4_500_505 import results_1_4_500_505

plot_experiment_results(results_1_4_500_505)

# %% [markdown]
# ## Payload 1:4, Gates 1000:1005

# %%
from results_1_4_1000_1005 import results_1_4_1000_1005

plot_experiment_results(results_1_4_1000_1005)

# %% [markdown]
# ## Payload 1:4, Gates 1500:1505

# %%
from results_1_4_1500_1505 import results_1_4_1500_1505

plot_experiment_results(results_1_4_1500_1505)

# %% [markdown]
# ## Payload 1:4, Gates 2000:2005

# %%
from results_1_4_2000_2005 import results_1_4_2000_2005

plot_experiment_results(results_1_4_2000_2005)

# %% [markdown]
# # Experiment analysis

# %%
from experiment_analysis import create_experiment_dataframe, plot_success_rates

# %%
df = create_experiment_dataframe()
    
# Display basic information about the dataset
print("\nDataFrame Info:")
print(df.info())

print("\nPayload size distribution:")
print(df.groupby('payload_size').size())

# Show counts distribution for each payload size
print("\nCounts distribution by payload size:")
for size in sorted(df['payload_size'].unique()):
    subset = df[df['payload_size'] == size]
    print(f"\nPayload size {size}:")
    print(f"Average counts_zeros: {subset['counts_zeros'].mean():.2f}")
    print(f"Average counts_ones: {subset['counts_ones'].mean():.2f}")

# Create all three versions of the plot
# print("\nRegression Statistics (Linear Scale):")
# print("-"*50)
# regression_stats = plot_success_rates(df, use_log_x=False, use_log_y=False)
# for stats in regression_stats:
#     print(f"\nPayload Size {stats['payload_size']}:")
#     print(f"Slope: {stats['slope']:.2e} ± {stats['std_err']:.2e}")
#     print(f"Intercept: {stats['intercept']:.2f}")
#     print(f"R²: {stats['r_squared']:.3f}")
#     print(f"p-value: {stats['p_value']:.2e}")
#     print("-"*50)


print("\nRegression Statistics (Log X Scale):")
print("-"*50)
regression_stats_logx = plot_success_rates(df, use_log_x=True, use_log_y=False)
for stats in regression_stats_logx:
    print(f"\nPayload Size {stats['payload_size']}:")
    print(f"Slope: {stats['slope']:.2e} ± {stats['std_err']:.2e}")
    print(f"Intercept: {stats['intercept']:.2f}")
    print(f"R²: {stats['r_squared']:.3f}")
    print(f"p-value: {stats['p_value']:.2e}")
    print("-"*50)

# print("\nRegression Statistics (Log-Log Scale):")
# print("-"*50)
# regression_stats_logxy = plot_success_rates(df, use_log_x=True, use_log_y=True)
# for stats in regression_stats_logxy:
#     print(f"\nPayload Size {stats['payload_size']}:")
#     print(f"Slope: {stats['slope']:.2e} ± {stats['std_err']:.2e}")
#     print(f"Intercept: {stats['intercept']:.2f}")
#     print(f"R²: {stats['r_squared']:.3f}")
#     print(f"p-value: {stats['p_value']:.2e}")
#     print("-"*50)
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 624 entries, cz532rbh0kc00088zr40 to cz6rj7810wx0008by2p0
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   status                  624 non-null    object
#  1   circuit_depth           624 non-null    int64
#  2   circuit_width           624 non-null    int64
#  3   circuit_size            624 non-null    int64
#  4   circuit_count_ops       624 non-null    object
#  5   num_qubits              252 non-null    float64
#  6   num_clbits              252 non-null    float64
#  7   num_ancillas            252 non-null    float64
#  8   num_parameters          252 non-null    float64
#  9   has_calibrations        252 non-null    object
#  10  has_layout              252 non-null    object
#  11  payload_size            624 non-null    int64
#  12  num_gates               624 non-null    int64
#  13  execution_type          624 non-null    object
#  14  experiment_type         624 non-null    object
#  15  counts                  620 non-null    object
#  16  success_rate            620 non-null    float64
#  17  ibm_backend             616 non-null    object
#  18  counts_zeros            624 non-null    int64
#  19  counts_ones             624 non-null    int64
#  20  job_duration            510 non-null    float64
#  21  job_quantum_duration    510 non-null    float64
#  22  job_status              510 non-null    object
#  23  job_success_rate        510 non-null    float64
#  24  job_created             510 non-null    object
#  25  job_finished            510 non-null    object
#  26  job_running             510 non-null    object
#  27  job_execution_spans     510 non-null    object
#  28  job_execution_duration  510 non-null    float64
#  29  duration                0 non-null      float64
# dtypes: float64(10), int64(7), object(13)
# memory usage: 151.1+ KB
# None
#
# Payload size distribution:
# payload_size
# 1    147
# 2    150
# 3    153
# 4    156
# 5     18
# dtype: int64
#
# Counts distribution by payload size:
#
# Payload size 1:
# Average counts_zeros: 2081.46
# Average counts_ones: 2014.54
#
# Payload size 2:
# Average counts_zeros: 1183.75
# Average counts_ones: 2912.25
#
# Payload size 3:
# Average counts_zeros: 525.46
# Average counts_ones: 3463.45
#
# Payload size 4:
# Average counts_zeros: 263.75
# Average counts_ones: 3832.25
#
# Payload size 5:
# Average counts_zeros: 132.33
# Average counts_ones: 3944.17
#
# Regression Statistics (Log X Scale):
# --------------------------------------------------
#
# Skipping payload size(s) [5] due to insufficient data for reliable analysis
#   Payload Size 5: 18 data points, gate range: 200-205
#
# Debug info for Payload Size 3:
#   Number of raw data points: 153
#   Unique gate counts: [200, 201, 202, 204, 205, 500, 501, 502, 503, 504, 505, 1000, 1001, 1002, 1003, 1004, 1005, 1500, 1501, 1502, 1503, 1504, 1505, 2000, 2001, 2002, 2003, 2004, 2005, 3000, 3001, 3002, 3003, 3004, 3005, 5000, 5001, 5002, 5003, 5004, 5005, 10000, 10001, 10002, 10003, 10004, 10005, 20000, 20001, 20002, 20003, 20004, 20005]
#   Grouped data points (before cleaning): 53
#   Grouped data points (after cleaning): 52
#   NaN values removed: 1
#   X values (gates): [  200   201   202   204   205   500   501   502   503   504   505  1000
#   1001  1002  1003  1004  1005  1500  1501  1502  1503  1504  1505  2000
#   2001  2002  2003  2004  2005  3000  3001  3002  3003  3004  3005  5000
#   5001  5002  5003  5004  5005 10000 10001 10002 10004 10005 20000 20001
#  20002 20003 20004 20005]
#   Y values (success rates): [18.38378906 20.33691406 14.67285156 20.75195312 13.37890625 19.43359375
#  10.13183594 10.71777344  8.984375   11.59667969 14.57519531 15.86914062
#  12.81738281 11.96289062 15.11230469 12.47558594 10.7421875  11.79199219
#  13.50097656 11.71875    11.74316406  9.25292969 11.93847656 10.18066406
#  12.18261719 13.62304688 15.72265625 12.23144531 13.64746094 11.45019531
#  12.28027344 13.62304688  9.93652344 24.24316406 13.50097656 13.42773438
#  14.99023438 12.32910156 12.54882812 13.98925781 13.98925781 11.69433594
#  12.28027344 11.76757812 12.86621094 11.96289062 12.6953125  10.03417969
#   4.56542969 11.15722656  9.5703125   3.73535156]
#   X range: 19805
#   X variance: 37632165.59282544
#   Y variance: 11.706240254746387
#
# Payload Size 1:
# Slope: -3.23e+00 ± 1.44e+00
# Intercept: 61.73
# R²: 0.090
# p-value: 2.93e-02
# --------------------------------------------------
#
# Payload Size 2:
# Slope: -5.32e+00 ± 1.47e+00
# Intercept: 46.40
# R²: 0.200
# p-value: 6.92e-04
# --------------------------------------------------
#
# Payload Size 3:
# Slope: -2.71e+00 ± 7.48e-01
# Intercept: 21.88
# R²: 0.208
# p-value: 6.85e-04
# --------------------------------------------------
#
# Payload Size 4:
# Slope: -2.22e-01 ± 2.71e-01
# Intercept: 7.15
# R²: 0.013
# p-value: 4.16e-01
# --------------------------------------------------

# %%
from experiment_analysis import plot_success_rates

# %% [markdown]
# # circuit complexity

# %%
from experiment_analysis import plot_circuit_complexity, create_experiment_dataframe

df = create_experiment_dataframe()
print("\nGenerating Circuit Complexity Analysis Plots...")
plot_circuit_complexity(df)
print("Circuit complexity plots saved as 'circuit_complexity_2d.png' and 'circuit_complexity_3d.png'")
# Out:
# Generating Circuit Complexity Analysis Plots...
# Circuit complexity plots saved as 'circuit_complexity_2d.png' and 'circuit_complexity_3d.png'

# %% [markdown]
# # Error

# %%
from experiment_analysis import plot_error_analysis, create_experiment_dataframe

df = create_experiment_dataframe()

print("\nGenerating Error Analysis Plots...")
plot_error_analysis(df)
print("Error analysis plots saved as 'error_analysis.png'")
# Out:
# Generating Error Analysis Plots...
# Error analysis plots saved as 'error_analysis.png'

# %%
from experiment_analysis import plot_error_analysis, plot_cap_scores

df = create_experiment_dataframe()

print("\nGenerating Cap-score Analysis Plot...")
plot_cap_scores(df)
print("Cap-score analysis plot saved as 'cap_scores_analysis.png'")
# Out:
# Generating Cap-score Analysis Plot...
# Cap-score analysis plot saved as 'cap_scores_analysis.png'
