# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append('./results')

# %%
from teleportation_validator import Experiments
from results_1_5_200_205 import results_1_5_200_205

experiments = Experiments()
updated_df = experiments.create_table_from_results(results_list=results_1_5_200_205)
# Out:
# Updated job cytd4gj4raf0008efamg information
# Updated job cytd4rb4raf0008efapg information
# Updated job cytd504q5bwg0083jjeg information
# Updated job cytd56mq5bwg0083jjf0 information
# Updated job cytd5ed78z600082knrg information
# Updated job cytd5pe78z600082knv0 information
# Updated job cytd5xqy2gd000882qx0 information
# Updated job cytd65g4raf0008efav0 information
# Updated job cytd6dhq5bwg0083jjmg information
# Updated job cytd6m24raf0008efax0 information
# Updated job cytd6w378z600082knx0 information
# Updated job cytd73w4raf0008efaz0 information
# Updated job cytd7bn38jq0008xtfz0 information
# Updated job cytd7j678z600082knzg information
# Updated job cytd7r778z600082kp10 information
# Updated job cytdcx3jj6dg008g0wag information
# Updated job cytdd3c78z600082kpf0 information
# Updated job cytddb5jj6dg008g0wb0 information
# Updated job cytddhejj6dg008g0wbg information
# Updated job cytddrz78z600082kpj0 information
# Updated job cytde0ry2gd000882rj0 information
# ...

# %%
from results_1_4_500_505 import results_1_4_500_505

experiments = Experiments()
updated_df = experiments.create_table_from_results(results_list=results_1_4_500_505)
# Out:
# Updated job cyv0974q5bwg0083nxqg information
# Updated job cyv09f578z600082q1pg information
# Updated job cyv0emay2gd0008864eg information
# Updated job cyv0exb4raf0008ejsv0 information
# Updated job cyv0f6438jq0008xxx7g information
# Updated job cyv0fdnq5bwg0083nygg information
# Updated job cyv0fpp38jq0008xxxbg information
# Updated job cyv0fzq38jq0008xxxcg information
# Updated job cyv0g81q5bwg0083nyp0 information
# Updated job cyv0gga78z600082q2hg information
# Updated job cyv0grv78z600082q2j0 information
# Updated job cyv0h2m38jq0008xxxmg information
# Updated job cyv0hbd78z600082q2qg information
# Updated job cyv0hm6y2gd00088652g information
# Updated job cyv0hvq4raf0008ejt90 information
# Updated job cyv0j484raf0008ejt9g information
# Updated job cyv0jd9jj6dg008g49t0 information
# Updated job cyv0jpa4raf0008ejtag information
# Updated job cyv0jzvjj6dg008g49tg information
# Updated job cyv0nsq38jq0008xxxv0 information
# Updated job cyv0p2ry2gd0008865f0 information
# ...

# %%
from results_1_5_200_205 import results_1_5_200_205
from results_1_4_500_505 import results_1_4_500_505
from results_1_4_1000_1005 import results_1_4_1000_1005
from results_1_4_1500_1505 import results_1_4_1500_1505
from results_1_4_2000_2005 import results_1_4_2000_2005

experiments = Experiments()
experiments.create_table_from_results(results_list=results_1_5_200_205)
experiments.create_table_from_results(results_list=results_1_4_500_505)
experiments.create_table_from_results(results_list=results_1_4_1000_1005)
experiments.create_table_from_results(results_list=results_1_4_1500_1505)
experiments.create_table_from_results(results_list=results_1_4_2000_2005)
# Out:
# Updated job cytd4gj4raf0008efamg information
# Updated job cytd4rb4raf0008efapg information
# Updated job cytd504q5bwg0083jjeg information
# Updated job cytd56mq5bwg0083jjf0 information
# Updated job cytd5ed78z600082knrg information
# Updated job cytd5pe78z600082knv0 information
# Updated job cytd5xqy2gd000882qx0 information
# Updated job cytd65g4raf0008efav0 information
# Updated job cytd6dhq5bwg0083jjmg information
# Updated job cytd6m24raf0008efax0 information
# Updated job cytd6w378z600082knx0 information
# Updated job cytd73w4raf0008efaz0 information
# Updated job cytd7bn38jq0008xtfz0 information
# Updated job cytd7j678z600082knzg information
# Updated job cytd7r778z600082kp10 information
# Updated job cytdcx3jj6dg008g0wag information
# Updated job cytdd3c78z600082kpf0 information
# Updated job cytddb5jj6dg008g0wb0 information
# Updated job cytddhejj6dg008g0wbg information
# Updated job cytddrz78z600082kpj0 information
# Updated job cytde0ry2gd000882rj0 information
# ...
