# %%
# %load_ext autoreload
# %autoreload 2

# %%
ids_1_2 = [
    'cz51f4ch0kc00088zfng',
    'cz51g2rp6030008chj40',
    'cz51gjtp6030008chj70',
    'cz51hn610wx0008bjc80',
    'cz51qenkvm9g008g9syg',
    'cz51sxz1xvhg008ea9m0',
    'cz51qxfh0kc00088zgjg',
    'cz51rj2h0kc00088zgr0',
    'cz51rs339f40008sfpr0',
    'cz51s24h0kc00088zh30',
    'cz51snp10wx0008bjdyg',
    'cz51sxz1xvhg008ea9m0',
]

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(10000, 10005),
    run_on_ibm=True,
    show_circuit=False
)
# Out:
# Running experiment with payload_size=1 and gates=10000
# ibm_brisbane
# 6
# >>> Job ID: cz51f4ch0kc00088zfng
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2093, '0': 2003}
# Experiment with payload=1, gates=10000 completed with status: completed
#
# Running experiment with payload_size=1 and gates=10001
# ibm_brisbane
# 6
# >>> Job ID: cz51g2rp6030008chj40
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# ...

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(3, 4),
    gates_range=(10000, 10005),
    run_on_ibm=True,
    show_circuit=False
)
# Out:
# Running experiment with payload_size=3 and gates=10000
# ibm_brisbane
# 5
# >>> Job ID: cz523h610wx0008bjg30
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# ...

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(1, 2),
    gates_range=(10000, 10005),
    run_on_ibm=True,
    show_circuit=False
)
# Out:
# Running experiment with payload_size=1 and gates=10000
# ibm_brisbane
# 5
# >>> Job ID: cz532rbh0kc00088zr40
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# ...

# %%
from teleportation_validator import Experiments

experiments = Experiments()
updated_df = experiments.update_table_with_job_info('experiment_results_dynamic_1-2_10000-10005_20250306_234959.csv')
# Out:
# Updated job cz532rbh0kc00088zr40 information
# Updated job cz534d91xvhg008eag90 information
# Updated job cz535pep6030008chv0g information
# Updated job cz535xq39f40008sfye0 information
# Updated job cz53660p6030008chv5g information
# Updated job cz536yvp6030008chv8g information
# Updated job cz537py10wx0008bjn20 information
# Updated job cz537xz39f40008sfym0 information
# Updated job cz53870kvm9g008ga210 information
# Updated job cz538e139f40008sfypg information
# Updated job cz538na10wx0008bjn7g information
# Updated job cz5396mp6030008chvn0 information
# Updated job cz523h610wx0008bjg30 information
# Updated job cz525bnh0kc00088zkp0 information
# Updated job cz525m61xvhg008eabrg information
# Updated job cz52at3p6030008chpx0 information
# Updated job cz52b1wp6030008chpz0 information
# Updated job cz52bexkvm9g008g9y20 information
# Updated job cz52bp61xvhg008eacn0 information
# Updated job cz52bxf39f40008sftxg information
# Updated job cz52c481xvhg008eacr0 information
# ...
