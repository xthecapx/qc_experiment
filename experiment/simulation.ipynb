# %%
# %load_ext autoreload
# %autoreload 2

# %%
from teleportation_validator import TeleportationValidator
validator = TeleportationValidator(payload_size=1, gates=1, save_statevector=True, use_barriers=False)
display(validator.draw())
results = validator.run_simulation()
# Out:
# State vector after payload:
# $$0.6479840602 |0000\rangle+(0.2578362217 - 0.1167781681 i) |0001\rangle+(0.1707357032 + 0.225756456 i) |0010\rangle+(-0.5692765636 - 0.3095279251 i) |0011\rangle$$
# State vector before validation:
# $$0.3239920301 |0000\rangle+(0.1289181108 - 0.0583890841 i) |0001\rangle+0.3239920301 |0010\rangle+(0.1289181108 - 0.0583890841 i) |0011\rangle+0.3239920301 |0100\rangle+(0.1289181108 - 0.0583890841 i) |0101\rangle + \ldots +(-0.2846382818 - 0.1547639625 i) |1011\rangle+(0.0853678516 + 0.112878228 i) |1100\rangle+(-0.2846382818 - 0.1547639625 i) |1101\rangle+(0.0853678516 + 0.112878228 i) |1110\rangle+(-0.2846382818 - 0.1547639625 i) |1111\rangle$$
# State vector after validation:
# $$\frac{1}{2} |0000\rangle+\frac{1}{2} |0010\rangle+\frac{1}{2} |0100\rangle+\frac{1}{2} |0110\rangle$$
