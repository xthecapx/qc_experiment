# %%
# %load_ext autoreload
# %autoreload 2

# %%
from teleportation_validator import Experiments 

experiments = Experiments()
results = experiments.run_target_depth_experiment(min_experiments_per_depth=10)
# Out:
# Running experiments for target depth: 13 (10 combinations)
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#   Running experiment with payload_size=1, gates=1
#   Experiment completed with status: completed, target depth: 13, actual depth: 13
#
# Running experiments for target depth: 15 (10 combinations)
#   Running experiment with payload_size=1, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=2, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=1, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=2, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=1, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=2, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=1, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=2, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=1, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#   Running experiment with payload_size=2, gates=2
#   Experiment completed with status: completed, target depth: 15, actual depth: 15
#
# Running experiments for target depth: 17 (10 combinations)
#   Running experiment with payload_size=1, gates=3
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=2, gates=4
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=3, gates=3
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=1, gates=3
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=2, gates=4
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=3, gates=3
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=1, gates=3
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=2, gates=4
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=3, gates=3
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#   Running experiment with payload_size=1, gates=3
#   Experiment completed with status: completed, target depth: 17, actual depth: 17
#
# Running experiments for target depth: 19 (10 combinations)
#   Running experiment with payload_size=1, gates=4
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=2, gates=6
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=3, gates=6
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=4, gates=4
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=1, gates=4
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=2, gates=6
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=3, gates=6
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=4, gates=4
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=1, gates=4
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#   Running experiment with payload_size=2, gates=6
#   Experiment completed with status: completed, target depth: 19, actual depth: 19
#
# Running experiments for target depth: 21 (10 combinations)
#   Running experiment with payload_size=1, gates=5
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=2, gates=8
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=3, gates=9
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=4, gates=8
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=5, gates=5
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=1, gates=5
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=2, gates=8
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=3, gates=9
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=4, gates=8
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#   Running experiment with payload_size=5, gates=5
#   Experiment completed with status: completed, target depth: 21, actual depth: 21
#
# Running experiments for target depth: 23 (10 combinations)
#   Running experiment with payload_size=1, gates=6
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=2, gates=10
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=3, gates=12
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=4, gates=12
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=5, gates=10
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=1, gates=6
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=2, gates=10
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=3, gates=12
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=4, gates=12
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#   Running experiment with payload_size=5, gates=10
#   Experiment completed with status: completed, target depth: 23, actual depth: 23
#
# Running experiments for target depth: 25 (10 combinations)
#   Running experiment with payload_size=1, gates=7
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=2, gates=12
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=3, gates=15
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=4, gates=16
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=5, gates=15
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=1, gates=7
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=2, gates=12
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=3, gates=15
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=4, gates=16
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#   Running experiment with payload_size=5, gates=15
#   Experiment completed with status: completed, target depth: 25, actual depth: 25
#
# Running experiments for target depth: 27 (10 combinations)
#   Running experiment with payload_size=1, gates=8
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=2, gates=14
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=3, gates=18
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=4, gates=20
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=5, gates=20
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=1, gates=8
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=2, gates=14
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=3, gates=18
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=4, gates=20
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#   Running experiment with payload_size=5, gates=20
#   Experiment completed with status: completed, target depth: 27, actual depth: 27
#
# Running experiments for target depth: 29 (10 combinations)
#   Running experiment with payload_size=1, gates=9
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=2, gates=16
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=3, gates=21
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=4, gates=24
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=5, gates=25
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=1, gates=9
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=2, gates=16
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=3, gates=21
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=4, gates=24
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#   Running experiment with payload_size=5, gates=25
#   Experiment completed with status: completed, target depth: 29, actual depth: 29
#
# Running experiments for target depth: 31 (10 combinations)
#   Running experiment with payload_size=1, gates=10
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=2, gates=18
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=3, gates=24
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=4, gates=28
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=5, gates=30
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=1, gates=10
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=2, gates=18
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=3, gates=24
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=4, gates=28
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#   Running experiment with payload_size=5, gates=30
#   Experiment completed with status: completed, target depth: 31, actual depth: 31
#
# Running experiments for target depth: 33 (10 combinations)
#   Running experiment with payload_size=1, gates=11
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=2, gates=20
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=3, gates=27
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=4, gates=32
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=5, gates=35
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=1, gates=11
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=2, gates=20
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=3, gates=27
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=4, gates=32
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#   Running experiment with payload_size=5, gates=35
#   Experiment completed with status: completed, target depth: 33, actual depth: 33
#
# Running experiments for target depth: 35 (10 combinations)
#   Running experiment with payload_size=1, gates=12
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=2, gates=22
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=3, gates=30
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=4, gates=36
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=5, gates=40
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=1, gates=12
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=2, gates=22
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=3, gates=30
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=4, gates=36
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#   Running experiment with payload_size=5, gates=40
#   Experiment completed with status: completed, target depth: 35, actual depth: 35
#
# Running experiments for target depth: 37 (10 combinations)
#   Running experiment with payload_size=1, gates=13
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=2, gates=24
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=3, gates=33
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=4, gates=40
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=5, gates=45
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=1, gates=13
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=2, gates=24
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=3, gates=33
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=4, gates=40
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#   Running experiment with payload_size=5, gates=45
#   Experiment completed with status: completed, target depth: 37, actual depth: 37
#
# Running experiments for target depth: 39 (10 combinations)
#   Running experiment with payload_size=1, gates=14
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=2, gates=26
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=3, gates=36
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=4, gates=44
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=5, gates=50
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=1, gates=14
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=2, gates=26
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=3, gates=36
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=4, gates=44
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#   Running experiment with payload_size=5, gates=50
#   Experiment completed with status: completed, target depth: 39, actual depth: 39
#
# Running experiments for target depth: 41 (10 combinations)
#   Running experiment with payload_size=1, gates=15
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=2, gates=28
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=3, gates=39
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=4, gates=48
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=5, gates=55
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=1, gates=15
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=2, gates=28
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=3, gates=39
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=4, gates=48
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#   Running experiment with payload_size=5, gates=55
#   Experiment completed with status: completed, target depth: 41, actual depth: 41
#
# Running experiments for target depth: 43 (10 combinations)
#   Running experiment with payload_size=1, gates=16
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=2, gates=30
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=3, gates=42
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=4, gates=52
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=5, gates=60
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=1, gates=16
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=2, gates=30
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=3, gates=42
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=4, gates=52
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#   Running experiment with payload_size=5, gates=60
#   Experiment completed with status: completed, target depth: 43, actual depth: 43
#
# Running experiments for target depth: 45 (10 combinations)
#   Running experiment with payload_size=1, gates=17
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=2, gates=32
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=3, gates=45
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=4, gates=56
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=5, gates=65
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=1, gates=17
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=2, gates=32
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=3, gates=45
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=4, gates=56
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#   Running experiment with payload_size=5, gates=65
#   Experiment completed with status: completed, target depth: 45, actual depth: 45
#
# Running experiments for target depth: 47 (10 combinations)
#   Running experiment with payload_size=1, gates=18
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=2, gates=34
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=3, gates=48
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=4, gates=60
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=5, gates=70
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=1, gates=18
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=2, gates=34
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=3, gates=48
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=4, gates=60
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#   Running experiment with payload_size=5, gates=70
#   Experiment completed with status: completed, target depth: 47, actual depth: 47
#
# Running experiments for target depth: 49 (10 combinations)
#   Running experiment with payload_size=1, gates=19
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=2, gates=36
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=3, gates=51
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=4, gates=64
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=5, gates=75
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=1, gates=19
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=2, gates=36
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=3, gates=51
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=4, gates=64
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
#   Running experiment with payload_size=5, gates=75
#   Experiment completed with status: completed, target depth: 49, actual depth: 49
# Results exported to experiment_results_target_depth_20250309_140743.csv

# %%
from teleportation_validator import Experiments 

experiments = Experiments()
results = experiments.run_target_depth_experiment(min_experiments_per_depth=10, run_on_ibm=True)
# Out:
# Running experiments for target depth: 13 (10 combinations)
#   Running experiment with payload_size=1, gates=1
# ibm_kyiv
# 5
# >>> Job ID: cz6t1zz39f40008svksg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'1': 1972, '0': 2124}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_kyiv
# 4
# >>> Job ID: cz6t258p6030008cxdeg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1526, '0': 2570}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_brisbane
# 8
# >>> Job ID: cz6t2bsp6030008cxdfg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3529, '1': 567}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_brisbane
# 3
# >>> Job ID: cz6t35m39f40008svkxg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3551, '1': 545}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_brisbane
# 3
# >>> Job ID: cz6t3c539f40008svky0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3531, '1': 565}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_brisbane
# 3
# >>> Job ID: cz6t3jp10wx0008by8f0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1567, '1': 2529}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_brisbane
# 5
# >>> Job ID: cz6t4a9p6030008cxdn0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1663, '1': 2433}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_brisbane
# 3
# >>> Job ID: cz6t4h2h0kc00089bdc0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1687, '1': 2409}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_brisbane
# 3
# >>> Job ID: cz6t5dxp6030008cxdsg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2479, '0': 1617}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#   Running experiment with payload_size=1, gates=1
# ibm_brisbane
# 4
# >>> Job ID: cz6t70439f40008svm5g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'0': 1599, '1': 2497}
#   Experiment completed with status: completed, target depth: 13, actual depth: 8
#   WARNING: Actual depth 8 does not match target depth 13
#
# Running experiments for target depth: 15 (10 combinations)
#   Running experiment with payload_size=1, gates=2
# ibm_brisbane
# 3
# >>> Job ID: cz6t75m39f40008svm6g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'0': 3535, '1': 561}
#   Experiment completed with status: completed, target depth: 15, actual depth: 9
#   WARNING: Actual depth 9 does not match target depth 15
#   Running experiment with payload_size=2, gates=2
# ibm_brisbane
# 3
# >>> Job ID: cz6t7b539f40008svm7g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1183, '01': 362, '11': 2218, '10': 333}
#   Experiment completed with status: completed, target depth: 15, actual depth: 10
#   WARNING: Actual depth 10 does not match target depth 15
#   Running experiment with payload_size=1, gates=2
# ibm_brisbane
# 5
# >>> Job ID: cz6t88sp6030008cxe20
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1686, '1': 2410}
#   Experiment completed with status: completed, target depth: 15, actual depth: 9
#   WARNING: Actual depth 9 does not match target depth 15
#   Running experiment with payload_size=2, gates=2
# ibm_brisbane
# 3
# >>> Job ID: cz6t8fs10wx0008by8s0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10': 369, '11': 2402, '01': 482, '00': 843}
#   Experiment completed with status: completed, target depth: 15, actual depth: 10
#   WARNING: Actual depth 10 does not match target depth 15
#   Running experiment with payload_size=1, gates=2
# ibm_brisbane
# 3
# >>> Job ID: cz6t9cnp6030008cxe40
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'0': 1623, '1': 2473}
#   Experiment completed with status: completed, target depth: 15, actual depth: 9
#   WARNING: Actual depth 9 does not match target depth 15
#   Running experiment with payload_size=2, gates=2
# ibm_brisbane
# 5
# >>> Job ID: cz6t9hykvm9g008gnjhg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 387, '01': 360, '00': 3149, '10': 200}
#   Experiment completed with status: completed, target depth: 15, actual depth: 10
#   WARNING: Actual depth 10 does not match target depth 15
#   Running experiment with payload_size=1, gates=2
# ibm_brisbane
# 5
# >>> Job ID: cz6t9t7h0kc00089bds0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3584, '1': 512}
#   Experiment completed with status: completed, target depth: 15, actual depth: 9
#   WARNING: Actual depth 9 does not match target depth 15
#   Running experiment with payload_size=2, gates=2
# ibm_brisbane
# 5
# >>> Job ID: cz6tag2h0kc00089bdy0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10': 218, '00': 3005, '01': 416, '11': 457}
#   Experiment completed with status: completed, target depth: 15, actual depth: 10
#   WARNING: Actual depth 10 does not match target depth 15
#   Running experiment with payload_size=1, gates=2
# ibm_brisbane
# 5
# >>> Job ID: cz6tapjh0kc00089bdzg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1648, '1': 2448}
#   Experiment completed with status: completed, target depth: 15, actual depth: 9
#   WARNING: Actual depth 9 does not match target depth 15
#   Running experiment with payload_size=2, gates=2
# ibm_brisbane
# 5
# >>> Job ID: cz6taxb39f40008svmmg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 366, '00': 3115, '10': 388, '01': 227}
#   Experiment completed with status: completed, target depth: 15, actual depth: 10
#   WARNING: Actual depth 10 does not match target depth 15
#
# Running experiments for target depth: 17 (10 combinations)
#   Running experiment with payload_size=1, gates=3
# ibm_brisbane
# 4
# >>> Job ID: cz6tbwz39f40008svn00
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3549, '1': 547}
#   Experiment completed with status: completed, target depth: 17, actual depth: 11
#   WARNING: Actual depth 11 does not match target depth 17
#   Running experiment with payload_size=2, gates=4
# ibm_brisbane
# 4
# >>> Job ID: cz6td6wh0kc00089besg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 3061, '10': 359, '11': 418, '01': 258}
#   Experiment completed with status: completed, target depth: 17, actual depth: 11
#   WARNING: Actual depth 11 does not match target depth 17
#   Running experiment with payload_size=3, gates=3
# ibm_brisbane
# 4
# >>> Job ID: cz6tdfd1xvhg008ep2fg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'010': 211, '101': 204, '000': 669, '100': 774, '110': 171, '111': 798, '001': 187, '011': 1082}
#   Experiment completed with status: completed, target depth: 17, actual depth: 12
#   WARNING: Actual depth 12 does not match target depth 17
#   Running experiment with payload_size=1, gates=3
# ibm_brisbane
# 4
# >>> Job ID: cz6tdvqh0kc00089bf10
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1685, '1': 2411}
#   Experiment completed with status: completed, target depth: 17, actual depth: 11
#   WARNING: Actual depth 11 does not match target depth 17
#   Running experiment with payload_size=2, gates=4
# ibm_brisbane
# 7
# >>> Job ID: cz6tek239f40008svnk0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 445, '10': 443, '11': 2186, '00': 1022}
#   Experiment completed with status: completed, target depth: 17, actual depth: 11
#   WARNING: Actual depth 11 does not match target depth 17
#   Running experiment with payload_size=3, gates=3
# ibm_brisbane
# 7
# >>> Job ID: cz6tewkp6030008cxffg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'010': 160, '000': 1206, '111': 406, '100': 1386, '101': 203, '110': 199, '001': 148, '011': 388}
#   Experiment completed with status: completed, target depth: 17, actual depth: 12
#   WARNING: Actual depth 12 does not match target depth 17
#   Running experiment with payload_size=1, gates=3
# ibm_brisbane
# 8
# >>> Job ID: cz6tfwf1xvhg008ep2zg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3544, '1': 552}
#   Experiment completed with status: completed, target depth: 17, actual depth: 11
#   WARNING: Actual depth 11 does not match target depth 17
#   Running experiment with payload_size=2, gates=4
# ibm_brisbane
# 5
# >>> Job ID: cz6tg99p6030008cxfkg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10': 423, '00': 2954, '11': 425, '01': 294}
#   Experiment completed with status: completed, target depth: 17, actual depth: 11
#   WARNING: Actual depth 11 does not match target depth 17
#   Running experiment with payload_size=3, gates=3
# ibm_brisbane
# 3
# >>> Job ID: cz6th5ch0kc00089bfkg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'100': 1567, '101': 165, '000': 1451, '011': 196, '111': 236, '001': 142, '110': 204, '010': 135}
#   Experiment completed with status: completed, target depth: 17, actual depth: 12
#   WARNING: Actual depth 12 does not match target depth 17
#   Running experiment with payload_size=1, gates=3
# ibm_brisbane
# 3
# >>> Job ID: cz6thdd1xvhg008ep390
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3559, '1': 537}
#   Experiment completed with status: completed, target depth: 17, actual depth: 11
#   WARNING: Actual depth 11 does not match target depth 17
#
# Running experiments for target depth: 19 (10 combinations)
#   Running experiment with payload_size=1, gates=4
# ibm_brisbane
# 3
# >>> Job ID: cz6tj381xvhg008ep3fg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3529, '1': 567}
#   Experiment completed with status: completed, target depth: 19, actual depth: 13
#   WARNING: Actual depth 13 does not match target depth 19
#   Running experiment with payload_size=2, gates=6
# ibm_brisbane
# 4
# >>> Job ID: cz6tkq6p6030008cxg7g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'10': 430, '11': 1456, '00': 1808, '01': 402}
#   Experiment completed with status: completed, target depth: 19, actual depth: 13
#   WARNING: Actual depth 13 does not match target depth 19
#   Running experiment with payload_size=3, gates=6
# ibm_brisbane
# 4
# >>> Job ID: cz6tkwqkvm9g008gnmkg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 180, '111': 210, '000': 1487, '100': 249, '101': 202, '001': 1417, '011': 172, '010': 179}
#   Experiment completed with status: completed, target depth: 19, actual depth: 13
#   WARNING: Actual depth 13 does not match target depth 19
#   Running experiment with payload_size=4, gates=4
# ibm_brisbane
# 4
# >>> Job ID: cz6tm3rkvm9g008gnmp0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0100': 237, '1000': 527, '0101': 245, '0001': 482, '1101': 260, '1001': 478, '0011': 128, '0000': 594, '1100': 319, '1011': 133, '1110': 117, '0010': 130, '1111': 112, '0111': 121, '0110': 95, '1010': 118}
#   Experiment completed with status: completed, target depth: 19, actual depth: 14
#   WARNING: Actual depth 14 does not match target depth 19
#   Running experiment with payload_size=1, gates=4
# ibm_brisbane
# 3
# >>> Job ID: cz6tmzkkvm9g008gnmwg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'0': 1704, '1': 2392}
#   Experiment completed with status: completed, target depth: 19, actual depth: 13
#   WARNING: Actual depth 13 does not match target depth 19
#   Running experiment with payload_size=2, gates=6
# ibm_brisbane
# 4
# >>> Job ID: cz6tn5c39f40008svpv0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 383, '00': 3025, '10': 298, '01': 390}
#   Experiment completed with status: completed, target depth: 19, actual depth: 13
#   WARNING: Actual depth 13 does not match target depth 19
#   Running experiment with payload_size=3, gates=6
# ibm_brisbane
# 5
# >>> Job ID: cz6tne5h0kc00089bghg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'010': 222, '110': 192, '111': 949, '011': 1221, '001': 249, '000': 644, '100': 429, '101': 190}
#   Experiment completed with status: completed, target depth: 19, actual depth: 13
#   WARNING: Actual depth 13 does not match target depth 19
#   Running experiment with payload_size=4, gates=4
# ibm_brisbane
# 4
# >>> Job ID: cz6tp40kvm9g008gnn0g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1001': 59, '0011': 481, '0110': 120, '0111': 530, '1110': 93, '0100': 587, '1111': 547, '1000': 236, '0000': 413, '1101': 97, '1011': 331, '0010': 70, '0101': 104, '1010': 71, '1100': 283, '0001': 74}
#   Experiment completed with status: completed, target depth: 19, actual depth: 14
#   WARNING: Actual depth 14 does not match target depth 19
#   Running experiment with payload_size=1, gates=4
# ibm_brisbane
# 5
# >>> Job ID: cz6tpas1xvhg008ep490
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2409, '0': 1687}
#   Experiment completed with status: completed, target depth: 19, actual depth: 13
#   WARNING: Actual depth 13 does not match target depth 19
#   Running experiment with payload_size=2, gates=6
# ibm_kyiv
# 5
# >>> Job ID: cz6tphj10wx0008byaz0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10': 435, '01': 2106, '11': 550, '00': 1005}
#   Experiment completed with status: completed, target depth: 19, actual depth: 13
#   WARNING: Actual depth 13 does not match target depth 19
#
# Running experiments for target depth: 21 (10 combinations)
#   Running experiment with payload_size=1, gates=5
# ibm_brisbane
# 5
# >>> Job ID: cz6tprkkvm9g008gnn2g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1645, '1': 2451}
#   Experiment completed with status: completed, target depth: 21, actual depth: 15
#   WARNING: Actual depth 15 does not match target depth 21
#   Running experiment with payload_size=2, gates=8
# ibm_brisbane
# 4
# >>> Job ID: cz6tq951xvhg008ep4cg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 422, '00': 2885, '10': 314, '11': 475}
#   Experiment completed with status: completed, target depth: 21, actual depth: 15
#   WARNING: Actual depth 15 does not match target depth 21
#   Running experiment with payload_size=3, gates=9
# ibm_brisbane
# 5
# >>> Job ID: cz6tqge10wx0008byb4g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'111': 256, '000': 1614, '010': 223, '100': 1068, '110': 204, '001': 234, '101': 257, '011': 240}
#   Experiment completed with status: completed, target depth: 21, actual depth: 15
#   WARNING: Actual depth 15 does not match target depth 21
#   Running experiment with payload_size=4, gates=8
# ibm_kyiv
# 5
# >>> Job ID: cz6tres10wx0008bybb0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'0011': 408, '0000': 381, '1111': 120, '1101': 131, '0001': 355, '1000': 329, '1011': 409, '1010': 394, '0010': 451, '0101': 119, '1001': 346, '1100': 119, '0100': 140, '0111': 118, '0110': 143, '1110': 133}
#   Experiment completed with status: completed, target depth: 21, actual depth: 15
#   WARNING: Actual depth 15 does not match target depth 21
#   Running experiment with payload_size=5, gates=5
# ibm_brisbane
# 4
# >>> Job ID: cz6trm21xvhg008ep4h0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00011': 257, '00100': 253, '00110': 56, '10111': 249, '00000': 195, '10000': 204, '11000': 154, '10110': 49, '11100': 149, '01111': 254, '00010': 51, '11011': 158, '10011': 230, '00111': 291, '10010': 53, '01100': 168, '10100': 247, '01001': 45, '11110': 42, '01011': 192, '01000': 148, '00001': 62, '11001': 41, '11111': 187, '00101': 53, '10101': 50, '10001': 42, '11101': 35, '11010': 31, '01101': 56, '01110': 61, '01010': 33}
#   Experiment completed with status: completed, target depth: 21, actual depth: 16
#   WARNING: Actual depth 16 does not match target depth 21
#   Running experiment with payload_size=1, gates=5
# ibm_brisbane
# 5
# >>> Job ID: cz6tszf10wx0008bybm0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1109, '0': 2987}
#   Experiment completed with status: completed, target depth: 21, actual depth: 15
#   WARNING: Actual depth 15 does not match target depth 21
#   Running experiment with payload_size=2, gates=8
# ibm_kyiv
# 5
# >>> Job ID: cz6tt7gkvm9g008gnnw0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'00': 996, '11': 1004, '10': 1381, '01': 715}
#   Experiment completed with status: completed, target depth: 21, actual depth: 15
#   WARNING: Actual depth 15 does not match target depth 21
#   Running experiment with payload_size=3, gates=9
# ibm_kyiv
# 5
# >>> Job ID: cz6ttd1p6030008cxhp0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'101': 525, '001': 516, '011': 501, '110': 560, '111': 450, '100': 521, '000': 488, '010': 535}
#   Experiment completed with status: completed, target depth: 21, actual depth: 15
#   WARNING: Actual depth 15 does not match target depth 21
#   Running experiment with payload_size=4, gates=8
# ibm_brisbane
# 5
# >>> Job ID: cz6ttm210wx0008bybs0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0001': 97, '1000': 384, '0100': 1086, '1001': 91, '1100': 537, '0101': 178, '0000': 613, '1111': 116, '0111': 142, '0010': 120, '0011': 123, '1010': 93, '0110': 168, '1110': 124, '1011': 120, '1101': 104}
#   Experiment completed with status: completed, target depth: 21, actual depth: 15
#   WARNING: Actual depth 15 does not match target depth 21
#   Running experiment with payload_size=5, gates=5
# ibm_brisbane
# 5
# >>> Job ID: cz6tv95h0kc00089bhng
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'10101': 23, '00000': 488, '01000': 381, '00010': 122, '01110': 103, '01010': 96, '00101': 110, '01100': 431, '00001': 98, '00100': 706, '11111': 125, '10010': 35, '00111': 101, '00110': 124, '11011': 152, '00011': 96, '01111': 98, '11001': 25, '10001': 30, '01101': 92, '10111': 83, '10100': 64, '01011': 114, '11010': 31, '11000': 40, '11100': 48, '10000': 43, '10011': 99, '11110': 17, '01001': 69, '10110': 35, '11101': 17}
#   Experiment completed with status: completed, target depth: 21, actual depth: 16
#   WARNING: Actual depth 16 does not match target depth 21
#
# Running experiments for target depth: 23 (10 combinations)
#   Running experiment with payload_size=1, gates=6
# ibm_kyiv
# 5
# >>> Job ID: cz6tvex1xvhg008ep57g
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1781, '0': 2315}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=2, gates=10
# ibm_kyiv
# 4
# >>> Job ID: cz6tvmyh0kc00089bhv0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'11': 876, '10': 1036, '01': 1031, '00': 1153}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=3, gates=12
# ibm_brisbane
# 3
# >>> Job ID: cz6tvtq10wx0008byc3g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'000': 432, '011': 1098, '111': 456, '001': 353, '100': 906, '101': 267, '010': 269, '110': 315}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=4, gates=12
# ibm_brisbane
# 3
# >>> Job ID: cz6twc91xvhg008ep5e0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0001': 127, '0100': 914, '1100': 464, '0000': 854, '1001': 90, '1000': 487, '0111': 175, '0110': 90, '0011': 169, '1010': 57, '0010': 100, '1011': 166, '1110': 56, '0101': 120, '1111': 143, '1101': 84}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=5, gates=10
# ibm_brisbane
# 3
# >>> Job ID: cz6twk210wx0008byc70
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00011': 97, '01010': 159, '11111': 96, '00110': 54, '01100': 56, '00000': 720, '00100': 110, '01001': 129, '10111': 92, '01110': 62, '11101': 68, '10101': 56, '11110': 63, '10010': 99, '01000': 338, '11000': 297, '01011': 116, '10000': 216, '11100': 83, '00001': 166, '10011': 92, '10100': 67, '11001': 78, '00111': 64, '11010': 112, '01111': 87, '00010': 182, '01101': 54, '11011': 62, '10110': 69, '10001': 81, '00101': 71}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=1, gates=6
# ibm_brisbane
# 3
# >>> Job ID: cz6twt339f40008svrp0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1644, '1': 2452}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=2, gates=10
# ibm_brisbane
# 3
# >>> Job ID: cz6txg61xvhg008ep5r0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'01': 450, '00': 1605, '11': 1553, '10': 488}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=3, gates=12
# ibm_brisbane
# 3
# >>> Job ID: cz6txny1xvhg008ep5rg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'111': 675, '100': 434, '000': 493, '011': 1374, '101': 260, '010': 256, '110': 201, '001': 403}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=4, gates=12
# ibm_brisbane
# 3
# >>> Job ID: cz6txyfp6030008cxjb0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1100': 234, '0000': 1295, '1111': 234, '0011': 104, '0001': 148, '1001': 194, '1000': 830, '0100': 174, '0010': 146, '0111': 175, '1010': 125, '0110': 65, '1110': 103, '1101': 107, '0101': 69, '1011': 93}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#   Running experiment with payload_size=5, gates=10
# ibm_brisbane
# 3
# >>> Job ID: cz6tym210wx0008bycp0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10001': 72, '00011': 139, '01110': 110, '11000': 173, '01100': 202, '00000': 188, '00111': 126, '10000': 147, '11110': 105, '01000': 177, '11101': 102, '11010': 123, '10010': 96, '01111': 133, '10011': 170, '00110': 122, '11111': 158, '11011': 129, '00101': 94, '01101': 126, '10110': 98, '00010': 90, '01001': 105, '01010': 96, '10111': 105, '11100': 161, '10100': 152, '00100': 173, '11001': 104, '10101': 98, '01011': 141, '00001': 81}
#   Experiment completed with status: completed, target depth: 23, actual depth: 17
#   WARNING: Actual depth 17 does not match target depth 23
#
# Running experiments for target depth: 25 (10 combinations)
#   Running experiment with payload_size=1, gates=7
# ibm_kyiv
# 5
# >>> Job ID: cz6v07gh0kc00089bjsg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1706, '0': 2390}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=2, gates=12
# ibm_brisbane
# 6
# >>> Job ID: cz6v0es1xvhg008ep65g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1261, '11': 1961, '10': 416, '01': 458}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=3, gates=15
# ibm_brisbane
# 6
# >>> Job ID: cz6v0sk1xvhg008ep680
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'001': 136, '110': 525, '100': 1774, '101': 216, '000': 601, '011': 249, '111': 248, '010': 347}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=4, gates=16
# ibm_kyiv
# 4
# >>> Job ID: cz6v1gy10wx0008byd9g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1110': 315, '1100': 337, '1010': 347, '0100': 149, '1011': 373, '1000': 271, '0101': 186, '0110': 120, '1111': 376, '0010': 122, '1101': 281, '0001': 226, '0111': 267, '1001': 334, '0011': 261, '0000': 131}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=5, gates=15
# ibm_brisbane
# 7
# >>> Job ID: cz6v1qyh0kc00089bjxg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00100': 83, '00101': 102, '00111': 160, '01001': 305, '01011': 120, '00001': 275, '10000': 149, '10110': 88, '11000': 234, '10001': 197, '01000': 148, '01110': 122, '01111': 134, '11111': 128, '11001': 183, '11011': 81, '00010': 58, '10011': 102, '00110': 102, '01101': 140, '00000': 129, '01100': 94, '11100': 70, '11101': 138, '11110': 117, '11010': 80, '10010': 65, '10111': 109, '10101': 124, '00011': 101, '01010': 77, '10100': 81}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=1, gates=7
# ibm_kyiv
# 6
# >>> Job ID: cz6v1yq39f40008svsm0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'0': 2551, '1': 1545}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=2, gates=12
# ibm_brisbane
# 3
# >>> Job ID: cz6v24010wx0008bydb0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10': 411, '11': 2196, '00': 934, '01': 555}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=3, gates=15
# ibm_brisbane
# 3
# >>> Job ID: cz6v2mtkvm9g008gnq5g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'100': 1019, '001': 230, '000': 1570, '010': 257, '011': 261, '110': 252, '101': 225, '111': 282}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=4, gates=16
# ibm_brisbane
# 3
# >>> Job ID: cz6v2tb1xvhg008ep6k0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1111': 227, '0100': 567, '0001': 157, '1100': 359, '0111': 307, '0000': 746, '1000': 520, '1001': 233, '1110': 78, '0011': 121, '0101': 146, '1010': 100, '0110': 125, '1011': 167, '0010': 86, '1101': 157}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#   Running experiment with payload_size=5, gates=15
# ibm_brisbane
# 3
# >>> Job ID: cz6v3141xvhg008ep6ng
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10100': 94, '10011': 142, '01001': 99, '10001': 73, '01010': 191, '01110': 165, '00010': 166, '11101': 158, '11100': 190, '00001': 64, '10101': 123, '00000': 152, '10000': 59, '11011': 92, '00101': 135, '01101': 249, '00110': 173, '10110': 83, '00111': 69, '10010': 101, '01111': 94, '01000': 167, '00011': 93, '10111': 77, '11000': 84, '00100': 217, '01100': 406, '11111': 84, '11110': 66, '11001': 79, '01011': 94, '11010': 57}
#   Experiment completed with status: completed, target depth: 25, actual depth: 19
#   WARNING: Actual depth 19 does not match target depth 25
#
# Running experiments for target depth: 27 (10 combinations)
#   Running experiment with payload_size=1, gates=8
# ibm_brisbane
# 3
# >>> Job ID: cz6v3r7p6030008cxk3g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'1': 2438, '0': 1658}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=2, gates=14
# ibm_brisbane
# 3
# >>> Job ID: cz6v3xfkvm9g008gnqbg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 1487, '00': 1545, '10': 576, '01': 488}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=3, gates=18
# ibm_brisbane
# 3
# >>> Job ID: cz6v46r39f40008svt0g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'000': 402, '001': 544, '101': 481, '011': 568, '111': 411, '110': 693, '010': 373, '100': 624}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=4, gates=20
# ibm_brisbane
# 3
# >>> Job ID: cz6v4wkkvm9g008gnqgg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1001': 163, '0100': 166, '0110': 86, '1000': 763, '0000': 1133, '1111': 314, '1100': 194, '0101': 86, '0010': 180, '0111': 211, '1101': 132, '0001': 167, '0011': 152, '1010': 141, '1110': 92, '1011': 116}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=5, gates=20
# ibm_kyiv
# 4
# >>> Job ID: cz6v6eh10wx0008bye4g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11001': 161, '00010': 160, '10011': 212, '01010': 163, '01110': 62, '10001': 80, '10100': 78, '11100': 99, '11010': 318, '11011': 367, '00111': 144, '01111': 80, '11111': 168, '01001': 59, '01011': 169, '10010': 190, '11110': 136, '01100': 66, '11000': 116, '10000': 76, '00011': 162, '00100': 92, '01000': 56, '00001': 87, '00110': 93, '10110': 110, '10111': 157, '10101': 90, '00000': 85, '01101': 69, '00101': 73, '11101': 118}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=1, gates=8
# ibm_brisbane
# 6
# >>> Job ID: cz6v94w10wx0008byejg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3500, '1': 596}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=2, gates=14
# ibm_brisbane
# 7
# >>> Job ID: cz6v9bx10wx0008byepg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10': 422, '11': 2410, '00': 835, '01': 429}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=3, gates=18
# ibm_brisbane
# 5
# >>> Job ID: cz6v9mekvm9g008gnr60
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'001': 307, '010': 353, '011': 597, '100': 1136, '111': 364, '000': 591, '110': 492, '101': 256}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=4, gates=20
# ibm_kyiv
# 5
# >>> Job ID: cz6va9s39f40008svv70
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0110': 243, '1010': 222, '1000': 301, '0011': 203, '0111': 202, '0010': 171, '1011': 265, '1110': 267, '1111': 261, '0000': 270, '1101': 230, '0100': 411, '1001': 242, '0101': 241, '1100': 315, '0001': 252}
#   Experiment completed with status: completed, target depth: 27, actual depth: 21
#   WARNING: Actual depth 21 does not match target depth 27
#   Running experiment with payload_size=5, gates=20
# ibm_brisbane
# 7
# >>> Job ID: cz6vagj39f40008svv9g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# ...
#   Experiment completed with status: completed, target depth: 45, actual depth: 39
#   WARNING: Actual depth 39 does not match target depth 45
#   Running experiment with payload_size=1, gates=17
# ibm_brisbane
# 4
# >>> Job ID: cz6wapakvm9g008gp1d0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 577, '0': 3519}
#   Experiment completed with status: completed, target depth: 45, actual depth: 39
#   WARNING: Actual depth 39 does not match target depth 45
#   Running experiment with payload_size=2, gates=32
# ibm_kyiv
# 4
# >>> Job ID: cz6wbhp1xvhg008ephd0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 1376, '00': 1934, '10': 373, '11': 413}
#   Experiment completed with status: completed, target depth: 45, actual depth: 39
#   WARNING: Actual depth 39 does not match target depth 45
#   Running experiment with payload_size=3, gates=45
# ibm_kyiv
# 4
# >>> Job ID: cz6wbrq39f40008sw4c0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'000': 380, '001': 514, '010': 374, '101': 584, '111': 519, '110': 595, '100': 628, '011': 502}
#   Experiment completed with status: completed, target depth: 45, actual depth: 39
#   WARNING: Actual depth 39 does not match target depth 45
#   Running experiment with payload_size=4, gates=56
# ibm_brisbane
# 5
# >>> Job ID: cz6wbzq39f40008sw4cg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1100': 106, '0111': 404, '0000': 1298, '0010': 264, '0011': 167, '1101': 148, '1111': 270, '1001': 90, '0101': 145, '0001': 261, '1010': 82, '1000': 286, '0100': 173, '1110': 119, '0110': 160, '1011': 123}
#   Experiment completed with status: completed, target depth: 45, actual depth: 39
#   WARNING: Actual depth 39 does not match target depth 45
#   Running experiment with payload_size=5, gates=65
# ibm_kyiv
# 4
# >>> Job ID: cz6wcnjh0kc00089bx2g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11000': 220, '10000': 162, '11111': 116, '01101': 107, '00111': 96, '01110': 114, '11110': 101, '11010': 92, '01100': 149, '01111': 115, '00101': 115, '10010': 108, '00000': 174, '00100': 186, '01001': 156, '00011': 98, '01011': 104, '11011': 98, '11101': 79, '00010': 115, '11001': 164, '10001': 120, '01000': 293, '10111': 99, '00110': 118, '10110': 89, '00001': 122, '10100': 169, '10101': 109, '11100': 112, '01010': 84, '10011': 112}
#   Experiment completed with status: completed, target depth: 45, actual depth: 39
#   WARNING: Actual depth 39 does not match target depth 45
#
# Running experiments for target depth: 47 (10 combinations)
#   Running experiment with payload_size=1, gates=18
# ibm_kyiv
# 5
# >>> Job ID: cz6wcwbp6030008cxxy0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1145, '0': 2951}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=2, gates=34
# ibm_kyiv
# 5
# >>> Job ID: cz6wd3m10wx0008bysdg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'01': 1108, '10': 1096, '00': 1461, '11': 431}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=3, gates=48
# ibm_brisbane
# 5
# >>> Job ID: cz6wd95kvm9g008gp1x0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 150, '011': 913, '100': 720, '111': 781, '000': 966, '101': 181, '001': 209, '010': 176}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=4, gates=60
# ibm_kyiv
# 5
# >>> Job ID: cz6we20p6030008cxy10
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1010': 259, '1111': 208, '1001': 268, '1000': 269, '0100': 252, '1011': 302, '1110': 244, '0000': 231, '0001': 274, '0010': 210, '1100': 277, '1101': 256, '0011': 294, '0110': 226, '0101': 268, '0111': 258}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=5, gates=70
# ibm_kyiv
# 5
# >>> Job ID: cz6we9hp6030008cxy1g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00110': 145, '10111': 134, '00101': 160, '00001': 135, '11000': 125, '10110': 163, '00111': 139, '01010': 122, '00010': 121, '01001': 109, '00011': 121, '11110': 143, '10100': 112, '01110': 175, '10010': 134, '11100': 107, '10001': 78, '11011': 140, '10011': 98, '10101': 133, '11010': 167, '00000': 106, '11001': 128, '01000': 82, '11101': 145, '01111': 120, '11111': 132, '01011': 125, '10000': 93, '01100': 119, '00100': 138, '01101': 147}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=1, gates=18
# ibm_brisbane
# 5
# >>> Job ID: cz6went1xvhg008ephzg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3566, '1': 530}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=2, gates=34
# ibm_brisbane
# 5
# >>> Job ID: cz6wfn61xvhg008epj80
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10': 378, '00': 2943, '01': 355, '11': 420}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=3, gates=48
# ibm_kyiv
# 4
# >>> Job ID: cz6wk8nkvm9g008gp330
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'100': 423, '101': 587, '011': 426, '001': 697, '111': 438, '010': 576, '110': 522, '000': 427}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=4, gates=60
# ibm_kyiv
# 6
# >>> Job ID: cz6wkedh0kc00089byng
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1001': 400, '1000': 242, '0011': 328, '1011': 321, '0010': 219, '0101': 337, '0110': 228, '0000': 183, '1101': 233, '0001': 340, '1110': 184, '1111': 206, '1100': 138, '0100': 168, '0111': 289, '1010': 280}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#   Running experiment with payload_size=5, gates=70
# ibm_kyiv
# 5
# >>> Job ID: cz6wkrqh0kc00089byt0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'11010': 127, '01100': 131, '00110': 137, '00010': 130, '00101': 108, '11110': 124, '10010': 162, '00000': 142, '10100': 115, '10001': 132, '11101': 114, '01001': 128, '01101': 131, '11000': 140, '11100': 131, '10000': 156, '01000': 124, '01011': 125, '10110': 145, '11001': 113, '11111': 124, '11011': 126, '00011': 110, '01111': 123, '00001': 118, '00111': 119, '10101': 128, '10011': 128, '01010': 130, '01110': 134, '10111': 119, '00100': 122}
#   Experiment completed with status: completed, target depth: 47, actual depth: 41
#   WARNING: Actual depth 41 does not match target depth 47
#
# Running experiments for target depth: 49 (10 combinations)
#   Running experiment with payload_size=1, gates=19
# ibm_kyiv
# 4
# >>> Job ID: cz6wkxz1xvhg008epk8g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2713, '1': 1383}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=2, gates=36
# ibm_kyiv
# 4
# >>> Job ID: cz6wm4r39f40008sw690
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 1188, '10': 906, '11': 824, '00': 1178}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=3, gates=51
# ibm_kyiv
# 4
# >>> Job ID: cz6wmbhh0kc00089bz00
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'111': 502, '011': 500, '100': 652, '010': 368, '001': 526, '000': 412, '110': 513, '101': 623}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=4, gates=64
# ibm_kyiv
# 6
# >>> Job ID: cz6wmjah0kc00089bz3g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'0000': 200, '1011': 292, '0110': 259, '0010': 199, '1100': 246, '1001': 328, '1101': 290, '0101': 278, '0011': 296, '1110': 236, '1111': 270, '1000': 208, '0111': 227, '0100': 216, '0001': 323, '1010': 228}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=5, gates=75
# ibm_kyiv
# 4
# >>> Job ID: cz6wmrbh0kc00089bz4g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'10001': 109, '00001': 122, '10000': 139, '10101': 134, '00110': 147, '01011': 138, '01001': 145, '00111': 138, '11010': 147, '01101': 114, '01010': 127, '10111': 124, '00011': 126, '01111': 117, '11111': 116, '00100': 139, '11000': 122, '11011': 126, '11001': 136, '00101': 133, '10011': 124, '11110': 115, '00000': 128, '01000': 130, '10010': 119, '11101': 128, '01100': 119, '01110': 137, '10110': 115, '10100': 120, '11100': 125, '00010': 137}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=1, gates=19
# ibm_kyiv
# 4
# >>> Job ID: cz6wmzbh0kc00089bz5g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'1': 1510, '0': 2586}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=2, gates=36
# ibm_kyiv
# 4
# >>> Job ID: cz6wn5mp6030008cxztg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'00': 1125, '01': 1387, '10': 790, '11': 794}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=3, gates=51
# ibm_kyiv
# 5
# >>> Job ID: cz6wnb51xvhg008epkhg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'101': 339, '010': 534, '100': 356, '111': 364, '000': 695, '001': 834, '011': 572, '110': 402}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=4, gates=64
# ibm_brisbane
# 5
# >>> Job ID: cz6wngy10wx0008byvg0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1101': 147, '0011': 416, '0000': 404, '0100': 298, '0101': 115, '1111': 441, '1011': 377, '1000': 381, '1100': 440, '1001': 112, '0111': 420, '1010': 109, '1110': 117, '0010': 108, '0001': 108, '0110': 103}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
#   Running experiment with payload_size=5, gates=75
# ibm_kyiv
# 4
# >>> Job ID: cz6wnqy10wx0008byvhg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: DONE
# {'11000': 143, '10100': 145, '00011': 95, '10000': 132, '01101': 103, '11111': 175, '01000': 93, '01011': 95, '00000': 114, '11110': 187, '00001': 93, '01001': 92, '00110': 107, '11100': 153, '00111': 91, '11101': 158, '01110': 102, '00010': 110, '11010': 149, '00101': 89, '10110': 148, '01111': 93, '11001': 180, '10111': 172, '10001': 148, '10011': 157, '00100': 123, '10101': 148, '01100': 86, '11011': 170, '01010': 84, '10010': 161}
#   Experiment completed with status: completed, target depth: 49, actual depth: 43
#   WARNING: Actual depth 43 does not match target depth 49
# Results exported to experiment_results_target_depth_20250309_170751.csv

# %%
