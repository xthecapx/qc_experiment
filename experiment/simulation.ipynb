# %%
# %load_ext autoreload
# %autoreload 2

# %%
from teleportation_validator import TeleportationValidator
validator = TeleportationValidator(payload_size=10, gates=4, save_statevector=True, use_barriers=False)
display(validator.draw())
results = validator.run_simulation()
# Out:
# State vector after payload:
# $$(-0.0207759263 + 0.0077202044 i) |0000000000000\rangle+(-0.0120216435 + 0.0131304183 i) |0000000000001\rangle+(0.0161606208 - 0.0149718457 i) |0000000000010\rangle+(0.0234143985 - 0.0105546503 i) |0000000000011\rangle+(0.0177851935 - 0.0007840222 i) |0000000000100\rangle+(0.0201498073 + 0.0092317895 i) |0000000000101\rangle + \ldots +(0.0219201348 - 0.0032784692 i) |0011111111011\rangle+(-0.0113719448 - 0.0188679808 i) |0011111111100\rangle+(0.0195665228 + 0.0166368833 i) |0011111111101\rangle+(-0.0178181038 - 0.0131816481 i) |0011111111110\rangle+(0.0079064096 + 0.0159504384 i) |0011111111111\rangle$$
# State vector before validation:
# ...
