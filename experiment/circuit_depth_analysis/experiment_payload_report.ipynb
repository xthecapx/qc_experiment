# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import the analysis functions
import sys
import os

from analysis import (
    plot_error_rate_vs_payload_size_colored_by_depth,
    plot_error_rate_distribution_by_payload_size,
    plot_error_distribution_by_payload_size_overall,
    create_experiment_dataframe
)

df = create_experiment_dataframe("experiment_results_fixed_payload_20250501_full_updated.csv")

plot_error_rate_vs_payload_size_colored_by_depth(df)
plot_error_rate_distribution_by_payload_size(df)
plot_error_distribution_by_payload_size_overall(df)
