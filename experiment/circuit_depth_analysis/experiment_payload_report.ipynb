# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import the analysis functions
import sys
import os

from analysis import (
    run_analysis
)

run_analysis("experiment_results_fixed_payload_20250501_full_updated.csv")
# Out:
# Loading data from experiment_results_fixed_payload_20250501_full_updated.csv...
# Loaded 101 experiment results.
# Circuit depths present in data: [11, 13, 15, 17, 19]
# Payload sizes present in data: [1, 2, 3, 4, 5]
#
# Generating success rate vs payload size plot...
#
# Regression statistics for success rate vs payload size:
# Overall: slope=-13.4688, intercept=63.5424, R²=0.8399, p-value=0.0286, std_err=3.3948
#
# Generating overall error distribution by payload size plot (single bar chart)...
#
# Generating success rate heatmap...
#
# Generating multi-panel error distribution by payload size plot...
#
# Generating execution time vs payload size plot...
#
# Regression statistics for execution time vs payload size:
# Slope: 0.0190, Intercept: 1.7653, R-squared: 0.2790, P-value: 0.3602, Std Err: 0.0177
#
# Performing detailed regression analysis (OLS models)...
#
# Model 1: All features (linear)
#                             OLS Regression Results
# ...
