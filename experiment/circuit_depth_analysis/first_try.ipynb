# %%
# %load_ext autoreload
# %autoreload 2

# %%
from teleportation_validator import TeleportationValidator

validator = TeleportationValidator(payload_size=1, gates=1, use_barriers=True, save_statevector=True)

# %%
validator.draw()

# %%
validator.run_simulation()
# Out:
# State vector after payload:
# $$\frac{\sqrt{2} i}{2} |0001\rangle- \frac{\sqrt{2} i}{2} |0010\rangle$$
# State vector before validation:
# $$\frac{\sqrt{2} i}{4} |0001\rangle+\frac{\sqrt{2} i}{4} |0011\rangle+\frac{\sqrt{2} i}{4} |0101\rangle+\frac{\sqrt{2} i}{4} |0111\rangle- \frac{\sqrt{2} i}{4} |1000\rangle- \frac{\sqrt{2} i}{4} |1010\rangle- \frac{\sqrt{2} i}{4} |1100\rangle- \frac{\sqrt{2} i}{4} |1110\rangle$$
# State vector after validation:
# $$\frac{1}{2} |0000\rangle+\frac{1}{2} |0010\rangle+\frac{1}{2} |0100\rangle+\frac{1}{2} |0110\rangle$$
# {'results_metrics': {'counts': {'0': 1024}, 'success_rate': 1.0},
#  'circuit_metrics': {'depth': 13,
#   'width': 5,
#   'size': 13,
#   'count_ops': OrderedDict([('cx', 5),
#                ('h', 4),
#                ('save_statevector', 3),
#                ('y', 2),
#                ('barrier', 1),
#                ('cz', 1),
#                ('measure', 1)]),
#   'num_qubits': 4,
#   'num_clbits': 1,
#   'num_ancillas': 0,
# ...
