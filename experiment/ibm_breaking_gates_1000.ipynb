# %%
# %load_ext autoreload
# %autoreload 2

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(1000, 1005),
    run_on_ibm=True,
    channel=channel,
    token=token
)
# Out:
# Running experiment with payload_size=1 and gates=1000
# ibm_kyiv
# 7
# >>> Job ID: cyv0qyfjj6dg008g4aa0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2387, '0': 1709}
# Experiment with payload=1, gates=1000 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1001
# ibm_kyiv
# 6
# >>> Job ID: cyv0rkt38jq0008xxyb0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1714, '1': 2382}
# Experiment with payload=1, gates=1001 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1002
# ibm_kyiv
# 6
# >>> Job ID: cyv0rx3y2gd0008865w0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2101, '0': 1995}
# Experiment with payload=1, gates=1002 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1003
# ibm_kyiv
# 6
# >>> Job ID: cyv0s6478z600082q3m0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2262, '0': 1834}
# Experiment with payload=1, gates=1003 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1004
# ibm_kyiv
# 9
# >>> Job ID: cyv0sex4raf0008ejv60
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1975, '1': 2121}
# Experiment with payload=1, gates=1004 completed with status: completed
#
# Running experiment with payload_size=1 and gates=1005
# ibm_kyiv
# 6
# >>> Job ID: cyv0sqpjj6dg008g4ang
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1907, '1': 2189}
# Experiment with payload=1, gates=1005 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1000
# ibm_kyiv
# 7
# >>> Job ID: cyv0t0878z600082q3wg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 1040, '00': 1227, '10': 1047, '01': 782}
# Experiment with payload=2, gates=1000 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1001
# ibm_kyiv
# 6
# >>> Job ID: cyv0t9h4raf0008ejv70
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 943, '00': 1094, '10': 971, '01': 1088}
# Experiment with payload=2, gates=1001 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1002
# ibm_kyiv
# 6
# >>> Job ID: cyv0tjtjj6dg008g4aqg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 975, '11': 956, '00': 1180, '10': 985}
# Experiment with payload=2, gates=1002 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1003
# ibm_kyiv
# 6
# >>> Job ID: cyv0tw378z600082q3z0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1314, '11': 1009, '01': 945, '10': 828}
# Experiment with payload=2, gates=1003 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1004
# ibm_kyiv
# 6
# >>> Job ID: cyv0v6mjj6dg008g4as0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1183, '11': 1137, '10': 879, '01': 897}
# Experiment with payload=2, gates=1004 completed with status: completed
#
# Running experiment with payload_size=2 and gates=1005
# ibm_kyiv
# 7
# >>> Job ID: cyv0vfnjj6dg008g4at0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'11': 1092, '10': 1136, '00': 1082, '01': 786}
# Experiment with payload=2, gates=1005 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1000
# ibm_kyiv
# 6
# >>> Job ID: cyv0vrzq5bwg0083p07g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'001': 615, '100': 412, '010': 616, '110': 369, '000': 650, '111': 396, '011': 620, '101': 418}
# Experiment with payload=3, gates=1000 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1001
# ibm_kyiv
# 6
# >>> Job ID: cyv0w2878z600082q42g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 565, '001': 461, '000': 525, '111': 448, '011': 485, '010': 569, '101': 482, '100': 561}
# Experiment with payload=3, gates=1001 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1002
# ibm_kyiv
# 7
# >>> Job ID: cyv0wb94raf0008ejvdg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'001': 500, '011': 530, '010': 485, '000': 490, '101': 474, '110': 547, '100': 564, '111': 506}
# Experiment with payload=3, gates=1002 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1003
# ibm_kyiv
# 7
# >>> Job ID: cyv0wnay2gd0008866a0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'101': 347, '010': 680, '111': 400, '001': 679, '110': 377, '000': 619, '011': 604, '100': 390}
# Experiment with payload=3, gates=1003 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1004
# ibm_kyiv
# 10
# >>> Job ID: cyv0xv7y2gd0008866dg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'100': 535, '011': 580, '111': 417, '000': 511, '110': 403, '001': 553, '101': 524, '010': 573}
# Experiment with payload=3, gates=1004 completed with status: completed
#
# Running experiment with payload_size=3 and gates=1005
# ibm_kyiv
# 9
# >>> Job ID: cyv0y48q5bwg0083p0g0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'010': 451, '011': 499, '001': 423, '100': 601, '000': 440, '101': 553, '111': 593, '110': 536}
# Experiment with payload=3, gates=1005 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1000
# ibm_kyiv
# 11
# >>> Job ID: cyv0ydh78z600082q470
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0111': 351, '0100': 352, '0010': 349, '0011': 379, '0001': 323, '1110': 176, '1010': 158, '0101': 285, '0110': 329, '0000': 304, '1101': 194, '1000': 206, '1001': 165, '1011': 185, '1100': 159, '1111': 181}
# Experiment with payload=4, gates=1000 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1001
# ibm_kyiv
# 10
# >>> Job ID: cyv0ypt4raf0008ejvk0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1111': 332, '1000': 244, '1101': 267, '0011': 251, '1110': 302, '1001': 269, '1011': 304, '0010': 218, '1010': 277, '0111': 248, '0100': 238, '0101': 224, '0001': 201, '1100': 242, '0000': 237, '0110': 242}
# Experiment with payload=4, gates=1001 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1002
# ibm_kyiv
# 11
# >>> Job ID: cyv0yzb78z600082q480
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0010': 283, '1001': 197, '1100': 182, '0100': 313, '0110': 296, '1111': 218, '1000': 178, '1010': 193, '1101': 210, '0101': 401, '0000': 275, '1011': 196, '0111': 302, '1110': 176, '0001': 364, '0011': 312}
# Experiment with payload=4, gates=1002 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1003
# ibm_kyiv
# 11
# >>> Job ID: cyv0z8d38jq0008xxyyg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0101': 247, '1010': 260, '0110': 303, '0010': 262, '0001': 253, '1011': 239, '1100': 245, '1111': 295, '1000': 242, '1101': 243, '0011': 229, '1110': 257, '1001': 268, '0000': 245, '0111': 270, '0100': 238}
# Experiment with payload=4, gates=1003 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1004
# ibm_kyiv
# 5
# >>> Job ID: cyv0zke38jq0008xxz00
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1110': 256, '1011': 251, '1001': 220, '0000': 262, '0100': 262, '0001': 262, '1100': 251, '0111': 298, '1101': 213, '0101': 251, '1000': 218, '0110': 244, '0010': 290, '1010': 260, '1111': 265, '0011': 293}
# Experiment with payload=4, gates=1004 completed with status: completed
#
# Running experiment with payload_size=4 and gates=1005
# ibm_kyiv
# 7
# >>> Job ID: cyv0zwqjj6dg008g4b1g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1100': 252, '0011': 267, '1110': 270, '0110': 236, '1101': 237, '1000': 276, '1001': 247, '1111': 239, '0010': 245, '0000': 257, '1010': 270, '0001': 239, '0100': 265, '1011': 245, '0111': 273, '0101': 278}
# Experiment with payload=4, gates=1005 completed with status: completed
# [{'status': 'completed',
#   'circuit_metrics': {'depth': 2005,
#    'width': 5,
#    'size': 2011,
#    'count_ops': OrderedDict([('y', 434),
#                 ('u', 398),
#                 ('x', 368),
#                 ('s', 216),
#                 ('sdg', 216),
#                 ('t', 184),
#                 ('tdg', 184),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0qyfjj6dg008g4aa0',
#    'counts': {'1': 2387, '0': 1709},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 2387, '0': 1709},
#    'success_rate': 0.417236328125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1000,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 2007,
#    'width': 5,
#    'size': 2013,
#    'count_ops': OrderedDict([('u', 430),
#                 ('x', 398),
#                 ('y', 366),
#                 ('s', 208),
#                 ('sdg', 208),
#                 ('t', 196),
#                 ('tdg', 196),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0rkt38jq0008xxyb0',
#    'counts': {'0': 1714, '1': 2382},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0': 1714, '1': 2382},
#    'success_rate': 0.41845703125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1001,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 2009,
#    'width': 5,
#    'size': 2015,
#    'count_ops': OrderedDict([('x', 488),
#                 ('y', 416),
#                 ('u', 366),
#                 ('s', 185),
#                 ('sdg', 185),
#                 ('t', 182),
#                 ('tdg', 182),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0rx3y2gd0008865w0',
#    'counts': {'1': 2101, '0': 1995},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 2101, '0': 1995},
#    'success_rate': 0.487060546875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1002,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 2011,
#    'width': 5,
#    'size': 2017,
#    'count_ops': OrderedDict([('y', 446),
#                 ('x', 402),
#                 ('u', 366),
#                 ('t', 224),
#                 ('tdg', 224),
#                 ('s', 172),
#                 ('sdg', 172),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0s6478z600082q3m0',
#    'counts': {'1': 2262, '0': 1834},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1': 2262, '0': 1834},
#    'success_rate': 0.44775390625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1003,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 2013,
#    'width': 5,
#    'size': 2019,
#    'count_ops': OrderedDict([('x', 446),
#                 ('y', 386),
#                 ('u', 350),
#                 ('t', 220),
#                 ('tdg', 220),
#                 ('s', 193),
#                 ('sdg', 193),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0sex4raf0008ejv60',
#    'counts': {'0': 1975, '1': 2121},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0': 1975, '1': 2121},
#    'success_rate': 0.482177734375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1004,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 2015,
#    'width': 5,
#    'size': 2021,
#    'count_ops': OrderedDict([('y', 394),
#                 ('u', 380),
#                 ('x', 358),
#                 ('t', 223),
#                 ('tdg', 223),
#                 ('s', 216),
#                 ('sdg', 216),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0sqpjj6dg008g4ang',
#    'counts': {'0': 1907, '1': 2189},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0': 1907, '1': 2189},
#    'success_rate': 0.465576171875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 1,
#    'num_gates': 1005,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1007,
#    'width': 7,
#    'size': 2016,
#    'count_ops': OrderedDict([('y', 414),
#                 ('u', 404),
#                 ('x', 342),
#                 ('t', 221),
#                 ('tdg', 221),
#                 ('s', 199),
#                 ('sdg', 199),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0t0878z600082q3wg',
#    'counts': {'11': 1040, '00': 1227, '10': 1047, '01': 782},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'11': 1040,
#     '00': 1227,
#     '10': 1047,
#     '01': 782},
#    'success_rate': 0.299560546875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1000,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1007,
#    'width': 7,
#    'size': 2018,
#    'count_ops': OrderedDict([('u', 430),
#                 ('x', 404),
#                 ('y', 368),
#                 ('t', 204),
#                 ('tdg', 204),
#                 ('s', 196),
#                 ('sdg', 196),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0t9h4raf0008ejv70',
#    'counts': {'11': 943, '00': 1094, '10': 971, '01': 1088},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'11': 943, '00': 1094, '10': 971, '01': 1088},
#    'success_rate': 0.26708984375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1001,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1009,
#    'width': 7,
#    'size': 2020,
#    'count_ops': OrderedDict([('u', 432),
#                 ('y', 420),
#                 ('x', 390),
#                 ('t', 208),
#                 ('tdg', 208),
#                 ('s', 173),
#                 ('sdg', 173),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0tjtjj6dg008g4aqg',
#    'counts': {'01': 975, '11': 956, '00': 1180, '10': 985},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'01': 975, '11': 956, '00': 1180, '10': 985},
#    'success_rate': 0.2880859375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1002,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1009,
#    'width': 7,
#    'size': 2022,
#    'count_ops': OrderedDict([('u', 440),
#                 ('x', 380),
#                 ('y', 378),
#                 ('t', 205),
#                 ('tdg', 205),
#                 ('s', 199),
#                 ('sdg', 199),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0tw378z600082q3z0',
#    'counts': {'00': 1314, '11': 1009, '01': 945, '10': 828},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'00': 1314, '11': 1009, '01': 945, '10': 828},
#    'success_rate': 0.32080078125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1003,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1011,
#    'width': 7,
#    'size': 2024,
#    'count_ops': OrderedDict([('u', 404),
#                 ('x', 398),
#                 ('y', 384),
#                 ('t', 222),
#                 ('tdg', 222),
#                 ('s', 189),
#                 ('sdg', 189),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0v6mjj6dg008g4as0',
#    'counts': {'00': 1183, '11': 1137, '10': 879, '01': 897},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'00': 1183, '11': 1137, '10': 879, '01': 897},
#    'success_rate': 0.288818359375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1004,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 1011,
#    'width': 7,
#    'size': 2026,
#    'count_ops': OrderedDict([('x', 498),
#                 ('y', 434),
#                 ('u', 396),
#                 ('t', 176),
#                 ('tdg', 176),
#                 ('s', 165),
#                 ('sdg', 165),
#                 ('cx', 7),
#                 ('h', 6),
#                 ('measure', 2),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 2},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0vfnjj6dg008g4at0',
#    'counts': {'11': 1092, '10': 1136, '00': 1082, '01': 786},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'11': 1092,
#     '10': 1136,
#     '00': 1082,
#     '01': 786},
#    'success_rate': 0.26416015625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 2,
#    'num_gates': 1005,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 675,
#    'width': 9,
#    'size': 2021,
#    'count_ops': OrderedDict([('x', 436),
#                 ('y', 402),
#                 ('u', 374),
#                 ('s', 208),
#                 ('sdg', 208),
#                 ('t', 186),
#                 ('tdg', 186),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0vrzq5bwg0083p07g',
#    'counts': {'001': 615,
#     '100': 412,
#     '010': 616,
#     '110': 369,
#     '000': 650,
#     '111': 396,
#     '011': 620,
#     '101': 418},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'001': 615,
#     '100': 412,
#     '010': 616,
#     '110': 369,
#     '000': 650,
#     '111': 396,
#     '011': 620,
#     '101': 418},
#    'success_rate': 0.15869140625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1000,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 675,
#    'width': 9,
#    'size': 2023,
#    'count_ops': OrderedDict([('x', 488),
#                 ('y', 376),
#                 ('u', 364),
#                 ('t', 204),
#                 ('tdg', 204),
#                 ('s', 183),
#                 ('sdg', 183),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0w2878z600082q42g',
#    'counts': {'110': 565,
#     '001': 461,
#     '000': 525,
#     '111': 448,
#     '011': 485,
#     '010': 569,
#     '101': 482,
#     '100': 561},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'110': 565,
#     '001': 461,
#     '000': 525,
#     '111': 448,
#     '011': 485,
#     '010': 569,
#     '101': 482,
#     '100': 561},
#    'success_rate': 0.128173828125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1001,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 677,
#    'width': 9,
#    'size': 2025,
#    'count_ops': OrderedDict([('u', 458),
#                 ('x', 402),
#                 ('y', 376),
#                 ('s', 195),
#                 ('sdg', 195),
#                 ('t', 189),
#                 ('tdg', 189),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0wb94raf0008ejvdg',
#    'counts': {'001': 500,
#     '011': 530,
#     '010': 485,
#     '000': 490,
#     '101': 474,
#     '110': 547,
#     '100': 564,
#     '111': 506},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'001': 500,
#     '011': 530,
#     '010': 485,
#     '000': 490,
#     '101': 474,
#     '110': 547,
#     '100': 564,
#     '111': 506},
#    'success_rate': 0.11962890625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1002,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 677,
#    'width': 9,
#    'size': 2027,
#    'count_ops': OrderedDict([('y', 400),
#                 ('x', 384),
#                 ('u', 358),
#                 ('s', 216),
#                 ('t', 216),
#                 ('sdg', 216),
#                 ('tdg', 216),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0wnay2gd0008866a0',
#    'counts': {'101': 347,
#     '010': 680,
#     '111': 400,
#     '001': 679,
#     '110': 377,
#     '000': 619,
#     '011': 604,
#     '100': 390},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'101': 347,
#     '010': 680,
#     '111': 400,
#     '001': 679,
#     '110': 377,
#     '000': 619,
#     '011': 604,
#     '100': 390},
#    'success_rate': 0.151123046875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1003,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 677,
#    'width': 9,
#    'size': 2029,
#    'count_ops': OrderedDict([('y', 424),
#                 ('x', 418),
#                 ('u', 404),
#                 ('s', 199),
#                 ('sdg', 199),
#                 ('t', 182),
#                 ('tdg', 182),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0xv7y2gd0008866dg',
#    'counts': {'100': 535,
#     '011': 580,
#     '111': 417,
#     '000': 511,
#     '110': 403,
#     '001': 553,
#     '101': 524,
#     '010': 573},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'100': 535,
#     '011': 580,
#     '111': 417,
#     '000': 511,
#     '110': 403,
#     '001': 553,
#     '101': 524,
#     '010': 573},
#    'success_rate': 0.124755859375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1004,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 679,
#    'width': 9,
#    'size': 2031,
#    'count_ops': OrderedDict([('x', 422),
#                 ('u', 386),
#                 ('y', 386),
#                 ('t', 206),
#                 ('tdg', 206),
#                 ('s', 202),
#                 ('sdg', 202),
#                 ('cx', 9),
#                 ('h', 8),
#                 ('measure', 3),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 3},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0y48q5bwg0083p0g0',
#    'counts': {'010': 451,
#     '011': 499,
#     '001': 423,
#     '100': 601,
#     '000': 440,
#     '101': 553,
#     '111': 593,
#     '110': 536},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'010': 451,
#     '011': 499,
#     '001': 423,
#     '100': 601,
#     '000': 440,
#     '101': 553,
#     '111': 593,
#     '110': 536},
#    'success_rate': 0.107421875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 3,
#    'num_gates': 1005,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 511,
#    'width': 11,
#    'size': 2026,
#    'count_ops': OrderedDict([('u', 414),
#                 ('x', 398),
#                 ('y', 374),
#                 ('t', 208),
#                 ('tdg', 208),
#                 ('s', 199),
#                 ('sdg', 199),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0ydh78z600082q470',
#    'counts': {'0111': 351,
#     '0100': 352,
#     '0010': 349,
#     '0011': 379,
#     '0001': 323,
#     '1110': 176,
#     '1010': 158,
#     '0101': 285,
#     '0110': 329,
#     '0000': 304,
#     '1101': 194,
#     '1000': 206,
#     '1001': 165,
#     '1011': 185,
#     '1100': 159,
#     '1111': 181},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0111': 351,
#     '0100': 352,
#     '0010': 349,
#     '0011': 379,
#     '0001': 323,
#     '1110': 176,
#     '1010': 158,
#     '0101': 285,
#     '0110': 329,
#     '0000': 304,
#     '1101': 194,
#     '1000': 206,
#     '1001': 165,
#     '1011': 185,
#     '1100': 159,
#     '1111': 181},
#    'success_rate': 0.07421875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1000,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 511,
#    'width': 11,
#    'size': 2028,
#    'count_ops': OrderedDict([('x', 430),
#                 ('y', 406),
#                 ('u', 352),
#                 ('t', 221),
#                 ('tdg', 221),
#                 ('s', 186),
#                 ('sdg', 186),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0ypt4raf0008ejvk0',
#    'counts': {'1111': 332,
#     '1000': 244,
#     '1101': 267,
#     '0011': 251,
#     '1110': 302,
#     '1001': 269,
#     '1011': 304,
#     '0010': 218,
#     '1010': 277,
#     '0111': 248,
#     '0100': 238,
#     '0101': 224,
#     '0001': 201,
#     '1100': 242,
#     '0000': 237,
#     '0110': 242},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1111': 332,
#     '1000': 244,
#     '1101': 267,
#     '0011': 251,
#     '1110': 302,
#     '1001': 269,
#     '1011': 304,
#     '0010': 218,
#     '1010': 277,
#     '0111': 248,
#     '0100': 238,
#     '0101': 224,
#     '0001': 201,
#     '1100': 242,
#     '0000': 237,
#     '0110': 242},
#    'success_rate': 0.057861328125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1001,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 511,
#    'width': 11,
#    'size': 2030,
#    'count_ops': OrderedDict([('y', 412),
#                 ('x', 408),
#                 ('u', 402),
#                 ('t', 207),
#                 ('tdg', 207),
#                 ('s', 184),
#                 ('sdg', 184),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0yzb78z600082q480',
#    'counts': {'0010': 283,
#     '1001': 197,
#     '1100': 182,
#     '0100': 313,
#     '0110': 296,
#     '1111': 218,
#     '1000': 178,
#     '1010': 193,
#     '1101': 210,
#     '0101': 401,
#     '0000': 275,
#     '1011': 196,
#     '0111': 302,
#     '1110': 176,
#     '0001': 364,
#     '0011': 312},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0010': 283,
#     '1001': 197,
#     '1100': 182,
#     '0100': 313,
#     '0110': 296,
#     '1111': 218,
#     '1000': 178,
#     '1010': 193,
#     '1101': 210,
#     '0101': 401,
#     '0000': 275,
#     '1011': 196,
#     '0111': 302,
#     '1110': 176,
#     '0001': 364,
#     '0011': 312},
#    'success_rate': 0.067138671875},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1002,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 511,
#    'width': 11,
#    'size': 2032,
#    'count_ops': OrderedDict([('u', 430),
#                 ('y', 400),
#                 ('x', 374),
#                 ('s', 207),
#                 ('sdg', 207),
#                 ('t', 194),
#                 ('tdg', 194),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0z8d38jq0008xxyyg',
#    'counts': {'0101': 247,
#     '1010': 260,
#     '0110': 303,
#     '0010': 262,
#     '0001': 253,
#     '1011': 239,
#     '1100': 245,
#     '1111': 295,
#     '1000': 242,
#     '1101': 243,
#     '0011': 229,
#     '1110': 257,
#     '1001': 268,
#     '0000': 245,
#     '0111': 270,
#     '0100': 238},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'0101': 247,
#     '1010': 260,
#     '0110': 303,
#     '0010': 262,
#     '0001': 253,
#     '1011': 239,
#     '1100': 245,
#     '1111': 295,
#     '1000': 242,
#     '1101': 243,
#     '0011': 229,
#     '1110': 257,
#     '1001': 268,
#     '0000': 245,
#     '0111': 270,
#     '0100': 238},
#    'success_rate': 0.059814453125},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1003,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 513,
#    'width': 11,
#    'size': 2034,
#    'count_ops': OrderedDict([('x', 422),
#                 ('u', 418),
#                 ('y', 412),
#                 ('t', 197),
#                 ('tdg', 197),
#                 ('s', 181),
#                 ('sdg', 181),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0zke38jq0008xxz00',
#    'counts': {'1110': 256,
#     '1011': 251,
#     '1001': 220,
#     '0000': 262,
#     '0100': 262,
#     '0001': 262,
#     '1100': 251,
#     '0111': 298,
#     '1101': 213,
#     '0101': 251,
#     '1000': 218,
#     '0110': 244,
#     '0010': 290,
#     '1010': 260,
#     '1111': 265,
#     '0011': 293},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1110': 256,
#     '1011': 251,
#     '1001': 220,
#     '0000': 262,
#     '0100': 262,
#     '0001': 262,
#     '1100': 251,
#     '0111': 298,
#     '1101': 213,
#     '0101': 251,
#     '1000': 218,
#     '0110': 244,
#     '0010': 290,
#     '1010': 260,
#     '1111': 265,
#     '0011': 293},
#    'success_rate': 0.06396484375},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1004,
#    'execution_type': 'ibm'}},
#  {'status': 'completed',
#   'circuit_metrics': {'depth': 513,
#    'width': 11,
#    'size': 2036,
#    'count_ops': OrderedDict([('x', 400),
#                 ('u', 398),
#                 ('y', 390),
#                 ('s', 215),
#                 ('sdg', 215),
#                 ('t', 196),
#                 ('tdg', 196),
#                 ('cx', 11),
#                 ('h', 10),
#                 ('measure', 4),
#                 ('cz', 1)])},
#   'config_metrics': {'payload_size': 4},
#   'ibm_data': {'status': 'completed',
#    'job_id': 'cyv0zwqjj6dg008g4b1g',
#    'counts': {'1100': 252,
#     '0011': 267,
#     '1110': 270,
#     '0110': 236,
#     '1101': 237,
#     '1000': 276,
#     '1001': 247,
#     '1111': 239,
#     '0010': 245,
#     '0000': 257,
#     '1010': 270,
#     '0001': 239,
#     '0100': 265,
#     '1011': 245,
#     '0111': 273,
#     '0101': 278},
#    'backend': 'ibm_kyiv'},
#   'results_metrics': {'counts': {'1100': 252,
#     '0011': 267,
#     '1110': 270,
#     '0110': 236,
#     '1101': 237,
#     '1000': 276,
#     '1001': 247,
#     '1111': 239,
#     '0010': 245,
#     '0000': 257,
#     '1010': 270,
#     '0001': 239,
#     '0100': 265,
#     '1011': 245,
#     '0111': 273,
#     '0101': 278},
#    'success_rate': 0.062744140625},
#   'experiment_params': {'experiment_type': 'dynamic_payload_gates',
#    'payload_size': 4,
#    'num_gates': 1005,
#    'execution_type': 'ibm'}}]

# %%
experiments.plot_success_rates()
