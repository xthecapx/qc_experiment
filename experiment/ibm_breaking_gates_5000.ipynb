# %%
# %load_ext autoreload
# %autoreload 2

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(5000, 5005),
    run_on_ibm=True,
    show_circuit=False
)
# Out:
# Running experiment with payload_size=1 and gates=5000
# ibm_sherbrooke
# 5
# >>> Job ID: cz4sg8hh0kc00088xsng
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 1892, '0': 2204}
# Experiment with payload=1, gates=5000 completed with status: completed
#
# Running experiment with payload_size=1 and gates=5001
# ibm_sherbrooke
# 7
# >>> Job ID: cz4sggt1xvhg008e8hz0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2018, '1': 2078}
# Experiment with payload=1, gates=5001 completed with status: completed
#
# Running experiment with payload_size=1 and gates=5002
# ibm_sherbrooke
# 7
# >>> Job ID: cz4sgtb39f40008se0ag
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2116, '0': 1980}
# Experiment with payload=1, gates=5002 completed with status: completed
#
# Running experiment with payload_size=1 and gates=5003
# ibm_sherbrooke
# 5
# >>> Job ID: cz4sh3mh0kc00088xsv0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1987, '1': 2109}
# Experiment with payload=1, gates=5003 completed with status: completed
#
# Running experiment with payload_size=1 and gates=5004
# ibm_sherbrooke
# 5
# >>> Job ID: cz4shexh0kc00088xsy0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1964, '1': 2132}
# Experiment with payload=1, gates=5004 completed with status: completed
#
# Running experiment with payload_size=1 and gates=5005
# ibm_sherbrooke
# 5
# >>> Job ID: cz4shzfkvm9g008g83zg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2049, '1': 2047}
# Experiment with payload=1, gates=5005 completed with status: completed
#
# Running experiment with payload_size=2 and gates=5000
# ibm_brisbane
# 10
# >>> Job ID: cz4sja9p6030008cfwf0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1078, '01': 1132, '11': 953, '10': 933}
# Experiment with payload=2, gates=5000 completed with status: completed
#
# Running experiment with payload_size=2 and gates=5001
# ibm_sherbrooke
# 8
# >>> Job ID: cz4sjja39f40008se0r0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1115, '01': 1058, '10': 930, '11': 993}
# Experiment with payload=2, gates=5001 completed with status: completed
#
# Running experiment with payload_size=2 and gates=5002
# ibm_brisbane
# 6
# >>> Job ID: cz4sk6wkvm9g008g849g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 782, '00': 1635, '10': 983, '11': 696}
# Experiment with payload=2, gates=5002 completed with status: completed
#
# Running experiment with payload_size=2 and gates=5003
# ibm_sherbrooke
# 8
# >>> Job ID: cz4sm1rh0kc00088xtg0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 1138, '10': 899, '00': 1104, '11': 955}
# Experiment with payload=2, gates=5003 completed with status: completed
#
# Running experiment with payload_size=2 and gates=5004
# ibm_sherbrooke
# 8
# >>> Job ID: cz4smcs39f40008se100
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'00': 1018, '01': 1089, '11': 1020, '10': 969}
# Experiment with payload=2, gates=5004 completed with status: completed
#
# Running experiment with payload_size=2 and gates=5005
# ibm_sherbrooke
# 6
# >>> Job ID: cz4smna10wx0008bgr8g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 964, '10': 1091, '11': 942, '00': 1099}
# Experiment with payload=2, gates=5005 completed with status: completed
#
# Running experiment with payload_size=3 and gates=5000
# ibm_brisbane
# 7
# >>> Job ID: cz4smxvh0kc00088xtq0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# WARNING:urllib3.connectionpool:Retrying (PostForcelistRetry(total=4, connect=3, read=None, redirect=None, status=None)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /runtime/jobs/cz4smxvh0kc00088xtq0?exclude_params=true
# WARNING:urllib3.connectionpool:Retrying (PostForcelistRetry(total=3, connect=2, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0xffff2cb5dc10>, 'Connection to api.quantum.ibm.com timed out. (connect timeout=5.0)')': /runtime/jobs/cz4smxvh0kc00088xtq0?exclude_params=true
# WARNING:urllib3.connectionpool:Retrying (PostForcelistRetry(total=2, connect=1, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0xffff2ceea310>, 'Connection to api.quantum.ibm.com timed out. (connect timeout=5.0)')': /runtime/jobs/cz4smxvh0kc00088xtq0?exclude_params=true
# WARNING:urllib3.connectionpool:Retrying (PostForcelistRetry(total=1, connect=0, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0xffff2c8989d0>: Failed to resolve 'api.quantum.ibm.com' ([Errno -3] Temporary failure in name resolution)")': /runtime/jobs/cz4smxvh0kc00088xtq0?exclude_params=true
# >>> Job Status: DONE
# {'011': 553, '001': 437, '100': 498, '111': 637, '110': 440, '101': 520, '000': 550, '010': 461}
# Experiment with payload=3, gates=5000 completed with status: completed
#
# Running experiment with payload_size=3 and gates=5001
# ibm_brisbane
# 6
# >>> Job ID: cz4snx7p6030008cfx10
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'011': 532, '001': 451, '000': 614, '010': 455, '111': 568, '110': 437, '101': 434, '100': 605}
# Experiment with payload=3, gates=5001 completed with status: completed
#
# Running experiment with payload_size=3 and gates=5002
# ibm_sherbrooke
# 7
# >>> Job ID: cz4sr2r39f40008se1kg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'001': 491, '110': 490, '100': 487, '000': 505, '111': 563, '010': 521, '011': 560, '101': 479}
# Experiment with payload=3, gates=5002 completed with status: completed
#
# Running experiment with payload_size=3 and gates=5003
# ibm_brisbane
# 6
# >>> Job ID: cz4srb910wx0008bgrx0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'100': 512, '110': 447, '010': 478, '111': 523, '011': 634, '001': 502, '101': 486, '000': 514}
# Experiment with payload=3, gates=5003 completed with status: completed
#
# Running experiment with payload_size=3 and gates=5004
# ibm_sherbrooke
# 9
# >>> Job ID: cz4srrv1xvhg008e8k7g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'100': 548, '110': 514, '010': 489, '011': 467, '111': 485, '000': 573, '101': 475, '001': 545}
# Experiment with payload=3, gates=5004 completed with status: completed
#
# Running experiment with payload_size=3 and gates=5005
# ibm_brisbane
# 8
# >>> Job ID: cz4ss2c10wx0008bgs2g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 449, '000': 573, '100': 482, '001': 490, '101': 486, '011': 576, '010': 457, '111': 583}
# Experiment with payload=3, gates=5005 completed with status: completed
#
# Running experiment with payload_size=4 and gates=5000
# ibm_kyiv
# 10
# >>> Job ID: cz4svr7kvm9g008g85v0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0000': 244, '1001': 275, '0100': 298, '1010': 275, '0010': 237, '1011': 265, '0110': 261, '0001': 235, '1111': 250, '0111': 250, '1101': 278, '1000': 272, '0101': 244, '0011': 221, '1110': 267, '1100': 224}
# Experiment with payload=4, gates=5000 completed with status: completed
#
# Running experiment with payload_size=4 and gates=5001
# ibm_sherbrooke
# 5
# >>> Job ID: cz4svzz1xvhg008e8kj0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0011': 236, '1010': 260, '1111': 272, '0111': 268, '0010': 236, '1110': 233, '0101': 275, '1001': 295, '1100': 266, '0001': 211, '0110': 270, '1000': 252, '0100': 228, '1011': 279, '0000': 234, '1101': 281}
# Experiment with payload=4, gates=5001 completed with status: completed
#
# Running experiment with payload_size=4 and gates=5002
# ibm_sherbrooke
# 5
# >>> Job ID: cz4sw8139f40008se280
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0101': 231, '1000': 309, '0010': 205, '0100': 262, '1010': 210, '0111': 319, '0011': 285, '1110': 190, '1101': 204, '0000': 317, '1011': 290, '0110': 233, '1001': 247, '1100': 309, '0001': 227, '1111': 258}
# Experiment with payload=4, gates=5002 completed with status: completed
#
# Running experiment with payload_size=4 and gates=5003
# ibm_sherbrooke
# 5
# >>> Job ID: cz4swg2h0kc00088xw00
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0100': 244, '1100': 226, '1111': 272, '1000': 241, '1101': 316, '1001': 261, '1110': 242, '1011': 235, '0111': 260, '1010': 286, '0000': 232, '0010': 292, '0001': 240, '0011': 205, '0110': 274, '0101': 270}
# Experiment with payload=4, gates=5003 completed with status: completed
#
# Running experiment with payload_size=4 and gates=5004
# ibm_sherbrooke
# 5
# >>> Job ID: cz4swr310wx0008bgsn0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1111': 268, '0001': 292, '1100': 258, '1011': 233, '1110': 236, '0011': 264, '1000': 231, '1001': 241, '0010': 304, '0100': 245, '1101': 259, '0111': 250, '0000': 300, '0101': 235, '0110': 257, '1010': 223}
# Experiment with payload=4, gates=5004 completed with status: completed
#
# Running experiment with payload_size=4 and gates=5005
# ibm_sherbrooke
# 5
# >>> Job ID: cz4sx0c39f40008se2c0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0101': 204, '0100': 297, '1110': 252, '1011': 266, '0011': 260, '0111': 258, '0000': 278, '1001': 266, '0010': 284, '0001': 226, '1100': 195, '1010': 212, '1111': 317, '1101': 268, '1000': 235, '0110': 278}
# Experiment with payload=4, gates=5005 completed with status: completed
# Results exported to experiment_results_dynamic_1-4_5000-5005_20250306_131017.csv
#        status  circuit_depth  circuit_width  circuit_size  \
# 0   completed          10005              5         10011
# 1   completed          10007              5         10013
# 2   completed          10009              5         10015
# 3   completed          10011              5         10017
# 4   completed          10013              5         10019
# 5   completed          10015              5         10021
# 6   completed           5007              7         10016
# 7   completed           5007              7         10018
# 8   completed           5009              7         10020
# 9   completed           5009              7         10022
# 10  completed           5011              7         10024
# 11  completed           5011              7         10026
# 12  completed           3341              9         10021
# 13  completed           3343              9         10023
# 14  completed           3343              9         10025
# 15  completed           3343              9         10027
# 16  completed           3345              9         10029
# 17  completed           3345              9         10031
# 18  completed           2511             11         10026
# 19  completed           2511             11         10028
# 20  completed           2511             11         10030
# 21  completed           2511             11         10032
# 22  completed           2513             11         10034
# 23  completed           2513             11         10036
#
#                                     circuit_count_ops  num_qubits  num_clbits  \
# 0   {"y": 2036, "x": 2026, "u": 2014, "t": 1013, "...           4           1
# 1   {"x": 2116, "y": 1978, "u": 1888, "s": 1012, "...           4           1
# 2   {"y": 2036, "x": 1966, "u": 1886, "s": 1081, "...           4           1
# 3   {"u": 2060, "y": 2048, "x": 1918, "s": 1050, "...           4           1
# 4   {"y": 2036, "u": 2006, "x": 2006, "s": 1013, "...           4           1
# 5   {"y": 2050, "u": 2014, "x": 1958, "t": 999, "t...           4           1
# 6   {"u": 2080, "y": 2056, "x": 1954, "t": 979, "t...           5           2
# 7   {"x": 2048, "u": 2046, "y": 1878, "t": 1034, "...           5           2
# 8   {"x": 2094, "u": 1970, "y": 1962, "t": 996, "t...           5           2
# 9   {"y": 2080, "u": 1900, "x": 1896, "s": 1038, "...           5           2
# 10  {"u": 2046, "y": 1994, "x": 1822, "s": 1060, "...           5           2
# 11  {"u": 2010, "x": 1990, "y": 1956, "s": 1030, "...           5           2
# 12  {"u": 2044, "y": 2032, "x": 1972, "t": 1016, "...           6           3
# 13  {"y": 1996, "x": 1964, "u": 1948, "s": 1029, "...           6           3
# 14  {"u": 2048, "y": 2044, "x": 1894, "t": 1009, "...           6           3
# 15  {"u": 2012, "x": 1986, "y": 1942, "t": 1045, "...           6           3
# 16  {"y": 2050, "u": 2010, "x": 1984, "t": 1014, "...           6           3
# 17  {"u": 2008, "x": 1986, "y": 1956, "s": 1027, "...           6           3
# 18  {"u": 2020, "x": 1958, "y": 1940, "t": 1035, "...           7           4
# 19  {"u": 2070, "y": 1982, "x": 1974, "t": 1008, "...           7           4
# 20  {"y": 2034, "u": 2006, "x": 2004, "s": 1003, "...           7           4
# 21  {"y": 2050, "x": 2034, "u": 1932, "t": 1006, "...           7           4
# 22  {"y": 2078, "x": 1966, "u": 1964, "s": 1015, "...           7           4
# 23  {"u": 2040, "y": 2022, "x": 2010, "s": 987, "s...           7           4
#
#     num_ancillas  num_parameters  has_calibrations  has_layout  payload_size  \
# 0              0               0             False       False             1
# 1              0               0             False       False             1
# 2              0               0             False       False             1
# 3              0               0             False       False             1
# 4              0               0             False       False             1
# 5              0               0             False       False             1
# 6              0               0             False       False             2
# 7              0               0             False       False             2
# 8              0               0             False       False             2
# 9              0               0             False       False             2
# 10             0               0             False       False             2
# 11             0               0             False       False             2
# 12             0               0             False       False             3
# 13             0               0             False       False             3
# 14             0               0             False       False             3
# 15             0               0             False       False             3
# 16             0               0             False       False             3
# 17             0               0             False       False             3
# 18             0               0             False       False             4
# 19             0               0             False       False             4
# 20             0               0             False       False             4
# 21             0               0             False       False             4
# 22             0               0             False       False             4
# 23             0               0             False       False             4
#
#     num_gates execution_type        experiment_type  \
# 0        5000            ibm  dynamic_payload_gates
# 1        5001            ibm  dynamic_payload_gates
# 2        5002            ibm  dynamic_payload_gates
# 3        5003            ibm  dynamic_payload_gates
# 4        5004            ibm  dynamic_payload_gates
# 5        5005            ibm  dynamic_payload_gates
# 6        5000            ibm  dynamic_payload_gates
# 7        5001            ibm  dynamic_payload_gates
# 8        5002            ibm  dynamic_payload_gates
# 9        5003            ibm  dynamic_payload_gates
# 10       5004            ibm  dynamic_payload_gates
# 11       5005            ibm  dynamic_payload_gates
# 12       5000            ibm  dynamic_payload_gates
# 13       5001            ibm  dynamic_payload_gates
# 14       5002            ibm  dynamic_payload_gates
# 15       5003            ibm  dynamic_payload_gates
# 16       5004            ibm  dynamic_payload_gates
# 17       5005            ibm  dynamic_payload_gates
# 18       5000            ibm  dynamic_payload_gates
# 19       5001            ibm  dynamic_payload_gates
# 20       5002            ibm  dynamic_payload_gates
# 21       5003            ibm  dynamic_payload_gates
# 22       5004            ibm  dynamic_payload_gates
# 23       5005            ibm  dynamic_payload_gates
#
#                                                counts  success_rate  \
# 0                              {"1": 1892, "0": 2204}      0.538086
# 1                              {"0": 2018, "1": 2078}      0.492676
# 2                              {"1": 2116, "0": 1980}      0.483398
# 3                              {"0": 1987, "1": 2109}      0.485107
# 4                              {"0": 1964, "1": 2132}      0.479492
# 5                              {"0": 2049, "1": 2047}      0.500244
# 6      {"00": 1078, "01": 1132, "11": 953, "10": 933}      0.263184
# 7      {"00": 1115, "01": 1058, "10": 930, "11": 993}      0.272217
# 8       {"01": 782, "00": 1635, "10": 983, "11": 696}      0.399170
# 9      {"01": 1138, "10": 899, "00": 1104, "11": 955}      0.269531
# 10    {"00": 1018, "01": 1089, "11": 1020, "10": 969}      0.248535
# 11     {"01": 964, "10": 1091, "11": 942, "00": 1099}      0.268311
# 12  {"011": 553, "001": 437, "100": 498, "111": 63...      0.134277
# 13  {"011": 532, "001": 451, "000": 614, "010": 45...      0.149902
# 14  {"001": 491, "110": 490, "100": 487, "000": 50...      0.123291
# 15  {"100": 512, "110": 447, "010": 478, "111": 52...      0.125488
# 16  {"100": 548, "110": 514, "010": 489, "011": 46...      0.139893
# 17  {"110": 449, "000": 573, "100": 482, "001": 49...      0.139893
# 18  {"0000": 244, "1001": 275, "0100": 298, "1010"...      0.059570
# 19  {"0011": 236, "1010": 260, "1111": 272, "0111"...      0.057129
# 20  {"0101": 231, "1000": 309, "0010": 205, "0100"...      0.077393
# 21  {"0100": 244, "1100": 226, "1111": 272, "1000"...      0.056641
# 22  {"1111": 268, "0001": 292, "1100": 258, "1011"...      0.073242
# 23  {"0101": 204, "0100": 297, "1110": 252, "1011"...      0.067871
#
#               ibm_job_id     ibm_backend
# 0   cz4sg8hh0kc00088xsng  ibm_sherbrooke
# 1   cz4sggt1xvhg008e8hz0  ibm_sherbrooke
# 2   cz4sgtb39f40008se0ag  ibm_sherbrooke
# 3   cz4sh3mh0kc00088xsv0  ibm_sherbrooke
# 4   cz4shexh0kc00088xsy0  ibm_sherbrooke
# 5   cz4shzfkvm9g008g83zg  ibm_sherbrooke
# 6   cz4sja9p6030008cfwf0    ibm_brisbane
# 7   cz4sjja39f40008se0r0  ibm_sherbrooke
# 8   cz4sk6wkvm9g008g849g    ibm_brisbane
# 9   cz4sm1rh0kc00088xtg0  ibm_sherbrooke
# 10  cz4smcs39f40008se100  ibm_sherbrooke
# 11  cz4smna10wx0008bgr8g  ibm_sherbrooke
# 12  cz4smxvh0kc00088xtq0    ibm_brisbane
# 13  cz4snx7p6030008cfx10    ibm_brisbane
# 14  cz4sr2r39f40008se1kg  ibm_sherbrooke
# 15  cz4srb910wx0008bgrx0    ibm_brisbane
# 16  cz4srrv1xvhg008e8k7g  ibm_sherbrooke
# 17  cz4ss2c10wx0008bgs2g    ibm_brisbane
# 18  cz4svr7kvm9g008g85v0        ibm_kyiv
# 19  cz4svzz1xvhg008e8kj0  ibm_sherbrooke
# 20  cz4sw8139f40008se280  ibm_sherbrooke
# 21  cz4swg2h0kc00088xw00  ibm_sherbrooke
# 22  cz4swr310wx0008bgsn0  ibm_sherbrooke
# 23  cz4sx0c39f40008se2c0  ibm_sherbrooke

# %%
from teleportation_validator import Experiments

experiments = Experiments()
updated_df = experiments.update_table_with_job_info('experiment_results_dynamic_1-4_5000-5005_20250306_131017.csv')
# Out:
# Updated job cz4sg8hh0kc00088xsng information
# Updated job cz4sggt1xvhg008e8hz0 information
# Updated job cz4sgtb39f40008se0ag information
# Updated job cz4sh3mh0kc00088xsv0 information
# Updated job cz4shexh0kc00088xsy0 information
# Updated job cz4shzfkvm9g008g83zg information
# Updated job cz4sja9p6030008cfwf0 information
# Updated job cz4sjja39f40008se0r0 information
# Updated job cz4sk6wkvm9g008g849g information
# Updated job cz4sm1rh0kc00088xtg0 information
# Updated job cz4smcs39f40008se100 information
# Updated job cz4smna10wx0008bgr8g information
# Updated job cz4smxvh0kc00088xtq0 information
# Updated job cz4snx7p6030008cfx10 information
# Updated job cz4sr2r39f40008se1kg information
# Updated job cz4srb910wx0008bgrx0 information
# Updated job cz4srrv1xvhg008e8k7g information
# Updated job cz4ss2c10wx0008bgs2g information
# Updated job cz4svr7kvm9g008g85v0 information
# Updated job cz4svzz1xvhg008e8kj0 information
# Updated job cz4sw8139f40008se280 information
# Updated job cz4swg2h0kc00088xw00 information
# Updated job cz4swr310wx0008bgsn0 information
# Updated job cz4sx0c39f40008se2c0 information
# Updated results saved to experiment_results_dynamic_1-4_5000-5005_20250306_131017_updated.csv
