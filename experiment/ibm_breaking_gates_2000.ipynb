# %%
# %load_ext autoreload
# %autoreload 2

# %%
channel='ibm_quantum'
token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86'

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(2000, 2005),
    run_on_ibm=True,
    channel=channel,
    token=token
)
# Out:
# Running experiment with payload_size=1 and gates=2000
# ibm_kyiv
# 5
# >>> Job ID: cyv1bj6jj6dg008g4bvg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2065, '1': 2031}
# Experiment with payload=1, gates=2000 completed with status: completed
#
# Running experiment with payload_size=1 and gates=2001
# ibm_kyiv
# 5
# >>> Job ID: cyv1bvfq5bwg0083p1hg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2037, '1': 2059}
# Experiment with payload=1, gates=2001 completed with status: completed
#
# Running experiment with payload_size=1 and gates=2002
# ibm_kyiv
# 5
# >>> Job ID: cyv1cah78z600082q590
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# ...

# %%
experiments.plot_success_rates()
