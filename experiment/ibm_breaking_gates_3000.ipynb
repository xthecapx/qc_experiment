# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# ibm_quantum
# 09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from teleportation_validator import Experiments
experiments = Experiments()

experiments.run_dynamic_payload_gates(
    payload_range=(1, 4),
    gates_range=(3000, 3005),
    run_on_ibm=True,
    show_circuit=False
)

# Total runtime used 1 min 20 seg
# Out:
# Running experiment with payload_size=1 and gates=3000
# ibm_brisbane
# 9
# >>> Job ID: cz33cja1xvhg008dzr90
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2000, '0': 2096}
# Experiment with payload=1, gates=3000 completed with status: completed
#
# Running experiment with payload_size=1 and gates=3001
# ibm_brisbane
# 9
# >>> Job ID: cz33czvh0kc00088mwng
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2174, '1': 1922}
# Experiment with payload=1, gates=3001 completed with status: completed
#
# Running experiment with payload_size=1 and gates=3002
# ibm_brisbane
# 9
# >>> Job ID: cz33danh0kc00088mwrg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# ...

# %%
experiments.plot_success_rates()

# %%
from teleportation_validator import TeleportationValidator

validator = TeleportationValidator(payload_size=1, gates=['s'], use_barriers=True)
validator.get_ibm_job_results(job_id='cz343wzkvm9g008fzctg')
# Out:
# ibm_quantum cz343wzkvm9g008fzctg
#
# Measurement Counts:
# {'0111': 234, '1111': 234, '0001': 233, '1101': 241, '1110': 229, '0000': 244, '0010': 273, '0110': 251, '0011': 295, '1001': 257, '1000': 282, '0100': 243, '0101': 242, '1010': 320, '1011': 313, '1100': 205}
# Success Rate: 5.96%
# {'counts': {'0111': 234,
#   '1111': 234,
#   '0001': 233,
#   '1101': 241,
#   '1110': 229,
#   '0000': 244,
#   '0010': 273,
#   '0110': 251,
#   '0011': 295,
#   '1001': 257,
#   '1000': 282,
#   '0100': 243,
#   '0101': 242,
#   '1010': 320,
#   '1011': 313,
#   '1100': 205},
#  'success_rate': 0.0595703125,
#  'circuit_depth': 13,
#  'circuit_width': 5,
#  'circuit_size': 13,
#  'circuit_count_ops': OrderedDict([('barrier', 6),
#               ('cx', 5),
#               ('h', 4),
#               ('s', 1),
#               ('cz', 1),
#               ('sdg', 1),
#               ('measure', 1)]),
#  'num_qubits': 4,
#  'num_clbits': 1,
#  'num_ancillas': 0,
#  'num_parameters': 0,
# ...
