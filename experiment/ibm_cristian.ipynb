# %%
# %load_ext autoreload
# %autoreload 2

# %%
channel='ibm_quantum'
token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86'

# %% [markdown]
# # simulation

# %%
from teleportation_validator import Experiments
experiments = Experiments()

# %%
experiments.run_payload_size_gates_correlation(start=1, end=3, channel=channel, token=token)
# Out:
# Running experiment with payload_size=1 and gates=1
# Experiment 1/3 completed with status: completed
#
# Running experiment with payload_size=2 and gates=2
# Experiment 2/3 completed with status: completed
#
# Running experiment with payload_size=3 and gates=3
# Experiment 3/3 completed with status: completed
# [{'results_metrics': {'counts': {'0': 1024}, 'success_rate': 1.0},
#   'circuit_metrics': {'depth': 13,
#    'width': 5,
#    'size': 13,
#    'count_ops': OrderedDict([('barrier', 6),
#                 ('cx', 5),
#                 ('h', 4),
#                 ('x', 2),
#                 ('cz', 1),
#                 ('measure', 1)])},
#   'config_metrics': {'payload_size': 1},
#   'custom_gate_distribution': {'x': 1},
#   'status': 'completed',
#   'experiment_params': {'experiment_type': 'payload_size_gates_correlation',
#    'payload_size': 1,
#    'num_gates': 1,
#    'execution_type': 'simulation'}},
#  {'results_metrics': {'counts': {'00': 1024}, 'success_rate': 1.0},
# ...

# %% [markdown]
# # run_payload_size_gates_correlation 1 - 3 qubits & 1 - 3 gates

# %%
experiments.run_payload_size_gates_correlation(start=1, end=3, channel=channel, token=token, run_on_ibm=True)
# Out:
# Running experiment with payload_size=1 and gates=1
# ibm_brisbane
# 14
# >>> Job ID: cytazjyq5bwg0083hsqg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 1680, '1': 2416}
# Experiment 1/3 completed with status: completed
#
# Running experiment with payload_size=2 and gates=2
# ibm_brisbane
# 11
# >>> Job ID: cytazvqy2gd000881xtg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'01': 1169, '11': 927, '10': 838, '00': 1162}
# Experiment 2/3 completed with status: completed
#
# Running experiment with payload_size=3 and gates=3
# ibm_brisbane
# 10
# >>> Job ID: cytb03878z600082jw8g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'110': 423, '100': 485, '011': 516, '001': 584, '000': 618, '101': 542, '010': 437, '111': 491}
# Experiment 3/3 completed with status: completed
# ...

# %%
experiments.plot_success_rates()

# %% [markdown]
# # run_fixed_payload_varying_gates 15 - 20

# %%
from teleportation_validator import Experiments
experiments = Experiments()

# %%
experiments.run_fixed_payload_varying_gates(payload_size=1, start_gates=15, end_gates=20, run_on_ibm=True, channel=channel, token=token)
# Out:
# Running experiment with payload_size=1 and gates=15
# ibm_brisbane
# 12
# >>> Job ID: cytb3z7y2gd000881yy0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2312, '0': 1784}
# Experiment 15/20 completed with status: completed
#
# Running experiment with payload_size=1 and gates=16
# ibm_brisbane
# 11
# >>> Job ID: cytb48hq5bwg0083hv0g
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 671, '0': 3425}
# Experiment 16/20 completed with status: completed
#
# Running experiment with payload_size=1 and gates=17
# ibm_brisbane
# 11
# >>> Job ID: cytb4j278z600082jxvg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2318, '0': 1778}
# Experiment 17/20 completed with status: completed
#
# ...

# %%
experiments.plot_success_rates()

# %% [markdown]
# # run_fixed_payload_varying_gates 20 - 30

# %%
from teleportation_validator import Experiments
experiments = Experiments()

# %%
experiments.run_fixed_payload_varying_gates(payload_size=1, start_gates=20, end_gates=30, run_on_ibm=True, channel=channel, token=token)
# Out:
# Running experiment with payload_size=1 and gates=20
# ibm_brisbane
# 10
# >>> Job ID: cytb9fnjj6dg008g0590
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3370, '1': 726}
# Experiment 20/30 completed with status: completed
#
# Running experiment with payload_size=1 and gates=21
# ibm_brisbane
# 11
# >>> Job ID: cytb9pyjj6dg008g05c0
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2318, '0': 1778}
# Experiment 21/30 completed with status: completed
#
# Running experiment with payload_size=1 and gates=22
# ibm_brisbane
# 11
# >>> Job ID: cytba8978z600082k0yg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'1': 2350, '0': 1746}
# Experiment 22/30 completed with status: completed
#
# ...

# %%
experiments.plot_success_rates()
