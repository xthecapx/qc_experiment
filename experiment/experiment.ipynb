# %%
# %load_ext autoreload
# %autoreload 2

# %%
from teleportation_validator import TeleportationValidator

validator = TeleportationValidator(payload_size=1, num_gates=1, gates=['s'], use_barriers=True)

# %%
validator.draw()

# %%
validator.plot_results()

# %%
channel='ibm_quantum'
token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86'

# %% [markdown]
# # Test gates=['s', 't'] and 2 qubits

# %%
from teleportation_validator import TeleportationValidator

validator = TeleportationValidator(payload_size=2, num_gates=2, gates=['s', 't'], use_barriers=False)

# %%
validator.draw()

# %%
validator.plot_results()

# %%
channel='ibm_quantum'
token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86'

validator.run_on_ibm(channel=channel, token=token)
# Out:
# ibm_kyiv
# 4
# >>> Job ID: cycn1p6rta1g0087vv5g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# ({'10': 864, '00': 946, '01': 1051, '11': 1235},
#  <qiskit.circuit.quantumcircuit.QuantumCircuit at 0xffffab473590>)

# %%
validator.get_job_results(
    token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86',
    job_id='cycn1p6rta1g0087vv5g'
)
# Out:
# Measurement Counts:
# {'10': 864, '00': 946, '01': 1051, '11': 1235}
# Circuit Metrics:
# Circuit depth: 11
# Circuit width: 7
# Total number of operations: 24
# Operation distribution: OrderedDict([('cx', 7), ('h', 6), ('s', 2), ('t', 2), ('tdg', 2), ('sdg', 2), ('measure', 2), ('cz', 1)])
#
# Success Rate: 23.10%
# {'counts': {'10': 864, '00': 946, '01': 1051, '11': 1235},
#  'depth': 11,
#  'width': 7,
#  'size': 24,
#  'operations': OrderedDict([('cx', 7),
#               ('h', 6),
#               ('s', 2),
#               ('t', 2),
#               ('tdg', 2),
#               ('sdg', 2),
#               ('measure', 2),
#               ('cz', 1)]),
#  'success_rate': 0.23095703125,
# ...

# %% [markdown]
# # Test gates=['s', 't'] and single qubit

# %%
validator = TeleportationValidator(payload_size=1, gates=['s', 't'], use_barriers=True)

# %%
validator.draw()

# %%
channel='ibm_quantum'
token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86'

validator.run_on_ibm(channel=channel, token=token)
# Out:
# ibm_kyiv
# 3
# >>> Job ID: cycn4nanrmz00086ad20
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# ({'0': 1622, '1': 2474},
#  <qiskit.circuit.quantumcircuit.QuantumCircuit at 0xffff4554c510>)

# %%
validator.get_job_results(
    token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86',
    job_id='cycn4nanrmz00086ad20'
)
# Out:
# Measurement Counts:
# {'0': 1622, '1': 2474}
# Circuit Metrics:
# Circuit depth: 15
# Circuit width: 5
# Total number of operations: 15
# Operation distribution: OrderedDict([('barrier', 6), ('cx', 5), ('h', 4), ('s', 1), ('t', 1), ('cz', 1), ('tdg', 1), ('sdg', 1), ('measure', 1)])
#
# Success Rate: 39.60%
# {'counts': {'0': 1622, '1': 2474},
#  'depth': 15,
#  'width': 5,
#  'size': 15,
#  'operations': OrderedDict([('barrier', 6),
#               ('cx', 5),
#               ('h', 4),
#               ('s', 1),
#               ('t', 1),
#               ('cz', 1),
#               ('tdg', 1),
#               ('sdg', 1),
#               ('measure', 1)]),
#  'success_rate': 0.39599609375,
# ...

# %% [markdown]
# # Test gates=['s'] and single qubit

# %%
validator = TeleportationValidator(payload_size=1, gates=['s'], use_barriers=False)

# %%
validator.draw()

# %%
channel='ibm_quantum'
token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86'

validator.run_on_ibm(channel=channel, token=token)
# Out:
# ibm_kyiv
# 4
# >>> Job ID: cycn5tzcw2k0008kmy2g
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# ({'1': 1632, '0': 2464},
#  <qiskit.circuit.quantumcircuit.QuantumCircuit at 0xffff45dbd810>)

# %%
validator.get_job_results(
    token='09cb2b78ef9fd33cd55f3561fa211ef84758bb76b94d26344e958fc53483dd16c781f631a59733f5ec36c4cbe82b2a6ac7bc8019b689457171dbd10f63025b86',
    job_id='cycn5tzcw2k0008kmy2g'
)
# Out:
# Measurement Counts:
# {'1': 1632, '0': 2464}
# Circuit Metrics:
# Circuit depth: 8
# Circuit width: 5
# Total number of operations: 13
# Operation distribution: OrderedDict([('cx', 5), ('h', 4), ('s', 1), ('cz', 1), ('sdg', 1), ('measure', 1)])
#
# Success Rate: 60.16%
# {'counts': {'1': 1632, '0': 2464},
#  'depth': 8,
#  'width': 5,
#  'size': 13,
#  'operations': OrderedDict([('cx', 5),
#               ('h', 4),
#               ('s', 1),
#               ('cz', 1),
#               ('sdg', 1),
#               ('measure', 1)]),
#  'success_rate': 0.6015625,
#  'job_result': PrimitiveResult([SamplerPubResult(data=DataBin(test_result=BitArray(<shape=(), num_shots=4096, num_bits=1>)), metadata={'circuit_metadata': {}})], metadata={'execution': {'execution_spans': ExecutionSpans([SliceSpan(<start='2025-01-28 21:58:06', stop='2025-01-28 21:58:16', size=4096>)])}, 'version': 2})}

# %% [markdown]
# # New Test

# %%
from teleportation_validator import TeleportationValidator

validator = TeleportationValidator(payload_size=1, gates=['s'], use_barriers=False)

# %%
validator.draw()

# %%
validator.plot_results()

# %%
validator.run_on_ibm(channel=channel, token=token)
# Out:
# ibm_sherbrooke
# 1
# >>> Job ID: cyd8ctvrta1g0087yabg
# >>> Job Status: QUEUED
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 3154, '1': 942}
# ({'0': 3154, '1': 942},
#  <qiskit.circuit.quantumcircuit.QuantumCircuit at 0xffff348a3cd0>)

# %%
validator.get_job_results(
    token=token,
    job_id='cyd8ctvrta1g0087yabg'
)
# Out:
# Measurement Counts:
# {'0': 3154, '1': 942}
# Circuit Metrics:
# Circuit depth: 8
# Circuit width: 5
# Total number of operations: 13
# Operation distribution: OrderedDict([('cx', 5), ('h', 4), ('s', 1), ('cz', 1), ('sdg', 1), ('measure', 1)])
#
# Success Rate: 77.00%
# {'counts': {'0': 3154, '1': 942},
#  'depth': 8,
#  'width': 5,
#  'size': 13,
#  'operations': OrderedDict([('cx', 5),
#               ('h', 4),
#               ('s', 1),
#               ('cz', 1),
#               ('sdg', 1),
#               ('measure', 1)]),
#  'success_rate': 0.77001953125,
#  'job_result': PrimitiveResult([SamplerPubResult(data=DataBin(test_result=BitArray(<shape=(), num_shots=4096, num_bits=1>)), metadata={'circuit_metadata': {}})], metadata={'execution': {'execution_spans': ExecutionSpans([SliceSpan(<start='2025-01-29 19:50:07', stop='2025-01-29 19:51:03', size=4096>)])}, 'version': 2})}

# %% [markdown]
# # Test Pedro/Kelly

# %%
from teleportation_validator import TeleportationValidator

validator = TeleportationValidator(payload_size=1, num_gates=1, gates=['t', 's', 'x', 'y', 's', 't', 's', 'x', 'y', 's'], use_barriers=False)

# %%
validator.draw()

# %%
validator.plot_results()

# %%
validator.run_on_ibm(channel=channel, token=token)
# Out:
# ibm_kyiv
# 3
# >>> Job ID: cyehjrvrta1g00882nq0
# >>> Job Status: QUEUED
# >>> Job Status: RUNNING
# >>> Job Status: RUNNING
# >>> Job Status: DONE
# {'0': 2113, '1': 1983}
# ({'0': 2113, '1': 1983},
#  <qiskit.circuit.quantumcircuit.QuantumCircuit at 0xffff3c850110>)

# %%
validator.get_job_results(
    token=token,
    job_id='cyehjrvrta1g00882nq0'
)
# Out:
# Measurement Counts:
# {'0': 2113, '1': 1983}
# Circuit Metrics:
# Circuit depth: 25
# Circuit width: 5
# Total number of operations: 31
# Operation distribution: OrderedDict([('cx', 5), ('h', 4), ('s', 4), ('x', 4), ('y', 4), ('sdg', 4), ('t', 2), ('tdg', 2), ('cz', 1), ('measure', 1)])
#
# Success Rate: 51.59%
# {'counts': {'0': 2113, '1': 1983},
#  'depth': 25,
#  'width': 5,
#  'size': 31,
#  'operations': OrderedDict([('cx', 5),
#               ('h', 4),
#               ('s', 4),
#               ('x', 4),
#               ('y', 4),
#               ('sdg', 4),
#               ('t', 2),
#               ('tdg', 2),
#               ('cz', 1),
#               ('measure', 1)]),
#  'success_rate': 0.515869140625,
# ...
